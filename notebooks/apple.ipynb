# %%
import matplotlib
# %matplotlib inline
import numpy as np
import pandas as pd
import json

# %%
import requests

# %%
url = "https://stocknewsapi.com/api/v1/stat?&tickers=AAPL&date=04012019-07152021&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"

# %%
url
# Out:
# 'https://stocknewsapi.com/api/v1/stat?&tickers=AAPL&date=04012019-07152021&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit'

# %%
response = requests.get(url)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data

aapl1 = data
aapl1
# Out:
# {'total': {'AAPL': {'Total Positive': 5395,
#    'Total Negative': 2280,
#    'Total Neutral': 3736,
#    'Sentiment Score': 0.737}},
#  'data': {'2021-07-15': {'AAPL': {'Neutral': 3,
#     'Positive': 14,
#     'Negative': 0,
#     'sentiment_score': 1.412}},
#   '2021-07-14': {'AAPL': {'Neutral': 2,
#     'Positive': 16,
#     'Negative': 1,
#     'sentiment_score': 1.289}},
#   '2021-07-13': {'AAPL': {'Neutral': 2,
#     'Positive': 20,
#     'Negative': 2,
#     'sentiment_score': 1.208}},
#   '2021-07-12': {'AAPL': {'Neutral': 1,
#     'Positive': 4,
#     'Negative': 2,
#     'sentiment_score': 0.571}},
#   '2021-07-11': {'AAPL': {'Neutral': 1,
#     'Positive': 1,
#     'Negative': 0,
#     'sentiment_score': 1.25}},
#   '2021-07-10': {'AAPL': {'Neutral': 1,
#     'Positive': 2,
#     'Negative': 0,
#     'sentiment_score': 1.333}},
#   '2021-07-09': {'AAPL': {'Neutral': 5,
#     'Positive': 9,
#     'Negative': 13,
#     'sentiment_score': -0.037}},
# ...

# %%
url_2 = "https://stocknewsapi.com/api/v1/stat?&tickers=AAPL&date=04012019-07152021&page=2&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_3 = "https://stocknewsapi.com/api/v1/stat?&tickers=AAPL&date=04012019-07152021&page=3&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_4 = "https://stocknewsapi.com/api/v1/stat?&tickers=AAPL&date=04012019-07152021&page=4&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_5 = "https://stocknewsapi.com/api/v1/stat?&tickers=AAPL&date=04012019-07152021&page=5&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_6 = "https://stocknewsapi.com/api/v1/stat?&tickers=AAPL&date=04012019-07152021&page=6&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_7 = "https://stocknewsapi.com/api/v1/stat?&tickers=AAPL&date=04012019-07152021&page=7&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_8 = "https://stocknewsapi.com/api/v1/stat?&tickers=AAPL&date=04012019-07152021&page=8&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_9 = "https://stocknewsapi.com/api/v1/stat?&tickers=AAPL&date=04012019-07152021&page=9&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_10 = "https://stocknewsapi.com/api/v1/stat?&tickers=AAPL&date=04012019-07152021&page=10&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_11 = "https://stocknewsapi.com/api/v1/stat?&tickers=AAPL&date=04012019-07152021&page=11&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_12 = "https://stocknewsapi.com/api/v1/stat?&tickers=AAPL&date=04012019-07152021&page=12&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_13 = "https://stocknewsapi.com/api/v1/stat?&tickers=AAPL&date=04012019-07152021&page=13&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_14 = "https://stocknewsapi.com/api/v1/stat?&tickers=AAPL&date=04012019-07152021&page=14&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_15 = "https://stocknewsapi.com/api/v1/stat?&tickers=AAPL&date=04012019-07152021&page=15&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_16 = "https://stocknewsapi.com/api/v1/stat?&tickers=AAPL&date=04012019-07152021&page=16&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_17 = "https://stocknewsapi.com/api/v1/stat?&tickers=AAPL&date=04012019-07152021&page=17&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"

# %%
response = requests.get(url_2)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
aapl2 = data

# %%
response = requests.get(url_3)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
aapl3 = data

# %%
response = requests.get(url_4)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
aapl4 = data

# %%
response = requests.get(url_5)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
aapl5 = data

# %%
response = requests.get(url_6)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
aapl6 = data

# %%
response = requests.get(url_7)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
aapl7 = data

# %%
response = requests.get(url_8)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
aapl8 = data

# %%
response = requests.get(url_9)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
aapl9 = data

# %%
response = requests.get(url_10)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
aapl10 = data

# %%
response = requests.get(url_11)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
aapl11 = data

# %%
response = requests.get(url_12)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
aapl12 = data

# %%
response = requests.get(url_13)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
aapl13 = data

# %%
response = requests.get(url_14)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
aapl14 = data

# %%
response = requests.get(url_15)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
aapl15 = data

# %%
response = requests.get(url_16)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
aapl16 = data

# %%
response = requests.get(url_17)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
aapl17 = data

# %%
aapl1['data'].keys()
datas = aapl1['data'].keys()
aapl_list1 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(aapl1['data'][key]['AAPL']['Positive'])
    mini_array.append(aapl1['data'][key]['AAPL']['Neutral'])
    mini_array.append(aapl1['data'][key]['AAPL']['Negative'])
    mini_array.append(aapl1['data'][key]['AAPL']['sentiment_score'])
    aapl_list1.append(mini_array)
aapl_list1
# Out:
# [['2021-07-15', 14, 3, 0, 1.412],
#  ['2021-07-14', 16, 2, 1, 1.289],
#  ['2021-07-13', 20, 2, 2, 1.208],
#  ['2021-07-12', 4, 1, 2, 0.571],
#  ['2021-07-11', 1, 1, 0, 1.25],
#  ['2021-07-10', 2, 1, 0, 1.333],
#  ['2021-07-09', 9, 5, 13, -0.037],
#  ['2021-07-08', 7, 2, 1, 1.1],
#  ['2021-07-07', 7, 0, 2, 0.833],
#  ['2021-07-06', 7, 7, 0, 1.25],
#  ['2021-07-05', 4, 0, 1, 0.9],
#  ['2021-07-02', 8, 2, 2, 0.917],
#  ['2021-07-01', 5, 0, 4, 0.167],
#  ['2021-06-30', 4, 2, 0, 1.333],
#  ['2021-06-29', 5, 4, 0, 1.278],
#  ['2021-06-28', 9, 2, 2, 0.962],
#  ['2021-06-27', 1, 0, 0, 1.5],
#  ['2021-06-26', 1, 1, 0, 1.25],
#  ['2021-06-25', 2, 4, 1, 0.786],
#  ['2021-06-24', 9, 4, 7, 0.35],
#  ['2021-06-23', 9, 1, 8, 0.139],
#  ['2021-06-22', 7, 5, 2, 0.893],
#  ['2021-06-21', 6, 3, 6, 0.2],
#  ['2021-06-20', 4, 0, 0, 1.5],
#  ['2021-06-18', 3, 1, 0, 1.375],
#  ['2021-06-17', 3, 1, 5, -0.222],
#  ['2021-06-16', 7, 3, 4, 0.536],
#  ['2021-06-15', 5, 4, 13, -0.364],
# ...

# %%
aapl2['data'].keys()
datas = aapl2['data'].keys()
aapl_list2 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(aapl2['data'][key]['AAPL']['Positive'])
    mini_array.append(aapl2['data'][key]['AAPL']['Neutral'])
    mini_array.append(aapl2['data'][key]['AAPL']['Negative'])
    mini_array.append(aapl2['data'][key]['AAPL']['sentiment_score'])
    aapl_list2.append(mini_array)
aapl_list2
# Out:
# [['2021-05-23', 2, 0, 1, 0.5],
#  ['2021-05-22', 2, 0, 1, 0.5],
#  ['2021-05-21', 7, 22, 3, 0.875],
#  ['2021-05-20', 4, 5, 2, 0.727],
#  ['2021-05-19', 4, 7, 6, 0.235],
#  ['2021-05-18', 7, 4, 3, 0.714],
#  ['2021-05-17', 6, 10, 2, 0.889],
#  ['2021-05-16', 2, 0, 0, 1.5],
#  ['2021-05-14', 3, 1, 4, -0.063],
#  ['2021-05-13', 8, 1, 2, 0.909],
#  ['2021-05-12', 9, 3, 1, 1.154],
#  ['2021-05-11', 2, 2, 8, -0.583],
#  ['2021-05-10', 1, 1, 2, -0.125],
#  ['2021-05-09', 1, 2, 0, 1.167],
#  ['2021-05-08', 0, 3, 0, 1],
#  ['2021-05-07', 5, 5, 3, 0.615],
#  ['2021-05-06', 5, 5, 2, 0.792],
#  ['2021-05-05', 9, 3, 1, 1.154],
#  ['2021-05-04', 4, 3, 7, -0.107],
#  ['2021-05-03', 12, 4, 17, -0.106],
#  ['2021-05-02', 0, 1, 4, -1],
#  ['2021-05-01', 0, 1, 0, 1],
#  ['2021-04-30', 12, 6, 23, -0.256],
#  ['2021-04-29', 24, 7, 8, 0.795],
#  ['2021-04-28', 43, 6, 3, 1.269],
#  ['2021-04-27', 6, 3, 5, 0.321],
#  ['2021-04-26', 23, 11, 7, 0.854],
#  ['2021-04-25', 2, 1, 0, 1.333],
# ...

# %%
aapl3['data'].keys()
datas = aapl3['data'].keys()
aapl_list3 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(aapl3['data'][key]['AAPL']['Positive'])
    mini_array.append(aapl3['data'][key]['AAPL']['Neutral'])
    mini_array.append(aapl3['data'][key]['AAPL']['Negative'])
    mini_array.append(aapl3['data'][key]['AAPL']['sentiment_score'])
    aapl_list3.append(mini_array)
aapl_list3
# Out:
# [['2021-04-02', 0, 1, 0, 1],
#  ['2021-04-01', 4, 1, 0, 1.4],
#  ['2021-03-31', 15, 4, 0, 1.395],
#  ['2021-03-30', 10, 2, 5, 0.559],
#  ['2021-03-29', 3, 1, 1, 0.8],
#  ['2021-03-27', 2, 0, 0, 1.5],
#  ['2021-03-26', 4, 0, 1, 0.9],
#  ['2021-03-25', 5, 1, 1, 1],
#  ['2021-03-24', 4, 1, 2, 0.571],
#  ['2021-03-23', 5, 2, 2, 0.722],
#  ['2021-03-22', 6, 1, 5, 0.208],
#  ['2021-03-21', 1, 1, 2, -0.125],
#  ['2021-03-20', 0, 1, 1, -0.25],
#  ['2021-03-19', 5, 0, 2, 0.643],
#  ['2021-03-18', 8, 1, 3, 0.708],
#  ['2021-03-17', 5, 5, 0, 1.25],
#  ['2021-03-16', 5, 2, 0, 1.357],
#  ['2021-03-15', 0, 3, 0, 1],
#  ['2021-03-14', 1, 3, 0, 1.125],
#  ['2021-03-13', 2, 1, 0, 1.333],
#  ['2021-03-12', 8, 2, 3, 0.731],
#  ['2021-03-11', 4, 4, 0, 1.25],
#  ['2021-03-10', 13, 9, 4, 0.865],
#  ['2021-03-09', 7, 3, 4, 0.536],
#  ['2021-03-08', 7, 1, 2, 0.85],
#  ['2021-03-07', 1, 2, 1, 0.5],
#  ['2021-03-06', 0, 1, 1, -0.25],
#  ['2021-03-05', 4, 5, 3, 0.542],
#  ['2021-03-04', 7, 2, 15, -0.417],
# ...

# %%
aapl4['data'].keys()
datas = aapl4['data'].keys()
aapl_list4 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(aapl4['data'][key]['AAPL']['Positive'])
    mini_array.append(aapl4['data'][key]['AAPL']['Neutral'])
    mini_array.append(aapl4['data'][key]['AAPL']['Negative'])
    mini_array.append(aapl4['data'][key]['AAPL']['sentiment_score'])
    aapl_list4.append(mini_array)
aapl_list4
# Out:
# [['2021-02-10', 4, 5, 2, 0.727],
#  ['2021-02-09', 5, 5, 1, 1],
#  ['2021-02-08', 3, 4, 3, 0.4],
#  ['2021-02-07', 0, 2, 0, 1],
#  ['2021-02-06', 2, 8, 1, 0.864],
#  ['2021-02-05', 6, 8, 3, 0.735],
#  ['2021-02-04', 9, 7, 5, 0.619],
#  ['2021-02-03', 19, 8, 1, 1.25],
#  ['2021-02-02', 5, 6, 1, 1],
#  ['2021-02-01', 15, 2, 2, 1.132],
#  ['2021-01-31', 2, 1, 1, 0.625],
#  ['2021-01-30', 1, 1, 1, 0.333],
#  ['2021-01-29', 3, 6, 3, 0.5],
#  ['2021-01-28', 19, 20, 12, 0.598],
#  ['2021-01-27', 34, 14, 2, 1.24],
#  ['2021-01-26', 13, 8, 1, 1.182],
#  ['2021-01-25', 18, 12, 5, 0.9],
#  ['2021-01-24', 4, 4, 0, 1.25],
#  ['2021-01-23', 1, 1, 0, 1.25],
#  ['2021-01-22', 15, 2, 1, 1.278],
#  ['2021-01-21', 14, 2, 3, 0.974],
#  ['2021-01-20', 5, 2, 1, 1],
#  ['2021-01-19', 6, 2, 1, 1.056],
#  ['2021-01-18', 1, 0, 0, 1.5],
#  ['2021-01-17', 1, 1, 2, -0.125],
#  ['2021-01-16', 3, 3, 0, 1.25],
#  ['2021-01-15', 11, 3, 2, 1.031],
#  ['2021-01-14', 2, 1, 0, 1.333],
# ...

# %%
aapl5['data'].keys()
datas = aapl5['data'].keys()
aapl_list5 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(aapl5['data'][key]['AAPL']['Positive'])
    mini_array.append(aapl5['data'][key]['AAPL']['Neutral'])
    mini_array.append(aapl5['data'][key]['AAPL']['Negative'])
    mini_array.append(aapl5['data'][key]['AAPL']['sentiment_score'])
    aapl_list5.append(mini_array)
aapl_list5
# Out:
# [['2020-12-22', 31, 7, 0, 1.408],
#  ['2020-12-21', 13, 1, 7, 0.476],
#  ['2020-12-20', 1, 1, 2, -0.125],
#  ['2020-12-19', 0, 4, 4, -0.25],
#  ['2020-12-18', 3, 1, 5, -0.222],
#  ['2020-12-17', 4, 0, 7, -0.409],
#  ['2020-12-16', 6, 1, 20, -0.741],
#  ['2020-12-15', 14, 6, 13, 0.227],
#  ['2020-12-14', 14, 3, 3, 0.975],
#  ['2020-12-13', 2, 0, 0, 1.5],
#  ['2020-12-12', 2, 1, 0, 1.333],
#  ['2020-12-11', 5, 4, 0, 1.278],
#  ['2020-12-10', 3, 3, 6, -0.125],
#  ['2020-12-09', 13, 4, 2, 1.079],
#  ['2020-12-08', 23, 9, 3, 1.114],
#  ['2020-12-07', 10, 2, 2, 1],
#  ['2020-12-05', 1, 1, 0, 1.25],
#  ['2020-12-04', 5, 0, 4, 0.167],
#  ['2020-12-03', 3, 1, 0, 1.375],
#  ['2020-12-02', 6, 0, 4, 0.3],
#  ['2020-12-01', 14, 4, 5, 0.761],
#  ['2020-11-30', 11, 3, 8, 0.341],
#  ['2020-11-27', 1, 3, 0, 1.125],
#  ['2020-11-26', 0, 2, 2, -0.25],
#  ['2020-11-25', 5, 1, 4, 0.25],
#  ['2020-11-24', 3, 6, 2, 0.682],
#  ['2020-11-23', 3, 3, 5, 0],
#  ['2020-11-21', 0, 2, 0, 1],
# ...

# %%
aapl6['data'].keys()
datas = aapl6['data'].keys()
aapl_list6 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(aapl6['data'][key]['AAPL']['Positive'])
    mini_array.append(aapl6['data'][key]['AAPL']['Neutral'])
    mini_array.append(aapl6['data'][key]['AAPL']['Negative'])
    mini_array.append(aapl6['data'][key]['AAPL']['sentiment_score'])
    aapl_list6.append(mini_array)
aapl_list6
# Out:
# [['2020-10-28', 9, 8, 3, 0.85],
#  ['2020-10-27', 6, 6, 4, 0.563],
#  ['2020-10-26', 10, 13, 5, 0.732],
#  ['2020-10-25', 0, 4, 2, 0.167],
#  ['2020-10-24', 0, 2, 0, 1],
#  ['2020-10-23', 4, 3, 2, 0.667],
#  ['2020-10-22', 6, 0, 2, 0.75],
#  ['2020-10-21', 2, 2, 0, 1.25],
#  ['2020-10-20', 6, 3, 2, 0.818],
#  ['2020-10-19', 7, 4, 2, 0.885],
#  ['2020-10-18', 2, 1, 0, 1.333],
#  ['2020-10-17', 2, 0, 0, 1.5],
#  ['2020-10-16', 2, 3, 1, 0.75],
#  ['2020-10-15', 3, 1, 3, 0.143],
#  ['2020-10-14', 15, 10, 4, 0.914],
#  ['2020-10-13', 26, 49, 6, 0.975],
#  ['2020-10-12', 22, 5, 6, 0.879],
#  ['2020-10-11', 3, 1, 2, 0.417],
#  ['2020-10-10', 4, 1, 3, 0.313],
#  ['2020-10-09', 5, 10, 4, 0.605],
#  ['2020-10-08', 3, 3, 4, 0.15],
#  ['2020-10-07', 10, 8, 9, 0.352],
#  ['2020-10-06', 12, 14, 22, -0.021],
#  ['2020-10-05', 3, 4, 1, 0.875],
#  ['2020-10-04', 0, 1, 0, 1],
#  ['2020-10-03', 1, 0, 0, 1.5],
#  ['2020-10-02', 3, 4, 2, 0.611],
#  ['2020-10-01', 3, 1, 2, 0.417],
# ...

# %%
aapl7['data'].keys()
datas = aapl7['data'].keys()
aapl_list7 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(aapl7['data'][key]['AAPL']['Positive'])
    mini_array.append(aapl7['data'][key]['AAPL']['Neutral'])
    mini_array.append(aapl7['data'][key]['AAPL']['Negative'])
    mini_array.append(aapl7['data'][key]['AAPL']['sentiment_score'])
    aapl_list7.append(mini_array)
aapl_list7
# Out:
# [['2020-09-08', 15, 7, 16, 0.145],
#  ['2020-09-07', 1, 6, 5, 0],
#  ['2020-09-06', 1, 2, 1, 0.5],
#  ['2020-09-05', 1, 4, 2, 0.357],
#  ['2020-09-04', 10, 10, 10, 0.333],
#  ['2020-09-03', 5, 11, 10, 0.135],
#  ['2020-09-02', 5, 8, 7, 0.25],
#  ['2020-09-01', 26, 5, 4, 1.086],
#  ['2020-08-31', 17, 15, 7, 0.769],
#  ['2020-08-30', 1, 0, 2, -0.5],
#  ['2020-08-29', 2, 1, 0, 1.333],
#  ['2020-08-28', 6, 7, 16, -0.276],
#  ['2020-08-27', 8, 9, 5, 0.614],
#  ['2020-08-26', 10, 13, 8, 0.516],
#  ['2020-08-25', 12, 12, 6, 0.7],
#  ['2020-08-24', 19, 6, 13, 0.395],
#  ['2020-08-23', 2, 0, 7, -0.833],
#  ['2020-08-22', 1, 2, 0, 1.167],
#  ['2020-08-21', 14, 13, 3, 0.983],
#  ['2020-08-20', 15, 11, 1, 1.185],
#  ['2020-08-19', 33, 7, 4, 1.148],
#  ['2020-08-18', 8, 5, 15, -0.196],
#  ['2020-08-17', 6, 9, 14, -0.103],
#  ['2020-08-16', 1, 2, 2, 0.1],
#  ['2020-08-15', 1, 1, 3, -0.4],
#  ['2020-08-14', 9, 16, 12, 0.311],
#  ['2020-08-13', 20, 15, 16, 0.412],
#  ['2020-08-12', 5, 2, 1, 1],
# ...

# %%
aapl8['data'].keys()
datas = aapl8['data'].keys()
aapl_list8 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(aapl8['data'][key]['AAPL']['Positive'])
    mini_array.append(aapl8['data'][key]['AAPL']['Neutral'])
    mini_array.append(aapl8['data'][key]['AAPL']['Negative'])
    mini_array.append(aapl8['data'][key]['AAPL']['sentiment_score'])
    aapl_list8.append(mini_array)
aapl_list8
# Out:
# [['2020-07-20', 0, 2, 1, 0.167],
#  ['2020-07-19', 1, 0, 0, 1.5],
#  ['2020-07-17', 2, 0, 0, 1.5],
#  ['2020-07-16', 4, 8, 0, 1.167],
#  ['2020-07-15', 28, 4, 1, 1.348],
#  ['2020-07-14', 7, 4, 3, 0.714],
#  ['2020-07-13', 11, 16, 0, 1.204],
#  ['2020-07-11', 2, 0, 0, 1.5],
#  ['2020-07-10', 5, 5, 0, 1.25],
#  ['2020-07-09', 4, 3, 0, 1.286],
#  ['2020-07-08', 9, 5, 1, 1.133],
#  ['2020-07-07', 4, 8, 1, 0.962],
#  ['2020-07-06', 6, 3, 0, 1.333],
#  ['2020-07-05', 2, 0, 0, 1.5],
#  ['2020-07-04', 2, 0, 0, 1.5],
#  ['2020-07-03', 1, 3, 0, 1.125],
#  ['2020-07-02', 6, 11, 2, 0.895],
#  ['2020-07-01', 7, 13, 10, 0.283],
#  ['2020-06-30', 7, 7, 4, 0.639],
#  ['2020-06-29', 3, 4, 4, 0.227],
#  ['2020-06-28', 3, 1, 0, 1.375],
#  ['2020-06-27', 2, 0, 1, 0.5],
#  ['2020-06-26', 4, 5, 1, 0.95],
#  ['2020-06-25', 9, 2, 9, 0.1],
#  ['2020-06-24', 6, 6, 11, -0.065],
#  ['2020-06-23', 28, 15, 1, 1.261],
#  ['2020-06-22', 32, 48, 6, 1.012],
#  ['2020-06-21', 0, 6, 2, 0.375],
# ...

# %%
aapl9['data'].keys()
datas = aapl9['data'].keys()
aapl_list9 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(aapl9['data'][key]['AAPL']['Positive'])
    mini_array.append(aapl9['data'][key]['AAPL']['Neutral'])
    mini_array.append(aapl9['data'][key]['AAPL']['Negative'])
    mini_array.append(aapl9['data'][key]['AAPL']['sentiment_score'])
    aapl_list9.append(mini_array)
aapl_list9
# Out:
# [['2020-05-28', 3, 3, 1, 0.857],
#  ['2020-05-27', 9, 2, 0, 1.409],
#  ['2020-05-26', 10, 2, 1, 1.192],
#  ['2020-05-25', 0, 1, 0, 1],
#  ['2020-05-23', 2, 1, 0, 1.333],
#  ['2020-05-22', 4, 4, 0, 1.25],
#  ['2020-05-21', 7, 3, 1, 1.091],
#  ['2020-05-20', 11, 6, 1, 1.167],
#  ['2020-05-19', 5, 5, 0, 1.25],
#  ['2020-05-18', 7, 4, 1, 1.083],
#  ['2020-05-17', 7, 0, 0, 1.5],
#  ['2020-05-16', 1, 0, 1, 0],
#  ['2020-05-15', 5, 2, 0, 1.357],
#  ['2020-05-14', 5, 4, 0, 1.278],
#  ['2020-05-13', 3, 5, 0, 1.188],
#  ['2020-05-12', 7, 1, 0, 1.438],
#  ['2020-05-11', 5, 2, 0, 1.357],
#  ['2020-05-10', 1, 0, 0, 1.5],
#  ['2020-05-09', 3, 0, 0, 1.5],
#  ['2020-05-08', 9, 5, 1, 1.133],
#  ['2020-05-07', 6, 10, 0, 1.188],
#  ['2020-05-06', 9, 5, 0, 1.321],
#  ['2020-05-05', 9, 10, 3, 0.864],
#  ['2020-05-04', 21, 13, 3, 1.081],
#  ['2020-05-03', 2, 1, 1, 0.625],
#  ['2020-05-02', 2, 1, 0, 1.333],
#  ['2020-05-01', 18, 7, 4, 0.966],
#  ['2020-04-30', 35, 15, 7, 1],
# ...

# %%
aapl10['data'].keys()
datas = aapl10['data'].keys()
aapl_list10 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(aapl10['data'][key]['AAPL']['Positive'])
    mini_array.append(aapl10['data'][key]['AAPL']['Neutral'])
    mini_array.append(aapl10['data'][key]['AAPL']['Negative'])
    mini_array.append(aapl10['data'][key]['AAPL']['sentiment_score'])
    aapl_list10.append(mini_array)
aapl_list10
# Out:
# [['2020-04-07', 3, 4, 0, 1.214],
#  ['2020-04-06', 13, 1, 1, 1.267],
#  ['2020-04-05', 2, 3, 0, 1.2],
#  ['2020-04-04', 1, 0, 1, 0],
#  ['2020-04-03', 3, 4, 4, 0.227],
#  ['2020-04-02', 4, 4, 3, 0.5],
#  ['2020-04-01', 7, 12, 1, 1.05],
#  ['2020-03-31', 6, 4, 2, 0.833],
#  ['2020-03-30', 5, 0, 4, 0.167],
#  ['2020-03-29', 2, 0, 0, 1.5],
#  ['2020-03-28', 3, 2, 0, 1.3],
#  ['2020-03-27', 6, 2, 1, 1.056],
#  ['2020-03-26', 6, 4, 4, 0.5],
#  ['2020-03-25', 7, 8, 7, 0.364],
#  ['2020-03-24', 4, 8, 4, 0.5],
#  ['2020-03-23', 8, 6, 4, 0.667],
#  ['2020-03-22', 3, 3, 1, 0.857],
#  ['2020-03-21', 2, 1, 0, 1.333],
#  ['2020-03-20', 5, 12, 4, 0.643],
#  ['2020-03-19', 5, 6, 2, 0.808],
#  ['2020-03-18', 12, 9, 3, 0.938],
#  ['2020-03-17', 3, 7, 9, -0.105],
#  ['2020-03-16', 2, 7, 22, -0.742],
#  ['2020-03-15', 5, 3, 0, 1.313],
#  ['2020-03-14', 2, 1, 12, -0.933],
#  ['2020-03-13', 7, 14, 4, 0.74],
#  ['2020-03-12', 7, 6, 6, 0.395],
#  ['2020-03-11', 5, 11, 4, 0.625],
# ...

# %%
aapl11['data'].keys()
datas = aapl11['data'].keys()
aapl_list11 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(aapl11['data'][key]['AAPL']['Positive'])
    mini_array.append(aapl11['data'][key]['AAPL']['Neutral'])
    mini_array.append(aapl11['data'][key]['AAPL']['Negative'])
    mini_array.append(aapl11['data'][key]['AAPL']['sentiment_score'])
    aapl_list11.append(mini_array)
aapl_list11
# Out:
# [['2020-02-17', 2, 0, 15, -1.147],
#  ['2020-02-15', 0, 1, 0, 1],
#  ['2020-02-14', 6, 1, 2, 0.778],
#  ['2020-02-13', 3, 2, 0, 1.3],
#  ['2020-02-12', 9, 5, 3, 0.824],
#  ['2020-02-11', 6, 8, 2, 0.875],
#  ['2020-02-10', 7, 4, 10, -0.024],
#  ['2020-02-09', 1, 1, 0, 1.25],
#  ['2020-02-08', 2, 0, 0, 1.5],
#  ['2020-02-07', 5, 2, 4, 0.318],
#  ['2020-02-06', 5, 2, 1, 1],
#  ['2020-02-05', 4, 2, 1, 0.929],
#  ['2020-02-04', 7, 2, 3, 0.667],
#  ['2020-02-03', 5, 4, 11, -0.25],
#  ['2020-02-02', 3, 2, 2, 0.5],
#  ['2020-02-01', 0, 3, 2, 0],
#  ['2020-01-31', 7, 4, 1, 1.083],
#  ['2020-01-30', 14, 8, 4, 0.885],
#  ['2020-01-29', 41, 12, 7, 1.05],
#  ['2020-01-28', 48, 16, 8, 1.056],
#  ['2020-01-27', 17, 9, 5, 0.871],
#  ['2020-01-26', 1, 2, 0, 1.167],
#  ['2020-01-25', 2, 0, 0, 1.5],
#  ['2020-01-24', 17, 2, 1, 1.3],
#  ['2020-01-23', 10, 5, 3, 0.861],
#  ['2020-01-22', 9, 10, 3, 0.864],
#  ['2020-01-21', 13, 10, 4, 0.87],
#  ['2020-01-20', 2, 3, 0, 1.2],
# ...

# %%
aapl12['data'].keys()
datas = aapl12['data'].keys()
aapl_list12 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(aapl12['data'][key]['AAPL']['Positive'])
    mini_array.append(aapl12['data'][key]['AAPL']['Neutral'])
    mini_array.append(aapl12['data'][key]['AAPL']['Negative'])
    mini_array.append(aapl12['data'][key]['AAPL']['sentiment_score'])
    aapl_list12.append(mini_array)
aapl_list12
# Out:
# [['2019-12-28', 2, 0, 1, 0.5],
#  ['2019-12-27', 13, 3, 2, 1.083],
#  ['2019-12-26', 6, 4, 1, 1.045],
#  ['2019-12-25', 0, 1, 0, 1],
#  ['2019-12-24', 7, 0, 0, 1.5],
#  ['2019-12-23', 8, 2, 3, 0.731],
#  ['2019-12-22', 0, 1, 0, 1],
#  ['2019-12-21', 2, 1, 0, 1.333],
#  ['2019-12-20', 12, 4, 0, 1.375],
#  ['2019-12-19', 3, 1, 0, 1.375],
#  ['2019-12-18', 12, 4, 2, 1.056],
#  ['2019-12-17', 11, 2, 4, 0.735],
#  ['2019-12-16', 9, 4, 4, 0.676],
#  ['2019-12-15', 1, 0, 1, 0],
#  ['2019-12-14', 2, 1, 0, 1.333],
#  ['2019-12-13', 10, 3, 0, 1.385],
#  ['2019-12-12', 5, 3, 6, 0.107],
#  ['2019-12-11', 7, 5, 2, 0.893],
#  ['2019-12-10', 11, 8, 4, 0.804],
#  ['2019-12-09', 8, 3, 2, 0.923],
#  ['2019-12-08', 1, 1, 0, 1.25],
#  ['2019-12-07', 2, 1, 0, 1.333],
#  ['2019-12-06', 10, 1, 1, 1.208],
#  ['2019-12-05', 6, 3, 1, 1.05],
#  ['2019-12-04', 2, 3, 3, 0.188],
#  ['2019-12-03', 6, 8, 1, 1.033],
#  ['2019-12-02', 14, 5, 3, 0.977],
#  ['2019-12-01', 1, 1, 1, 0.333],
# ...

# %%
aapl13['data'].keys()
datas = aapl13['data'].keys()
aapl_list13 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(aapl13['data'][key]['AAPL']['Positive'])
    mini_array.append(aapl13['data'][key]['AAPL']['Neutral'])
    mini_array.append(aapl13['data'][key]['AAPL']['Negative'])
    mini_array.append(aapl13['data'][key]['AAPL']['sentiment_score'])
    aapl_list13.append(mini_array)
aapl_list13
# Out:
# [['2019-11-07', 6, 1, 2, 0.778],
#  ['2019-11-06', 13, 4, 0, 1.382],
#  ['2019-11-05', 5, 2, 3, 0.5],
#  ['2019-11-04', 14, 3, 2, 1.105],
#  ['2019-11-03', 2, 2, 0, 1.25],
#  ['2019-11-02', 4, 2, 0, 1.333],
#  ['2019-11-01', 19, 8, 2, 1.155],
#  ['2019-10-31', 36, 5, 7, 1.01],
#  ['2019-10-30', 42, 16, 5, 1.135],
#  ['2019-10-29', 10, 3, 4, 0.706],
#  ['2019-10-28', 14, 6, 0, 1.35],
#  ['2019-10-27', 0, 3, 1, 0.375],
#  ['2019-10-26', 3, 1, 1, 0.8],
#  ['2019-10-25', 5, 8, 0, 1.192],
#  ['2019-10-24', 4, 2, 0, 1.333],
#  ['2019-10-23', 10, 4, 1, 1.167],
#  ['2019-10-22', 9, 3, 1, 1.154],
#  ['2019-10-21', 13, 4, 0, 1.382],
#  ['2019-10-20', 0, 0, 1, -1.5],
#  ['2019-10-19', 7, 0, 3, 0.6],
#  ['2019-10-18', 4, 3, 5, 0.125],
#  ['2019-10-17', 8, 7, 0, 1.267],
#  ['2019-10-16', 2, 5, 0, 1.143],
#  ['2019-10-15', 11, 7, 3, 0.905],
#  ['2019-10-14', 7, 7, 1, 1.067],
#  ['2019-10-13', 3, 1, 0, 1.375],
#  ['2019-10-12', 2, 3, 0, 1.2],
#  ['2019-10-11', 18, 11, 0, 1.31],
# ...

# %%
aapl14['data'].keys()
datas = aapl14['data'].keys()
aapl_list14 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(aapl14['data'][key]['AAPL']['Positive'])
    mini_array.append(aapl14['data'][key]['AAPL']['Neutral'])
    mini_array.append(aapl14['data'][key]['AAPL']['Negative'])
    mini_array.append(aapl14['data'][key]['AAPL']['sentiment_score'])
    aapl_list14.append(mini_array)
aapl_list14
# Out:
# [['2019-09-18', 6, 10, 4, 0.65],
#  ['2019-09-17', 8, 9, 6, 0.522],
#  ['2019-09-16', 8, 19, 4, 0.806],
#  ['2019-09-15', 1, 3, 0, 1.125],
#  ['2019-09-14', 2, 2, 0, 1.25],
#  ['2019-09-13', 4, 22, 15, 0.134],
#  ['2019-09-12', 9, 15, 0, 1.188],
#  ['2019-09-11', 29, 24, 3, 1.125],
#  ['2019-09-10', 52, 55, 2, 1.193],
#  ['2019-09-09', 7, 17, 5, 0.69],
#  ['2019-09-08', 1, 2, 0, 1.167],
#  ['2019-09-07', 1, 3, 0, 1.125],
#  ['2019-09-06', 8, 11, 2, 0.952],
#  ['2019-09-05', 2, 15, 0, 1.059],
#  ['2019-09-04', 6, 12, 1, 1.026],
#  ['2019-09-03', 2, 8, 3, 0.5],
#  ['2019-09-02', 0, 2, 1, 0.167],
#  ['2019-08-31', 2, 1, 1, 0.625],
#  ['2019-08-30', 8, 5, 4, 0.647],
#  ['2019-08-29', 12, 14, 3, 0.948],
#  ['2019-08-28', 1, 16, 4, 0.548],
#  ['2019-08-27', 4, 5, 0, 1.222],
#  ['2019-08-26', 2, 12, 2, 0.75],
#  ['2019-08-25', 0, 1, 0, 1],
#  ['2019-08-23', 2, 4, 4, 0.1],
#  ['2019-08-22', 7, 8, 1, 1.063],
#  ['2019-08-21', 6, 15, 3, 0.813],
#  ['2019-08-20', 12, 17, 5, 0.809],
# ...

# %%
aapl15['data'].keys()
datas = aapl15['data'].keys()
aapl_list15 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(aapl15['data'][key]['AAPL']['Positive'])
    mini_array.append(aapl15['data'][key]['AAPL']['Neutral'])
    mini_array.append(aapl15['data'][key]['AAPL']['Negative'])
    mini_array.append(aapl15['data'][key]['AAPL']['sentiment_score'])
    aapl_list15.append(mini_array)
aapl_list15
# Out:
# [['2019-07-28', 0, 3, 0, 1],
#  ['2019-07-27', 0, 2, 0, 1],
#  ['2019-07-26', 8, 10, 6, 0.542],
#  ['2019-07-25', 8, 9, 2, 0.947],
#  ['2019-07-24', 3, 6, 3, 0.5],
#  ['2019-07-23', 14, 10, 6, 0.733],
#  ['2019-07-22', 9, 12, 2, 0.978],
#  ['2019-07-21', 1, 0, 0, 1.5],
#  ['2019-07-19', 0, 2, 1, 0.167],
#  ['2019-07-18', 9, 3, 0, 1.375],
#  ['2019-07-17', 1, 7, 1, 0.778],
#  ['2019-07-16', 3, 4, 1, 0.875],
#  ['2019-07-15', 2, 7, 1, 0.85],
#  ['2019-07-14', 0, 1, 0, 1],
#  ['2019-07-13', 0, 1, 1, -0.25],
#  ['2019-07-12', 2, 4, 1, 0.786],
#  ['2019-07-11', 7, 7, 2, 0.906],
#  ['2019-07-10', 4, 4, 3, 0.5],
#  ['2019-07-09', 9, 14, 3, 0.885],
#  ['2019-07-08', 4, 8, 21, -0.53],
#  ['2019-07-07', 1, 1, 0, 1.25],
#  ['2019-07-06', 1, 1, 1, 0.333],
#  ['2019-07-05', 2, 5, 2, 0.556],
#  ['2019-07-04', 0, 1, 1, -0.25],
#  ['2019-07-03', 5, 3, 1, 1],
#  ['2019-07-02', 4, 7, 7, 0.139],
#  ['2019-07-01', 5, 7, 9, 0.048],
#  ['2019-06-30', 1, 2, 0, 1.167],
#  ['2019-06-29', 3, 2, 0, 1.3],
# ...

# %%
aapl16['data'].keys()
datas = aapl16['data'].keys()
aapl_list16 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(aapl16['data'][key]['AAPL']['Positive'])
    mini_array.append(aapl16['data'][key]['AAPL']['Neutral'])
    mini_array.append(aapl16['data'][key]['AAPL']['Negative'])
    mini_array.append(aapl16['data'][key]['AAPL']['sentiment_score'])
    aapl_list16.append(mini_array)
aapl_list16
# Out:
# [['2019-06-07', 8, 7, 2, 0.941],
#  ['2019-06-06', 11, 4, 5, 0.65],
#  ['2019-06-05', 11, 8, 13, 0.156],
#  ['2019-06-04', 12, 9, 14, 0.171],
#  ['2019-06-03', 41, 21, 14, 0.809],
#  ['2019-06-02', 2, 3, 1, 0.75],
#  ['2019-06-01', 2, 1, 0, 1.333],
#  ['2019-05-31', 3, 5, 1, 0.889],
#  ['2019-05-30', 9, 4, 6, 0.447],
#  ['2019-05-29', 7, 6, 3, 0.75],
#  ['2019-05-28', 8, 5, 9, 0.159],
#  ['2019-05-27', 2, 1, 0, 1.333],
#  ['2019-05-26', 2, 2, 0, 1.25],
#  ['2019-05-25', 0, 1, 1, -0.25],
#  ['2019-05-24', 5, 5, 4, 0.464],
#  ['2019-05-23', 1, 5, 2, 0.438],
#  ['2019-05-22', 2, 6, 8, -0.188],
#  ['2019-05-21', 3, 4, 6, -0.038],
#  ['2019-05-20', 0, 3, 4, -0.429],
#  ['2019-05-19', 1, 1, 0, 1.25],
#  ['2019-05-18', 0, 1, 0, 1],
#  ['2019-05-17', 5, 1, 4, 0.25],
#  ['2019-05-16', 5, 2, 2, 0.722],
#  ['2019-05-15', 2, 2, 4, -0.125],
#  ['2019-05-14', 11, 6, 4, 0.786],
#  ['2019-05-13', 8, 3, 16, -0.333],
#  ['2019-05-12', 1, 1, 0, 1.25],
#  ['2019-05-11', 2, 1, 0, 1.333],
# ...

# %%
aapl17['data'].keys()
datas = aapl17['data'].keys()
aapl_list17 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(aapl17['data'][key]['AAPL']['Positive'])
    mini_array.append(aapl17['data'][key]['AAPL']['Neutral'])
    mini_array.append(aapl17['data'][key]['AAPL']['Negative'])
    mini_array.append(aapl17['data'][key]['AAPL']['sentiment_score'])
    aapl_list17.append(mini_array)
aapl_list17
# Out:
# [['2019-04-18', 3, 2, 2, 0.5],
#  ['2019-04-17', 7, 6, 0, 1.269],
#  ['2019-04-16', 4, 2, 3, 0.389],
#  ['2019-04-15', 4, 3, 6, 0],
#  ['2019-04-14', 1, 0, 0, 1.5],
#  ['2019-04-13', 0, 0, 1, -1.5],
#  ['2019-04-12', 6, 1, 0, 1.429],
#  ['2019-04-11', 2, 4, 6, -0.167],
#  ['2019-04-10', 2, 6, 5, 0.115],
#  ['2019-04-09', 14, 1, 4, 0.842],
#  ['2019-04-08', 7, 0, 1, 1.125],
#  ['2019-04-07', 2, 0, 1, 0.5],
#  ['2019-04-06', 0, 0, 2, -1.5],
#  ['2019-04-05', 6, 2, 2, 0.8],
#  ['2019-04-04', 10, 2, 6, 0.444],
#  ['2019-04-03', 10, 3, 5, 0.583],
#  ['2019-04-02', 4, 1, 4, 0.111],
#  ['2019-04-01', 9, 2, 8, 0.184]]

# %%
aapl_list = aapl_list1 + aapl_list2 + aapl_list3 + aapl_list4 + aapl_list5 + aapl_list6 + aapl_list7 + aapl_list8 + aapl_list9 + aapl_list10 + aapl_list11 + aapl_list12 + aapl_list13 + aapl_list14 + aapl_list15 + aapl_list16 + aapl_list17

# %%
# # my_dict = json.load(json_file)
aapl_df = pd.DataFrame(aapl_list)
aapl_df.shape
# Out:
# (818, 5)

# %%
aapl_df.to_csv('aapl_df.csv')

# %%
aapl_df
# Out:
#               0   1  2  3      4
# 0    2021-07-15  14  3  0  1.412
# 1    2021-07-14  16  2  1  1.289
# 2    2021-07-13  20  2  2  1.208
# 3    2021-07-12   4  1  2  0.571
# 4    2021-07-11   1  1  0  1.250
# ..          ...  .. .. ..    ...
# 813  2019-04-05   6  2  2  0.800
# 814  2019-04-04  10  2  6  0.444
# 815  2019-04-03  10  3  5  0.583
# 816  2019-04-02   4  1  4  0.111
# 817  2019-04-01   9  2  8  0.184
#
# [818 rows x 5 columns]
