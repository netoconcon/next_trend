# %%
import matplotlib
# %matplotlib inline
import numpy as np
import pandas as pd
import json

# %%
import requests

# %%
url = "https://stocknewsapi.com/api/v1/stat?&tickers=GME&date=04012019-07152021&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb"

# %%
url
# Out:
# 'https://stocknewsapi.com/api/v1/stat?&tickers=GME&date=04012019-07152021&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb'

# %%
response = requests.get(url)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data

gme1 = data
gme1
# Out:
# {'total': {'GME': {'Total Positive': 952,
#    'Total Negative': 751,
#    'Total Neutral': 727,
#    'Sentiment Score': 0.423}},
#  'data': {'2021-07-15': {'GME': {'Neutral': 4,
#     'Positive': 0,
#     'Negative': 8,
#     'sentiment_score': -0.667}},
#   '2021-07-14': {'GME': {'Neutral': 0,
#     'Positive': 2,
#     'Negative': 1,
#     'sentiment_score': 0.5}},
#   '2021-07-13': {'GME': {'Neutral': 2,
#     'Positive': 3,
#     'Negative': 0,
#     'sentiment_score': 1.3}},
#   '2021-07-12': {'GME': {'Neutral': 0,
#     'Positive': 2,
#     'Negative': 0,
#     'sentiment_score': 1.5}},
#   '2021-07-11': {'GME': {'Neutral': 0,
#     'Positive': 0,
#     'Negative': 1,
#     'sentiment_score': -1.5}},
#   '2021-07-10': {'GME': {'Neutral': 0,
#     'Positive': 0,
#     'Negative': 1,
#     'sentiment_score': -1.5}},
#   '2021-07-09': {'GME': {'Neutral': 2,
#     'Positive': 0,
#     'Negative': 4,
#     'sentiment_score': -0.667}},
#   '2021-07-08': {'GME': {'Neutral': 2,
#     'Positive': 1,
#     'Negative': 5,
#     'sentiment_score': -0.5}},
#   '2021-07-07': {'GME': {'Neutral': 1,
#     'Positive': 4,
#     'Negative': 5,
#     'sentiment_score': -0.05}},
#   '2021-07-06': {'GME': {'Neutral': 3,
#     'Positive': 4,
#     'Negative': 0,
#     'sentiment_score': 1.286}},
#   '2021-07-05': {'GME': {'Neutral': 0,
#     'Positive': 1,
#     'Negative': 1,
#     'sentiment_score': 0}},
#   '2021-07-02': {'GME': {'Neutral': 0,
#     'Positive': 2,
#     'Negative': 1,
#     'sentiment_score': 0.5}},
#   '2021-07-01': {'GME': {'Neutral': 1,
#     'Positive': 1,
#     'Negative': 0,
#     'sentiment_score': 1.25}},
#   '2021-06-30': {'GME': {'Neutral': 0,
#     'Positive': 1,
#     'Negative': 1,
#     'sentiment_score': 0}},
#   '2021-06-29': {'GME': {'Neutral': 0,
#     'Positive': 1,
#     'Negative': 1,
#     'sentiment_score': 0}},
#   '2021-06-28': {'GME': {'Neutral': 5,
#     'Positive': 2,
#     'Negative': 0,
#     'sentiment_score': 1.143}},
#   '2021-06-27': {'GME': {'Neutral': 0,
#     'Positive': 1,
#     'Negative': 0,
#     'sentiment_score': 1.5}},
#   '2021-06-26': {'GME': {'Neutral': 0,
#     'Positive': 0,
#     'Negative': 1,
#     'sentiment_score': -1.5}},
#   '2021-06-25': {'GME': {'Neutral': 0,
#     'Positive': 0,
#     'Negative': 1,
#     'sentiment_score': -1.5}},
#   '2021-06-24': {'GME': {'Neutral': 2,
#     'Positive': 3,
#     'Negative': 1,
#     'sentiment_score': 0.833}},
#   '2021-06-23': {'GME': {'Neutral': 1,
#     'Positive': 3,
#     'Negative': 1,
#     'sentiment_score': 0.8}},
#   '2021-06-22': {'GME': {'Neutral': 3,
#     'Positive': 20,
#     'Negative': 2,
#     'sentiment_score': 1.2}},
#   '2021-06-21': {'GME': {'Neutral': 4,
#     'Positive': 0,
#     'Negative': 3,
#     'sentiment_score': -0.071}},
#   '2021-06-20': {'GME': {'Neutral': 2,
#     'Positive': 0,
#     'Negative': 0,
#     'sentiment_score': 1}},
#   '2021-06-19': {'GME': {'Neutral': 0,
#     'Positive': 0,
#     'Negative': 1,
#     'sentiment_score': -1.5}},
#   '2021-06-18': {'GME': {'Neutral': 4,
#     'Positive': 0,
#     'Negative': 0,
#     'sentiment_score': 1}},
#   '2021-06-17': {'GME': {'Neutral': 2,
#     'Positive': 2,
#     'Negative': 2,
#     'sentiment_score': 0.333}},
#   '2021-06-16': {'GME': {'Neutral': 0,
#     'Positive': 0,
#     'Negative': 3,
#     'sentiment_score': -1.5}},
#   '2021-06-15': {'GME': {'Neutral': 1,
#     'Positive': 1,
#     'Negative': 2,
#     'sentiment_score': -0.125}},
#   '2021-06-14': {'GME': {'Neutral': 1,
#     'Positive': 1,
#     'Negative': 2,
#     'sentiment_score': -0.125}},
#   '2021-06-13': {'GME': {'Neutral': 0,
#     'Positive': 0,
#     'Negative': 1,
#     'sentiment_score': -1.5}},
#   '2021-06-11': {'GME': {'Neutral': 6,
#     'Positive': 7,
#     'Negative': 2,
#     'sentiment_score': 0.9}},
#   '2021-06-10': {'GME': {'Neutral': 9,
#     'Positive': 8,
#     'Negative': 8,
#     'sentiment_score': 0.36}},
#   '2021-06-09': {'GME': {'Neutral': 26,
#     'Positive': 17,
#     'Negative': 6,
#     'sentiment_score': 0.867}},
#   '2021-06-08': {'GME': {'Neutral': 8,
#     'Positive': 5,
#     'Negative': 2,
#     'sentiment_score': 0.833}},
#   '2021-06-07': {'GME': {'Neutral': 2,
#     'Positive': 12,
#     'Negative': 2,
#     'sentiment_score': 1.063}},
#   '2021-06-06': {'GME': {'Neutral': 2,
#     'Positive': 0,
#     'Negative': 0,
#     'sentiment_score': 1}},
#   '2021-06-04': {'GME': {'Neutral': 0,
#     'Positive': 1,
#     'Negative': 3,
#     'sentiment_score': -0.75}},
#   '2021-06-03': {'GME': {'Neutral': 4,
#     'Positive': 3,
#     'Negative': 1,
#     'sentiment_score': 0.875}},
#   '2021-06-02': {'GME': {'Neutral': 5,
#     'Positive': 5,
#     'Negative': 2,
#     'sentiment_score': 0.792}},
#   '2021-06-01': {'GME': {'Neutral': 3,
#     'Positive': 3,
#     'Negative': 0,
#     'sentiment_score': 1.25}},
#   '2021-05-31': {'GME': {'Neutral': 0,
#     'Positive': 1,
#     'Negative': 0,
#     'sentiment_score': 1.5}},
#   '2021-05-30': {'GME': {'Neutral': 0,
#     'Positive': 1,
#     'Negative': 0,
#     'sentiment_score': 1.5}},
#   '2021-05-29': {'GME': {'Neutral': 0,
#     'Positive': 1,
#     'Negative': 0,
#     'sentiment_score': 1.5}},
#   '2021-05-28': {'GME': {'Neutral': 2,
#     'Positive': 7,
#     'Negative': 2,
#     'sentiment_score': 0.864}},
#   '2021-05-27': {'GME': {'Neutral': 2,
#     'Positive': 7,
#     'Negative': 1,
#     'sentiment_score': 1.1}},
#   '2021-05-26': {'GME': {'Neutral': 3,
#     'Positive': 21,
#     'Negative': 0,
#     'sentiment_score': 1.438}},
#   '2021-05-25': {'GME': {'Neutral': 2,
#     'Positive': 9,
#     'Negative': 1,
#     'sentiment_score': 1.167}},
#   '2021-05-24': {'GME': {'Neutral': 0,
#     'Positive': 1,
#     'Negative': 1,
#     'sentiment_score': 0}},
#   '2021-05-22': {'GME': {'Neutral': 0,
#     'Positive': 1,
#     'Negative': 0,
#     'sentiment_score': 1.5}}},
#  'total_pages': 9}

# %%
url_2 = "https://stocknewsapi.com/api/v1/stat?&tickers=GME&date=04012019-07152021&page=2&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb"

# %%
response = requests.get(url_2)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data

gme2 = data

# %%
url_3 = "https://stocknewsapi.com/api/v1/stat?&tickers=GME&date=04012019-07152021&page=3&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb"

# %%
response = requests.get(url_3)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
gme3 = data

# %%
url_4 = "https://stocknewsapi.com/api/v1/stat?&tickers=gme&date=04012019-07152021&page=4&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb"

response = requests.get(url_4)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data

gme4 = data

# %%
url_5 = "https://stocknewsapi.com/api/v1/stat?&tickers=gme&date=04012019-07152021&page=5&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb"

response = requests.get(url_5)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data

gme5 = data

# %%
url_6 = "https://stocknewsapi.com/api/v1/stat?&tickers=GME&date=04012019-07152021&page=6&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb"

response = requests.get(url_6)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data

gme6 = data

# %%
url_7 = "https://stocknewsapi.com/api/v1/stat?&tickers=gme&date=04012019-07152021&page=7&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb"

response = requests.get(url_7)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data

gme7 = data

# %%
url_8 = "https://stocknewsapi.com/api/v1/stat?&tickers=gme&date=04012019-07152021&page=8&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb"

response = requests.get(url_8)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data

gme8 = data

# %%
url_9 = "https://stocknewsapi.com/api/v1/stat?&tickers=gme&date=04012019-07152021&page=9&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb"

response = requests.get(url_9)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data

gme9 = data

# %%
# url_10 = "https://stocknewsapi.com/api/v1/stat?&tickers=AMZN&date=04012019-07152021&page=10&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb"

# response = requests.get(url_10)
# if response.status_code != 200:
#     print("deu ruim")
# data = response.json()
# data

# amazon10 = data

# %%
# url_11 = "https://stocknewsapi.com/api/v1/stat?&tickers=AMZN&date=04012019-07152021&page=11&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb"

# response = requests.get(url_11)
# if response.status_code != 200:
#     print("deu ruim")
# data = response.json()
# data

# amazon11 = data

# %%
# url_12 = "https://stocknewsapi.com/api/v1/stat?&tickers=AMZN&date=04012019-07152021&page=12&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb"

# response = requests.get(url_12)
# if response.status_code != 200:
#     print("deu ruim")
# data = response.json()
# data

# amazon12 = data

# %%
# url_13 = "https://stocknewsapi.com/api/v1/stat?&tickers=AMZN&date=04012019-07152021&page=13&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb"

# response = requests.get(url_13)
# if response.status_code != 200:
#     print("deu ruim")
# data = response.json()
# data

# amazon13 = data

# %%
# url_14 = "https://stocknewsapi.com/api/v1/stat?&tickers=AMZN&date=04012019-07152021&page=14&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb"

# response = requests.get(url_14)
# if response.status_code != 200:
#     print("deu ruim")
# data = response.json()
# data

# amazon14 = data

# %%
# url_15 = "https://stocknewsapi.com/api/v1/stat?&tickers=AMZN&date=04012019-07152021&page=15&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb"

# response = requests.get(url_15)
# if response.status_code != 200:
#     print("deu ruim")
# data = response.json()
# data

# amazon15 = data

# %%
# url_16 = "https://stocknewsapi.com/api/v1/stat?&tickers=AMZN&date=04012019-07152021&page=16&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb"

# response = requests.get(url_16)
# if response.status_code != 200:
#     print("deu ruim")
# data = response.json()
# data

# amazon16 = data

# %%
# url_17 = "https://stocknewsapi.com/api/v1/stat?&tickers=AMZN&date=04012019-07152021&page=17&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb"

# response = requests.get(url_17)
# if response.status_code != 200:
#     print("deu ruim")
# data = response.json()
# data

# amazon17 = data

# %%
# amazon_df = pd.DataFrame

# %%
# amazon_df['data'] = data

# %%
# amazon2['data'].keys()
# datas = amazon2['data'].keys()
# list = []
# for key in datas:
#     mini_array = []
#     mini_array.append(key)
#     mini_array.append(amazon2['data'][key]['AMZN']['Positive'])
#     mini_array.append(amazon2['data'][key]['AMZN']['Neutral'])
#     mini_array.append(amazon2['data'][key]['AMZN']['Negative'])
#     mini_array.append(amazon2['data'][key]['AMZN']['sentiment_score'])
#     list.append(mini_array)
# list

# %%
# amazon4['data'].keys()
# datas = amazon4['data'].keys()
# list2 = []
# for key in datas:
#     mini_array = []
#     mini_array.append(key)
#     mini_array.append(amazon4['data'][key]['AMZN']['Positive'])
#     mini_array.append(amazon4['data'][key]['AMZN']['Neutral'])
#     mini_array.append(amazon4['data'][key]['AMZN']['Negative'])
#     mini_array.append(amazon4['data'][key]['AMZN']['sentiment_score'])
#     list2.append(mini_array)
# list2

# %%
# amazon_first_try['data'].keys()
# datas = amazon_first_try['data'].keys()
# list3 = []
# for key in datas:
#     mini_array = []
#     mini_array.append(key)
#     mini_array.append(amazon_first_try['data'][key]['AMZN']['Positive'])
#     mini_array.append(amazon_first_try['data'][key]['AMZN']['Neutral'])
#     mini_array.append(amazon_first_try['data'][key]['AMZN']['Negative'])
#     mini_array.append(amazon_first_try['data'][key]['AMZN']['sentiment_score'])
#     list3.append(mini_array)
# list3

# %%
gme1['data'].keys()
datas = gme1['data'].keys()
gme_list1 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(gme1['data'][key]['GME']['Positive'])
    mini_array.append(gme1['data'][key]['GME']['Neutral'])
    mini_array.append(gme1['data'][key]['GME']['Negative'])
    mini_array.append(gme1['data'][key]['GME']['sentiment_score'])
    gme_list1.append(mini_array)
# gme_list1

# %%
gme2['data'].keys()
datas = gme2['data'].keys()
gme_list2 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(gme2['data'][key]['GME']['Positive'])
    mini_array.append(gme2['data'][key]['GME']['Neutral'])
    mini_array.append(gme2['data'][key]['GME']['Negative'])
    mini_array.append(gme2['data'][key]['GME']['sentiment_score'])
    gme_list2.append(mini_array)
# amazon_list1

# %%
gme3['data'].keys()
datas = gme3['data'].keys()
gme_list3 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(gme3['data'][key]['GME']['Positive'])
    mini_array.append(gme3['data'][key]['GME']['Neutral'])
    mini_array.append(gme3['data'][key]['GME']['Negative'])
    mini_array.append(gme3['data'][key]['GME']['sentiment_score'])
    gme_list3.append(mini_array)

# %%
gme4['data'].keys()
datas = gme4['data'].keys()
gme_list4 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(gme4['data'][key]['GME']['Positive'])
    mini_array.append(gme4['data'][key]['GME']['Neutral'])
    mini_array.append(gme4['data'][key]['GME']['Negative'])
    mini_array.append(gme4['data'][key]['GME']['sentiment_score'])
    gme_list4.append(mini_array)

# %%
gme5['data'].keys()
datas = gme5['data'].keys()
gme_list5 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(gme5['data'][key]['GME']['Positive'])
    mini_array.append(gme5['data'][key]['GME']['Neutral'])
    mini_array.append(gme5['data'][key]['GME']['Negative'])
    mini_array.append(gme5['data'][key]['GME']['sentiment_score'])
    gme_list5.append(mini_array)

# %%
gme6['data'].keys()
datas = gme6['data'].keys()
gme_list6 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(gme6['data'][key]['GME']['Positive'])
    mini_array.append(gme6['data'][key]['GME']['Neutral'])
    mini_array.append(gme6['data'][key]['GME']['Negative'])
    mini_array.append(gme6['data'][key]['GME']['sentiment_score'])
    gme_list6.append(mini_array)

# %%
gme7['data'].keys()
datas = gme7['data'].keys()
gme_list7 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(gme7['data'][key]['GME']['Positive'])
    mini_array.append(gme7['data'][key]['GME']['Neutral'])
    mini_array.append(gme7['data'][key]['GME']['Negative'])
    mini_array.append(gme7['data'][key]['GME']['sentiment_score'])
    gme_list7.append(mini_array)

# %%
gme8['data'].keys()
datas = gme8['data'].keys()
gme_list8 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(gme8['data'][key]['GME']['Positive'])
    mini_array.append(gme8['data'][key]['GME']['Neutral'])
    mini_array.append(gme8['data'][key]['GME']['Negative'])
    mini_array.append(gme8['data'][key]['GME']['sentiment_score'])
    gme_list8.append(mini_array)

# %%
gme9['data'].keys()
datas = gme9['data'].keys()
gme_list9 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(gme9['data'][key]['GME']['Positive'])
    mini_array.append(gme9['data'][key]['GME']['Neutral'])
    mini_array.append(gme9['data'][key]['GME']['Negative'])
    mini_array.append(gme9['data'][key]['GME']['sentiment_score'])
    gme_list9.append(mini_array)

# %%
# amazon10['data'].keys()
# datas = amazon10['data'].keys()
# amazon_list10 = []
# for key in datas:
#     mini_array = []
#     mini_array.append(key)
#     mini_array.append(amazon10['data'][key]['AMZN']['Positive'])
#     mini_array.append(amazon10['data'][key]['AMZN']['Neutral'])
#     mini_array.append(amazon10['data'][key]['AMZN']['Negative'])
#     mini_array.append(amazon10['data'][key]['AMZN']['sentiment_score'])
#     amazon_list10.append(mini_array)

# %%
# amazon11['data'].keys()
# datas = amazon11['data'].keys()
# amazon_list11 = []
# for key in datas:
#     mini_array = []
#     mini_array.append(key)
#     mini_array.append(amazon11['data'][key]['AMZN']['Positive'])
#     mini_array.append(amazon11['data'][key]['AMZN']['Neutral'])
#     mini_array.append(amazon11['data'][key]['AMZN']['Negative'])
#     mini_array.append(amazon11['data'][key]['AMZN']['sentiment_score'])
#     amazon_list11.append(mini_array)

# %%
# amazon12['data'].keys()
# datas = amazon12['data'].keys()
# amazon_list12 = []
# for key in datas:
#     mini_array = []
#     mini_array.append(key)
#     mini_array.append(amazon12['data'][key]['AMZN']['Positive'])
#     mini_array.append(amazon12['data'][key]['AMZN']['Neutral'])
#     mini_array.append(amazon12['data'][key]['AMZN']['Negative'])
#     mini_array.append(amazon12['data'][key]['AMZN']['sentiment_score'])
#     amazon_list12.append(mini_array)

# %%
# amazon13['data'].keys()
# datas = amazon13['data'].keys()
# amazon_list13 = []
# for key in datas:
#     mini_array = []
#     mini_array.append(key)
#     mini_array.append(amazon13['data'][key]['AMZN']['Positive'])
#     mini_array.append(amazon13['data'][key]['AMZN']['Neutral'])
#     mini_array.append(amazon13['data'][key]['AMZN']['Negative'])
#     mini_array.append(amazon13['data'][key]['AMZN']['sentiment_score'])
#     amazon_list13.append(mini_array)

# %%
# amazon14['data'].keys()
# datas = amazon14['data'].keys()
# amazon_list14 = []
# for key in datas:
#     mini_array = []
#     mini_array.append(key)
#     mini_array.append(amazon14['data'][key]['AMZN']['Positive'])
#     mini_array.append(amazon14['data'][key]['AMZN']['Neutral'])
#     mini_array.append(amazon14['data'][key]['AMZN']['Negative'])
#     mini_array.append(amazon14['data'][key]['AMZN']['sentiment_score'])
#     amazon_list14.append(mini_array)

# %%
# amazon15['data'].keys()
# datas = amazon15['data'].keys()
# amazon_list15 = []
# for key in datas:
#     mini_array = []
#     mini_array.append(key)
#     mini_array.append(amazon15['data'][key]['AMZN']['Positive'])
#     mini_array.append(amazon15['data'][key]['AMZN']['Neutral'])
#     mini_array.append(amazon15['data'][key]['AMZN']['Negative'])
#     mini_array.append(amazon15['data'][key]['AMZN']['sentiment_score'])
#     amazon_list15.append(mini_array)

# %%
# amazon16['data'].keys()
# datas = amazon16['data'].keys()
# amazon_list16 = []
# for key in datas:
#     mini_array = []
#     mini_array.append(key)
#     mini_array.append(amazon16['data'][key]['AMZN']['Positive'])
#     mini_array.append(amazon16['data'][key]['AMZN']['Neutral'])
#     mini_array.append(amazon16['data'][key]['AMZN']['Negative'])
#     mini_array.append(amazon16['data'][key]['AMZN']['sentiment_score'])
#     amazon_list16.append(mini_array)

# %%
# amazon17['data'].keys()
# datas = amazon17['data'].keys()
# amazon_list17 = []
# for key in datas:
#     mini_array = []
#     mini_array.append(key)
#     mini_array.append(amazon17['data'][key]['AMZN']['Positive'])
#     mini_array.append(amazon17['data'][key]['AMZN']['Neutral'])
#     mini_array.append(amazon17['data'][key]['AMZN']['Negative'])
#     mini_array.append(amazon17['data'][key]['AMZN']['sentiment_score'])
#     amazon_list17.append(mini_array)

# %%
gme_list = gme_list1 + gme_list2 + gme_list3 + gme_list4 + gme_list5 + gme_list6 + gme_list7 + gme_list8 + gme_list9

# %%
# # my_dict = json.load(json_file)
gme_df = pd.DataFrame(gme_list)
gme_df.shape
# Out:
# (423, 5)

# %%
gme_df.to_csv('gme_df.csv')

# %%
gme_df
# Out:
#               0  1  2  3      4
# 0    2021-07-15  0  4  8 -0.667
# 1    2021-07-14  2  0  1  0.500
# 2    2021-07-13  3  2  0  1.300
# 3    2021-07-12  2  0  0  1.500
# 4    2021-07-11  0  0  1 -1.500
# ..          ... .. .. ..    ...
# 418  2019-04-08  0  1  4 -1.000
# 419  2019-04-07  0  0  1 -1.500
# 420  2019-04-04  0  0  1 -1.500
# 421  2019-04-03  0  2  5 -0.786
# 422  2019-04-02  1  2  5 -0.500
#
# [423 rows x 5 columns]
