# %%
import matplotlib
# %matplotlib inline
import numpy as np
import pandas as pd
import json

# %%
import requests

# %%
url = "https://stocknewsapi.com/api/v1/stat?&tickers=TSLA&date=04012019-07152021&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"

# %%
url
# Out:
# 'https://stocknewsapi.com/api/v1/stat?&tickers=TSLA&date=04012019-07152021&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit'

# %%
response = requests.get(url)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data

tsla1 = data
tsla1
# Out:
# {'total': {'TSLA': {'Total Positive': 4217,
#    'Total Negative': 2335,
#    'Total Neutral': 2886,
#    'Sentiment Score': 0.605}},
#  'data': {'2021-07-15': {'TSLA': {'Neutral': 1,
#     'Positive': 3,
#     'Negative': 5,
#     'sentiment_score': -0.222}},
#   '2021-07-14': {'TSLA': {'Neutral': 2,
#     'Positive': 5,
#     'Negative': 2,
#     'sentiment_score': 0.722}},
#   '2021-07-13': {'TSLA': {'Neutral': 7,
#     'Positive': 9,
#     'Negative': 9,
#     'sentiment_score': 0.28}},
#   '2021-07-12': {'TSLA': {'Neutral': 1,
#     'Positive': 7,
#     'Negative': 13,
#     'sentiment_score': -0.381}},
#   '2021-07-10': {'TSLA': {'Neutral': 0,
#     'Positive': 0,
#     'Negative': 1,
#     'sentiment_score': -1.5}},
#   '2021-07-09': {'TSLA': {'Neutral': 1,
#     'Positive': 4,
#     'Negative': 3,
#     'sentiment_score': 0.313}},
#   '2021-07-08': {'TSLA': {'Neutral': 4,
#     'Positive': 6,
#     'Negative': 8,
#     'sentiment_score': 0.056}},
# ...

# %%
url_2 = "https://stocknewsapi.com/api/v1/stat?&tickers=TSLA&date=04012019-07152021&page=2&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_3 = "https://stocknewsapi.com/api/v1/stat?&tickers=TSLA&date=04012019-07152021&page=3&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_4 = "https://stocknewsapi.com/api/v1/stat?&tickers=TSLA&date=04012019-07152021&page=4&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_5 = "https://stocknewsapi.com/api/v1/stat?&tickers=TSLA&date=04012019-07152021&page=5&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_6 = "https://stocknewsapi.com/api/v1/stat?&tickers=TSLA&date=04012019-07152021&page=6&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_7 = "https://stocknewsapi.com/api/v1/stat?&tickers=TSLA&date=04012019-07152021&page=7&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_8 = "https://stocknewsapi.com/api/v1/stat?&tickers=TSLA&date=04012019-07152021&page=8&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_9 = "https://stocknewsapi.com/api/v1/stat?&tickers=TSLA&date=04012019-07152021&page=9&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_10 = "https://stocknewsapi.com/api/v1/stat?&tickers=TSLA&date=04012019-07152021&page=10&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_11 = "https://stocknewsapi.com/api/v1/stat?&tickers=TSLA&date=04012019-07152021&page=11&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_12 = "https://stocknewsapi.com/api/v1/stat?&tickers=TSLA&date=04012019-07152021&page=12&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_13 = "https://stocknewsapi.com/api/v1/stat?&tickers=TSLA&date=04012019-07152021&page=13&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_14 = "https://stocknewsapi.com/api/v1/stat?&tickers=TSLA&date=04012019-07152021&page=14&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_15 = "https://stocknewsapi.com/api/v1/stat?&tickers=TSLA&date=04012019-07152021&page=15&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_16 = "https://stocknewsapi.com/api/v1/stat?&tickers=TSLA&date=04012019-07152021&page=16&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"

# %%
response = requests.get(url_2)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
tsla2 = data

# %%
response = requests.get(url_3)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
tsla3 = data

# %%
response = requests.get(url_4)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
tsla4 = data

# %%
response = requests.get(url_5)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
tsla5 = data

# %%
response = requests.get(url_6)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
tsla6 = data

# %%
response = requests.get(url_7)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
tsla7 = data

# %%
response = requests.get(url_8)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
tsla8 = data

# %%
response = requests.get(url_9)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
tsla9 = data

# %%
response = requests.get(url_10)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
tsla10 = data

# %%
response = requests.get(url_11)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
tsla11 = data

# %%
response = requests.get(url_12)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
tsla12 = data

# %%
response = requests.get(url_13)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
tsla13 = data

# %%
response = requests.get(url_14)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
tsla14 = data

# %%
response = requests.get(url_15)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
tsla15 = data

# %%
response = requests.get(url_16)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
tsla16 = data

# %%
tsla1['data'].keys()
datas = tsla1['data'].keys()
tsla_list1 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(tsla1['data'][key]['TSLA']['Positive'])
    mini_array.append(tsla1['data'][key]['TSLA']['Neutral'])
    mini_array.append(tsla1['data'][key]['TSLA']['Negative'])
    mini_array.append(tsla1['data'][key]['TSLA']['sentiment_score'])
    tsla_list1.append(mini_array)
tsla_list1
# Out:
# [['2021-07-15', 3, 1, 5, -0.222],
#  ['2021-07-14', 5, 2, 2, 0.722],
#  ['2021-07-13', 9, 7, 9, 0.28],
#  ['2021-07-12', 7, 1, 13, -0.381],
#  ['2021-07-10', 0, 0, 1, -1.5],
#  ['2021-07-09', 4, 1, 3, 0.313],
#  ['2021-07-08', 6, 4, 8, 0.056],
#  ['2021-07-07', 4, 1, 6, -0.182],
#  ['2021-07-06', 6, 1, 3, 0.55],
#  ['2021-07-05', 1, 1, 0, 1.25],
#  ['2021-07-04', 1, 0, 0, 1.5],
#  ['2021-07-03', 1, 0, 0, 1.5],
#  ['2021-07-02', 17, 11, 5, 0.879],
#  ['2021-07-01', 5, 2, 4, 0.318],
#  ['2021-06-30', 8, 3, 0, 1.364],
#  ['2021-06-29', 5, 7, 3, 0.667],
#  ['2021-06-28', 4, 4, 11, -0.342],
#  ['2021-06-27', 1, 0, 2, -0.5],
#  ['2021-06-26', 2, 0, 5, -0.643],
#  ['2021-06-25', 6, 4, 1, 1.045],
#  ['2021-06-24', 13, 5, 1, 1.211],
#  ['2021-06-23', 14, 1, 1, 1.281],
#  ['2021-06-22', 1, 1, 1, 0.333],
#  ['2021-06-21', 7, 1, 1, 1.111],
#  ['2021-06-20', 2, 0, 0, 1.5],
#  ['2021-06-19', 0, 0, 1, -1.5],
#  ['2021-06-18', 2, 1, 3, -0.083],
#  ['2021-06-17', 6, 3, 2, 0.818],
# ...

# %%
tsla2['data'].keys()
datas = tsla2['data'].keys()
tsla_list2 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(tsla2['data'][key]['TSLA']['Positive'])
    mini_array.append(tsla2['data'][key]['TSLA']['Neutral'])
    mini_array.append(tsla2['data'][key]['TSLA']['Negative'])
    mini_array.append(tsla2['data'][key]['TSLA']['sentiment_score'])
    tsla_list2.append(mini_array)
tsla_list2
# Out:
# [['2021-05-24', 7, 1, 6, 0.179],
#  ['2021-05-23', 0, 1, 1, -0.25],
#  ['2021-05-22', 1, 0, 1, 0],
#  ['2021-05-21', 9, 4, 3, 0.813],
#  ['2021-05-20', 9, 5, 3, 0.824],
#  ['2021-05-19', 6, 7, 6, 0.368],
#  ['2021-05-18', 5, 5, 16, -0.442],
#  ['2021-05-17', 5, 9, 10, 0.062],
#  ['2021-05-16', 1, 0, 6, -1.071],
#  ['2021-05-15', 2, 3, 1, 0.75],
#  ['2021-05-14', 1, 2, 3, -0.167],
#  ['2021-05-13', 3, 4, 14, -0.595],
#  ['2021-05-12', 6, 3, 27, -0.792],
#  ['2021-05-11', 1, 6, 16, -0.717],
#  ['2021-05-10', 4, 9, 7, 0.225],
#  ['2021-05-07', 4, 6, 4, 0.429],
#  ['2021-05-06', 5, 3, 4, 0.375],
#  ['2021-05-05', 4, 1, 1, 0.917],
#  ['2021-05-04', 5, 2, 7, -0.071],
#  ['2021-05-03', 4, 3, 5, 0.125],
#  ['2021-05-02', 1, 2, 1, 0.5],
#  ['2021-05-01', 2, 2, 0, 1.25],
#  ['2021-04-30', 3, 4, 1, 0.875],
#  ['2021-04-29', 4, 4, 3, 0.5],
#  ['2021-04-28', 6, 3, 10, -0.158],
#  ['2021-04-27', 14, 9, 18, 0.073],
#  ['2021-04-26', 34, 28, 13, 0.793],
#  ['2021-04-25', 4, 2, 0, 1.333],
# ...

# %%
tsla3['data'].keys()
datas = tsla3['data'].keys()
tsla_list3 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(tsla3['data'][key]['TSLA']['Positive'])
    mini_array.append(tsla3['data'][key]['TSLA']['Neutral'])
    mini_array.append(tsla3['data'][key]['TSLA']['Negative'])
    mini_array.append(tsla3['data'][key]['TSLA']['sentiment_score'])
    tsla_list3.append(mini_array)
tsla_list3
# Out:
# [['2021-03-31', 9, 2, 1, 1.167],
#  ['2021-03-30', 4, 5, 3, 0.542],
#  ['2021-03-29', 3, 7, 5, 0.267],
#  ['2021-03-27', 2, 1, 0, 1.333],
#  ['2021-03-26', 2, 4, 1, 0.786],
#  ['2021-03-25', 4, 4, 4, 0.333],
#  ['2021-03-24', 22, 6, 6, 0.882],
#  ['2021-03-23', 3, 1, 5, -0.222],
#  ['2021-03-22', 16, 1, 5, 0.795],
#  ['2021-03-20', 3, 1, 3, 0.143],
#  ['2021-03-19', 3, 1, 15, -0.895],
#  ['2021-03-18', 3, 1, 3, 0.143],
#  ['2021-03-17', 1, 1, 6, -0.813],
#  ['2021-03-16', 2, 2, 4, -0.125],
#  ['2021-03-15', 7, 18, 6, 0.629],
#  ['2021-03-14', 0, 0, 1, -1.5],
#  ['2021-03-13', 3, 0, 2, 0.3],
#  ['2021-03-12', 6, 6, 11, -0.065],
#  ['2021-03-11', 7, 7, 3, 0.765],
#  ['2021-03-10', 12, 5, 3, 0.925],
#  ['2021-03-09', 27, 9, 2, 1.224],
#  ['2021-03-08', 8, 6, 7, 0.357],
#  ['2021-03-07', 3, 3, 3, 0.333],
#  ['2021-03-06', 2, 1, 0, 1.333],
#  ['2021-03-05', 11, 7, 5, 0.696],
#  ['2021-03-04', 5, 11, 7, 0.348],
#  ['2021-03-03', 8, 5, 2, 0.933],
#  ['2021-03-02', 6, 5, 3, 0.679],
# ...

# %%
tsla4['data'].keys()
datas = tsla4['data'].keys()
tsla_list4 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(tsla4['data'][key]['TSLA']['Positive'])
    mini_array.append(tsla4['data'][key]['TSLA']['Neutral'])
    mini_array.append(tsla4['data'][key]['TSLA']['Negative'])
    mini_array.append(tsla4['data'][key]['TSLA']['sentiment_score'])
    tsla_list4.append(mini_array)
tsla_list4
# Out:
# [['2021-02-06', 1, 4, 1, 0.667],
#  ['2021-02-05', 5, 5, 1, 1],
#  ['2021-02-04', 4, 3, 1, 0.938],
#  ['2021-02-03', 6, 2, 4, 0.417],
#  ['2021-02-02', 6, 8, 13, -0.093],
#  ['2021-02-01', 7, 2, 2, 0.864],
#  ['2021-01-31', 3, 3, 0, 1.25],
#  ['2021-01-30', 5, 1, 0, 1.417],
#  ['2021-01-29', 4, 5, 1, 0.95],
#  ['2021-01-28', 11, 21, 9, 0.585],
#  ['2021-01-27', 22, 18, 11, 0.676],
#  ['2021-01-26', 10, 7, 1, 1.139],
#  ['2021-01-25', 11, 6, 4, 0.786],
#  ['2021-01-24', 2, 7, 2, 0.636],
#  ['2021-01-23', 1, 0, 2, -0.5],
#  ['2021-01-22', 5, 6, 2, 0.808],
#  ['2021-01-21', 2, 1, 10, -0.846],
#  ['2021-01-20', 10, 3, 7, 0.375],
#  ['2021-01-19', 11, 5, 1, 1.176],
#  ['2021-01-18', 7, 1, 0, 1.438],
#  ['2021-01-17', 1, 1, 1, 0.333],
#  ['2021-01-16', 1, 0, 2, -0.5],
#  ['2021-01-15', 11, 6, 4, 0.786],
#  ['2021-01-14', 2, 4, 4, 0.1],
#  ['2021-01-13', 7, 3, 9, 0],
#  ['2021-01-12', 9, 3, 2, 0.964],
#  ['2021-01-11', 8, 3, 6, 0.353],
#  ['2021-01-10', 2, 2, 2, 0.333],
# ...

# %%
tsla5['data'].keys()
datas = tsla5['data'].keys()
tsla_list5 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(tsla5['data'][key]['TSLA']['Positive'])
    mini_array.append(tsla5['data'][key]['TSLA']['Neutral'])
    mini_array.append(tsla5['data'][key]['TSLA']['Negative'])
    mini_array.append(tsla5['data'][key]['TSLA']['sentiment_score'])
    tsla_list5.append(mini_array)
tsla_list5
# Out:
# [['2020-12-18', 22, 6, 6, 0.882],
#  ['2020-12-17', 10, 1, 1, 1.208],
#  ['2020-12-16', 3, 3, 0, 1.25],
#  ['2020-12-15', 6, 3, 2, 0.818],
#  ['2020-12-14', 10, 4, 5, 0.605],
#  ['2020-12-13', 0, 1, 3, -0.875],
#  ['2020-12-12', 1, 2, 3, -0.167],
#  ['2020-12-11', 3, 7, 6, 0.156],
#  ['2020-12-10', 6, 6, 4, 0.563],
#  ['2020-12-09', 9, 1, 10, -0.025],
#  ['2020-12-08', 17, 17, 8, 0.726],
#  ['2020-12-07', 12, 5, 0, 1.353],
#  ['2020-12-06', 2, 0, 0, 1.5],
#  ['2020-12-05', 4, 4, 0, 1.25],
#  ['2020-12-04', 6, 5, 1, 1.042],
#  ['2020-12-03', 16, 7, 2, 1.12],
#  ['2020-12-02', 4, 5, 2, 0.727],
#  ['2020-12-01', 15, 10, 3, 1],
#  ['2020-11-30', 16, 3, 2, 1.143],
#  ['2020-11-29', 2, 5, 0, 1.143],
#  ['2020-11-27', 6, 2, 5, 0.269],
#  ['2020-11-26', 4, 0, 1, 0.9],
#  ['2020-11-25', 8, 4, 11, -0.022],
#  ['2020-11-24', 21, 2, 2, 1.22],
#  ['2020-11-23', 12, 0, 0, 1.5],
#  ['2020-11-22', 2, 0, 0, 1.5],
#  ['2020-11-21', 2, 0, 1, 0.5],
#  ['2020-11-20', 8, 5, 0, 1.308],
# ...

# %%
tsla6['data'].keys()
datas = tsla6['data'].keys()
tsla_list6 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(tsla6['data'][key]['TSLA']['Positive'])
    mini_array.append(tsla6['data'][key]['TSLA']['Neutral'])
    mini_array.append(tsla6['data'][key]['TSLA']['Negative'])
    mini_array.append(tsla6['data'][key]['TSLA']['sentiment_score'])
    tsla_list6.append(mini_array)
tsla_list6
# Out:
# [['2020-10-27', 3, 2, 0, 1.3],
#  ['2020-10-26', 10, 7, 0, 1.294],
#  ['2020-10-25', 3, 1, 0, 1.375],
#  ['2020-10-24', 3, 1, 0, 1.375],
#  ['2020-10-23', 5, 9, 6, 0.375],
#  ['2020-10-22', 31, 8, 2, 1.256],
#  ['2020-10-21', 22, 10, 1, 1.258],
#  ['2020-10-20', 11, 8, 5, 0.708],
#  ['2020-10-19', 11, 2, 3, 0.875],
#  ['2020-10-18', 1, 3, 0, 1.125],
#  ['2020-10-17', 2, 1, 0, 1.333],
#  ['2020-10-16', 3, 6, 1, 0.9],
#  ['2020-10-15', 5, 5, 2, 0.792],
#  ['2020-10-14', 9, 7, 0, 1.281],
#  ['2020-10-13', 5, 5, 0, 1.25],
#  ['2020-10-12', 2, 2, 1, 0.7],
#  ['2020-10-11', 0, 2, 0, 1],
#  ['2020-10-10', 1, 1, 0, 1.25],
#  ['2020-10-09', 6, 0, 1, 1.071],
#  ['2020-10-08', 8, 7, 0, 1.267],
#  ['2020-10-07', 6, 5, 2, 0.846],
#  ['2020-10-06', 8, 6, 3, 0.794],
#  ['2020-10-05', 10, 0, 1, 1.227],
#  ['2020-10-04', 1, 0, 1, 0],
#  ['2020-10-03', 2, 1, 1, 0.625],
#  ['2020-10-02', 21, 4, 5, 0.933],
#  ['2020-10-01', 10, 7, 4, 0.762],
#  ['2020-09-30', 6, 2, 0, 1.375],
# ...

# %%
tsla7['data'].keys()
datas = tsla7['data'].keys()
tsla_list7 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(tsla7['data'][key]['TSLA']['Positive'])
    mini_array.append(tsla7['data'][key]['TSLA']['Neutral'])
    mini_array.append(tsla7['data'][key]['TSLA']['Negative'])
    mini_array.append(tsla7['data'][key]['TSLA']['sentiment_score'])
    tsla_list7.append(mini_array)
tsla_list7
# Out:
# [['2020-09-06', 1, 3, 1, 0.6],
#  ['2020-09-05', 1, 0, 0, 1.5],
#  ['2020-09-04', 2, 6, 11, -0.395],
#  ['2020-09-03', 5, 6, 9, 0],
#  ['2020-09-02', 5, 8, 11, -0.042],
#  ['2020-09-01', 19, 9, 5, 0.909],
#  ['2020-08-31', 19, 18, 1, 1.184],
#  ['2020-08-30', 0, 1, 1, -0.25],
#  ['2020-08-29', 1, 1, 1, 0.333],
#  ['2020-08-28', 6, 7, 2, 0.867],
#  ['2020-08-27', 7, 3, 5, 0.4],
#  ['2020-08-26', 10, 4, 1, 1.167],
#  ['2020-08-25', 4, 5, 0, 1.222],
#  ['2020-08-24', 10, 7, 2, 1],
#  ['2020-08-23', 3, 0, 0, 1.5],
#  ['2020-08-22', 1, 1, 0, 1.25],
#  ['2020-08-21', 14, 3, 1, 1.25],
#  ['2020-08-20', 16, 3, 1, 1.275],
#  ['2020-08-19', 4, 1, 1, 0.917],
#  ['2020-08-18', 7, 5, 1, 1.077],
#  ['2020-08-17', 14, 2, 2, 1.111],
#  ['2020-08-16', 0, 1, 0, 1],
#  ['2020-08-15', 3, 0, 0, 1.5],
#  ['2020-08-14', 7, 6, 0, 1.269],
#  ['2020-08-13', 5, 3, 1, 1],
#  ['2020-08-12', 20, 12, 2, 1.147],
#  ['2020-08-11', 8, 5, 2, 0.933],
#  ['2020-08-10', 3, 4, 0, 1.214],
#  ['2020-08-09', 1, 0, 0, 1.5],
# ...

# %%
tsla8['data'].keys()
datas = tsla8['data'].keys()
tsla_list8 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(tsla8['data'][key]['TSLA']['Positive'])
    mini_array.append(tsla8['data'][key]['TSLA']['Neutral'])
    mini_array.append(tsla8['data'][key]['TSLA']['Negative'])
    mini_array.append(tsla8['data'][key]['TSLA']['sentiment_score'])
    tsla_list8.append(mini_array)
tsla_list8
# Out:
# [['2020-07-18', 0, 1, 0, 1],
#  ['2020-07-17', 5, 2, 1, 1],
#  ['2020-07-16', 3, 3, 7, -0.231],
#  ['2020-07-15', 6, 8, 3, 0.735],
#  ['2020-07-14', 18, 9, 10, 0.568],
#  ['2020-07-13', 17, 14, 3, 1.029],
#  ['2020-07-12', 1, 3, 0, 1.125],
#  ['2020-07-11', 0, 2, 0, 1],
#  ['2020-07-10', 8, 8, 1, 1.088],
#  ['2020-07-09', 12, 13, 2, 1.037],
#  ['2020-07-08', 9, 4, 2, 0.967],
#  ['2020-07-07', 18, 2, 1, 1.31],
#  ['2020-07-06', 15, 7, 0, 1.341],
#  ['2020-07-05', 4, 0, 0, 1.5],
#  ['2020-07-04', 0, 2, 0, 1],
#  ['2020-07-03', 8, 1, 1, 1.15],
#  ['2020-07-02', 34, 5, 4, 1.163],
#  ['2020-07-01', 15, 8, 1, 1.208],
#  ['2020-06-30', 15, 4, 0, 1.395],
#  ['2020-06-29', 8, 7, 1, 1.094],
#  ['2020-06-28', 0, 2, 0, 1],
#  ['2020-06-27', 0, 1, 0, 1],
#  ['2020-06-26', 3, 3, 0, 1.25],
#  ['2020-06-25', 7, 4, 7, 0.222],
#  ['2020-06-24', 1, 1, 17, -1.211],
#  ['2020-06-23', 2, 8, 5, 0.233],
#  ['2020-06-22', 3, 9, 0, 1.125],
#  ['2020-06-21', 1, 1, 1, 0.333],
#  ['2020-06-19', 5, 13, 1, 1],
# ...

# %%
tsla9['data'].keys()
datas = tsla9['data'].keys()
tsla_list9 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(tsla9['data'][key]['TSLA']['Positive'])
    mini_array.append(tsla9['data'][key]['TSLA']['Neutral'])
    mini_array.append(tsla9['data'][key]['TSLA']['Negative'])
    mini_array.append(tsla9['data'][key]['TSLA']['sentiment_score'])
    tsla_list9.append(mini_array)
tsla_list9
# Out:
# [['2020-05-23', 0, 1, 0, 1],
#  ['2020-05-22', 2, 0, 2, 0],
#  ['2020-05-21', 3, 6, 2, 0.682],
#  ['2020-05-20', 4, 7, 0, 1.182],
#  ['2020-05-19', 1, 5, 2, 0.438],
#  ['2020-05-18', 5, 4, 0, 1.278],
#  ['2020-05-17', 1, 0, 0, 1.5],
#  ['2020-05-16', 0, 0, 1, -1.5],
#  ['2020-05-15', 6, 5, 0, 1.273],
#  ['2020-05-14', 8, 3, 5, 0.469],
#  ['2020-05-13', 20, 12, 5, 0.932],
#  ['2020-05-12', 12, 18, 6, 0.75],
#  ['2020-05-11', 4, 20, 19, -0.058],
#  ['2020-05-10', 2, 1, 2, 0.2],
#  ['2020-05-09', 2, 5, 11, -0.472],
#  ['2020-05-08', 8, 5, 6, 0.421],
#  ['2020-05-07', 0, 2, 6, -0.875],
#  ['2020-05-06', 2, 8, 0, 1.1],
#  ['2020-05-05', 4, 3, 2, 0.667],
#  ['2020-05-04', 6, 1, 2, 0.778],
#  ['2020-05-03', 3, 0, 0, 1.5],
#  ['2020-05-02', 1, 1, 2, -0.125],
#  ['2020-05-01', 8, 5, 20, -0.394],
#  ['2020-04-30', 7, 10, 3, 0.8],
#  ['2020-04-29', 23, 20, 5, 0.979],
#  ['2020-04-28', 5, 5, 2, 0.792],
#  ['2020-04-27', 6, 6, 4, 0.563],
#  ['2020-04-26', 0, 5, 2, 0.286],
# ...

# %%
tsla10['data'].keys()
datas = tsla10['data'].keys()
tsla_list10 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(tsla10['data'][key]['TSLA']['Positive'])
    mini_array.append(tsla10['data'][key]['TSLA']['Neutral'])
    mini_array.append(tsla10['data'][key]['TSLA']['Negative'])
    mini_array.append(tsla10['data'][key]['TSLA']['sentiment_score'])
    tsla_list10.append(mini_array)
tsla_list10
# Out:
# [['2020-03-31', 4, 3, 4, 0.273],
#  ['2020-03-30', 1, 3, 4, -0.188],
#  ['2020-03-27', 0, 3, 7, -0.75],
#  ['2020-03-26', 3, 9, 0, 1.125],
#  ['2020-03-25', 3, 3, 2, 0.563],
#  ['2020-03-24', 5, 5, 4, 0.464],
#  ['2020-03-23', 2, 3, 0, 1.2],
#  ['2020-03-22', 1, 4, 0, 1.1],
#  ['2020-03-21', 1, 1, 1, 0.333],
#  ['2020-03-20', 0, 7, 3, 0.25],
#  ['2020-03-19', 7, 21, 6, 0.662],
#  ['2020-03-18', 3, 16, 8, 0.315],
#  ['2020-03-17', 0, 14, 5, 0.342],
#  ['2020-03-16', 2, 4, 5, -0.045],
#  ['2020-03-14', 0, 0, 1, -1.5],
#  ['2020-03-13', 2, 3, 3, 0.188],
#  ['2020-03-12', 1, 2, 5, -0.5],
#  ['2020-03-11', 5, 1, 2, 0.688],
#  ['2020-03-10', 17, 4, 3, 1.042],
#  ['2020-03-09', 3, 1, 6, -0.35],
#  ['2020-03-07', 0, 0, 1, -1.5],
#  ['2020-03-06', 6, 3, 1, 1.05],
#  ['2020-03-05', 1, 0, 4, -0.9],
#  ['2020-03-04', 3, 1, 2, 0.417],
#  ['2020-03-03', 6, 2, 1, 1.056],
#  ['2020-03-02', 3, 1, 3, 0.143],
#  ['2020-03-01', 0, 1, 0, 1],
#  ['2020-02-29', 0, 1, 0, 1],
# ...

# %%
tsla11['data'].keys()
datas = tsla11['data'].keys()
tsla_list11 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(tsla11['data'][key]['TSLA']['Positive'])
    mini_array.append(tsla11['data'][key]['TSLA']['Neutral'])
    mini_array.append(tsla11['data'][key]['TSLA']['Negative'])
    mini_array.append(tsla11['data'][key]['TSLA']['sentiment_score'])
    tsla_list11.append(mini_array)
tsla_list11
# Out:
# [['2020-02-06', 5, 8, 11, -0.042],
#  ['2020-02-05', 20, 8, 28, -0.071],
#  ['2020-02-04', 57, 10, 9, 1.079],
#  ['2020-02-03', 21, 5, 3, 1.103],
#  ['2020-02-02', 2, 0, 0, 1.5],
#  ['2020-02-01', 1, 2, 0, 1.167],
#  ['2020-01-31', 8, 2, 0, 1.4],
#  ['2020-01-30', 32, 3, 3, 1.224],
#  ['2020-01-29', 30, 9, 2, 1.244],
#  ['2020-01-28', 7, 4, 1, 1.083],
#  ['2020-01-27', 6, 1, 2, 0.778],
#  ['2020-01-26', 1, 2, 1, 0.5],
#  ['2020-01-25', 3, 1, 0, 1.375],
#  ['2020-01-24', 5, 7, 6, 0.306],
#  ['2020-01-23', 9, 2, 1, 1.167],
#  ['2020-01-22', 26, 7, 1, 1.309],
#  ['2020-01-21', 14, 7, 3, 0.979],
#  ['2020-01-20', 4, 4, 0, 1.25],
#  ['2020-01-19', 3, 0, 0, 1.5],
#  ['2020-01-18', 1, 0, 1, 0],
#  ['2020-01-17', 7, 4, 6, 0.324],
#  ['2020-01-16', 5, 4, 8, -0.029],
#  ['2020-01-15', 3, 4, 1, 0.875],
#  ['2020-01-14', 16, 5, 2, 1.13],
#  ['2020-01-13', 24, 11, 1, 1.264],
#  ['2020-01-12', 0, 1, 0, 1],
#  ['2020-01-11', 1, 0, 0, 1.5],
#  ['2020-01-10', 5, 4, 3, 0.583],
# ...

# %%
tsla12['data'].keys()
datas = tsla12['data'].keys()
tsla_list12 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(tsla12['data'][key]['TSLA']['Positive'])
    mini_array.append(tsla12['data'][key]['TSLA']['Neutral'])
    mini_array.append(tsla12['data'][key]['TSLA']['Negative'])
    mini_array.append(tsla12['data'][key]['TSLA']['sentiment_score'])
    tsla_list12.append(mini_array)
tsla_list12
# Out:
# [['2019-12-17', 2, 2, 3, 0.071],
#  ['2019-12-16', 4, 3, 3, 0.45],
#  ['2019-12-15', 0, 1, 0, 1],
#  ['2019-12-14', 2, 0, 0, 1.5],
#  ['2019-12-13', 1, 1, 2, -0.125],
#  ['2019-12-12', 3, 1, 2, 0.417],
#  ['2019-12-11', 4, 6, 0, 1.2],
#  ['2019-12-10', 4, 1, 0, 1.4],
#  ['2019-12-09', 4, 6, 3, 0.577],
#  ['2019-12-06', 6, 3, 2, 0.818],
#  ['2019-12-05', 1, 1, 3, -0.4],
#  ['2019-12-04', 2, 4, 1, 0.786],
#  ['2019-12-03', 6, 7, 7, 0.275],
#  ['2019-12-02', 1, 2, 1, 0.5],
#  ['2019-11-30', 0, 5, 0, 1],
#  ['2019-11-29', 2, 3, 1, 0.75],
#  ['2019-11-28', 1, 3, 0, 1.125],
#  ['2019-11-27', 5, 4, 1, 1],
#  ['2019-11-26', 6, 8, 2, 0.875],
#  ['2019-11-25', 15, 6, 1, 1.227],
#  ['2019-11-23', 5, 2, 1, 1],
#  ['2019-11-22', 19, 19, 21, 0.271],
#  ['2019-11-21', 4, 10, 2, 0.813],
#  ['2019-11-20', 6, 4, 2, 0.833],
#  ['2019-11-19', 4, 1, 0, 1.4],
#  ['2019-11-18', 1, 0, 3, -0.75],
#  ['2019-11-16', 0, 1, 0, 1],
#  ['2019-11-15', 3, 1, 0, 1.375],
#  ['2019-11-14', 8, 2, 2, 0.917],
# ...

# %%
tsla13['data'].keys()
datas = tsla13['data'].keys()
tsla_list13 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(tsla13['data'][key]['TSLA']['Positive'])
    mini_array.append(tsla13['data'][key]['TSLA']['Neutral'])
    mini_array.append(tsla13['data'][key]['TSLA']['Negative'])
    mini_array.append(tsla13['data'][key]['TSLA']['sentiment_score'])
    tsla_list13.append(mini_array)
tsla_list13
# Out:
# [['2019-10-21', 2, 2, 1, 0.7],
#  ['2019-10-20', 0, 2, 1, 0.167],
#  ['2019-10-18', 4, 3, 1, 0.938],
#  ['2019-10-17', 7, 2, 0, 1.389],
#  ['2019-10-16', 1, 1, 1, 0.333],
#  ['2019-10-15', 2, 0, 3, -0.3],
#  ['2019-10-14', 3, 0, 1, 0.75],
#  ['2019-10-13', 0, 1, 0, 1],
#  ['2019-10-12', 1, 0, 0, 1.5],
#  ['2019-10-11', 4, 2, 0, 1.333],
#  ['2019-10-10', 1, 3, 0, 1.125],
#  ['2019-10-09', 2, 6, 2, 0.6],
#  ['2019-10-08', 1, 0, 0, 1.5],
#  ['2019-10-07', 4, 2, 1, 0.929],
#  ['2019-10-06', 0, 1, 1, -0.25],
#  ['2019-10-04', 5, 6, 7, 0.167],
#  ['2019-10-03', 5, 3, 11, -0.316],
#  ['2019-10-02', 9, 6, 12, 0.056],
#  ['2019-10-01', 5, 3, 1, 1],
#  ['2019-09-30', 1, 0, 1, 0],
#  ['2019-09-28', 1, 1, 1, 0.333],
#  ['2019-09-27', 4, 5, 3, 0.542],
#  ['2019-09-26', 9, 5, 2, 0.969],
#  ['2019-09-25', 0, 4, 0, 1],
#  ['2019-09-24', 4, 2, 3, 0.389],
#  ['2019-09-23', 1, 2, 1, 0.5],
#  ['2019-09-21', 2, 1, 0, 1.333],
#  ['2019-09-20', 0, 0, 3, -1.5],
#  ['2019-09-19', 6, 2, 1, 1.056],
# ...

# %%
tsla14['data'].keys()
datas = tsla14['data'].keys()
tsla_list14 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(tsla14['data'][key]['TSLA']['Positive'])
    mini_array.append(tsla14['data'][key]['TSLA']['Neutral'])
    mini_array.append(tsla14['data'][key]['TSLA']['Negative'])
    mini_array.append(tsla14['data'][key]['TSLA']['sentiment_score'])
    tsla_list14.append(mini_array)
tsla_list14
# Out:
# [['2019-08-23', 2, 4, 8, -0.357],
#  ['2019-08-22', 8, 7, 3, 0.806],
#  ['2019-08-21', 0, 1, 12, -1.308],
#  ['2019-08-20', 3, 6, 9, -0.167],
#  ['2019-08-19', 1, 0, 1, 0],
#  ['2019-08-18', 1, 0, 0, 1.5],
#  ['2019-08-16', 1, 0, 2, -0.5],
#  ['2019-08-15', 1, 0, 2, -0.5],
#  ['2019-08-14', 0, 1, 2, -0.667],
#  ['2019-08-13', 1, 0, 1, 0],
#  ['2019-08-12', 1, 0, 1, 0],
#  ['2019-08-11', 1, 0, 2, -0.5],
#  ['2019-08-09', 1, 0, 0, 1.5],
#  ['2019-08-08', 0, 0, 3, -1.5],
#  ['2019-08-07', 0, 5, 4, -0.111],
#  ['2019-08-06', 2, 1, 0, 1.333],
#  ['2019-08-05', 3, 2, 0, 1.3],
#  ['2019-08-03', 1, 1, 0, 1.25],
#  ['2019-08-02', 0, 1, 1, -0.25],
#  ['2019-08-01', 0, 4, 0, 1],
#  ['2019-07-31', 0, 1, 0, 1],
#  ['2019-07-30', 1, 1, 1, 0.333],
#  ['2019-07-29', 3, 5, 0, 1.188],
#  ['2019-07-28', 0, 2, 0, 1],
#  ['2019-07-27', 0, 3, 1, 0.375],
#  ['2019-07-26', 2, 5, 6, -0.077],
#  ['2019-07-25', 4, 5, 27, -0.819],
#  ['2019-07-24', 7, 15, 15, 0.081],
#  ['2019-07-23', 3, 4, 2, 0.611],
# ...

# %%
tsla15['data'].keys()
datas = tsla15['data'].keys()
tsla_list15 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(tsla15['data'][key]['TSLA']['Positive'])
    mini_array.append(tsla15['data'][key]['TSLA']['Neutral'])
    mini_array.append(tsla15['data'][key]['TSLA']['Negative'])
    mini_array.append(tsla15['data'][key]['TSLA']['sentiment_score'])
    tsla_list15.append(mini_array)
tsla_list15
# Out:
# [['2019-06-28', 6, 4, 4, 0.5],
#  ['2019-06-27', 4, 2, 1, 0.929],
#  ['2019-06-26', 4, 4, 3, 0.5],
#  ['2019-06-25', 4, 1, 1, 0.917],
#  ['2019-06-24', 5, 0, 2, 0.643],
#  ['2019-06-23', 2, 0, 0, 1.5],
#  ['2019-06-22', 0, 2, 1, 0.167],
#  ['2019-06-21', 1, 1, 3, -0.4],
#  ['2019-06-20', 2, 2, 7, -0.5],
#  ['2019-06-19', 2, 1, 3, -0.083],
#  ['2019-06-18', 5, 3, 2, 0.75],
#  ['2019-06-17', 3, 4, 1, 0.875],
#  ['2019-06-16', 3, 1, 1, 0.8],
#  ['2019-06-15', 1, 0, 0, 1.5],
#  ['2019-06-14', 3, 0, 2, 0.3],
#  ['2019-06-13', 4, 3, 4, 0.273],
#  ['2019-06-12', 9, 6, 3, 0.833],
#  ['2019-06-11', 13, 8, 1, 1.182],
#  ['2019-06-10', 2, 3, 3, 0.188],
#  ['2019-06-09', 0, 0, 1, -1.5],
#  ['2019-06-08', 1, 2, 1, 0.5],
#  ['2019-06-07', 1, 2, 2, 0.1],
#  ['2019-06-06', 9, 0, 0, 1.5],
#  ['2019-06-05', 2, 1, 2, 0.2],
#  ['2019-06-04', 5, 4, 1, 1],
#  ['2019-06-03', 3, 5, 5, 0.154],
#  ['2019-06-02', 0, 0, 1, -1.5],
#  ['2019-05-31', 1, 1, 4, -0.583],
#  ['2019-05-30', 1, 4, 3, 0.125],
# ...

# %%
tsla16['data'].keys()
datas = tsla16['data'].keys()
tsla_list16 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(tsla16['data'][key]['TSLA']['Positive'])
    mini_array.append(tsla16['data'][key]['TSLA']['Neutral'])
    mini_array.append(tsla16['data'][key]['TSLA']['Negative'])
    mini_array.append(tsla16['data'][key]['TSLA']['sentiment_score'])
    tsla_list16.append(mini_array)
tsla_list16
# Out:
# [['2019-05-06', 2, 2, 5, -0.278],
#  ['2019-05-05', 0, 0, 1, -1.5],
#  ['2019-05-04', 1, 1, 1, 0.333],
#  ['2019-05-03', 10, 7, 1, 1.139],
#  ['2019-05-02', 17, 8, 2, 1.13],
#  ['2019-05-01', 2, 2, 2, 0.333],
#  ['2019-04-30', 1, 1, 3, -0.4],
#  ['2019-04-29', 5, 2, 1, 1],
#  ['2019-04-28', 0, 1, 2, -0.667],
#  ['2019-04-26', 4, 4, 4, 0.333],
#  ['2019-04-25', 5, 6, 13, -0.25],
#  ['2019-04-24', 6, 8, 14, -0.143],
#  ['2019-04-23', 7, 9, 4, 0.675],
#  ['2019-04-22', 5, 11, 10, 0.135],
#  ['2019-04-21', 0, 0, 1, -1.5],
#  ['2019-04-19', 1, 1, 1, 0.333],
#  ['2019-04-18', 1, 3, 1, 0.6],
#  ['2019-04-17', 2, 1, 2, 0.2],
#  ['2019-04-16', 2, 2, 1, 0.7],
#  ['2019-04-15', 0, 1, 3, -0.875],
#  ['2019-04-14', 0, 0, 1, -1.5],
#  ['2019-04-13', 2, 0, 0, 1.5],
#  ['2019-04-12', 1, 0, 2, -0.5],
#  ['2019-04-11', 0, 2, 10, -1.083],
#  ['2019-04-10', 6, 1, 1, 1.063],
#  ['2019-04-09', 0, 0, 5, -1.5],
#  ['2019-04-08', 0, 0, 6, -1.5],
#  ['2019-04-07', 1, 0, 1, 0],
# ...

# %%
tsla_list = tsla_list1 + tsla_list2 + tsla_list3 + tsla_list4 + tsla_list5 + tsla_list6 + tsla_list7 + tsla_list8 + tsla_list9 + tsla_list10 + tsla_list11 + tsla_list12 + tsla_list13 + tsla_list14 + tsla_list15 + tsla_list16

# %%
# # my_dict = json.load(json_file)
tsla_df = pd.DataFrame(tsla_list)
tsla_df.shape
# Out:
# (784, 5)

# %%
tsla_df.to_csv('tsla_df.csv')

# %%
tsla_df
# Out:
#               0  1   2   3      4
# 0    2021-07-15  3   1   5 -0.222
# 1    2021-07-14  5   2   2  0.722
# 2    2021-07-13  9   7   9  0.280
# 3    2021-07-12  7   1  13 -0.381
# 4    2021-07-10  0   0   1 -1.500
# ..          ... ..  ..  ..    ...
# 779  2019-04-05  3   6   5  0.214
# 780  2019-04-04  4  17  31 -0.452
# 781  2019-04-03  5   3   2  0.750
# 782  2019-04-02  1   2   6 -0.611
# 783  2019-04-01  2   2   3  0.071
#
# [784 rows x 5 columns]
