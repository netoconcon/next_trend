# %%
import matplotlib
# %matplotlib inline
import numpy as np
import pandas as pd
import json

# %%
import requests

# %%
url = "https://stocknewsapi.com/api/v1/stat?&tickers=PFE&date=04012019-07152021&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"

# %%
url
# Out:
# 'https://stocknewsapi.com/api/v1/stat?&tickers=PFE&date=04012019-07152021&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit'

# %%
response = requests.get(url)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data

pfe1 = data
pfe1
# Out:
# {'total': {'PFE': {'Total Positive': 1715,
#    'Total Negative': 278,
#    'Total Neutral': 928,
#    'Sentiment Score': 1.056}},
#  'data': {'2021-07-15': {'PFE': {'Neutral': 1,
#     'Positive': 0,
#     'Negative': 0,
#     'sentiment_score': 1}},
#   '2021-07-14': {'PFE': {'Neutral': 3,
#     'Positive': 0,
#     'Negative': 0,
#     'sentiment_score': 1}},
#   '2021-07-13': {'PFE': {'Neutral': 4,
#     'Positive': 1,
#     'Negative': 0,
#     'sentiment_score': 1.1}},
#   '2021-07-12': {'PFE': {'Neutral': 1,
#     'Positive': 4,
#     'Negative': 0,
#     'sentiment_score': 1.4}},
#   '2021-07-11': {'PFE': {'Neutral': 3,
#     'Positive': 1,
#     'Negative': 0,
#     'sentiment_score': 1.125}},
#   '2021-07-09': {'PFE': {'Neutral': 4,
#     'Positive': 6,
#     'Negative': 1,
#     'sentiment_score': 1.045}},
#   '2021-07-08': {'PFE': {'Neutral': 2,
#     'Positive': 7,
#     'Negative': 1,
#     'sentiment_score': 1.1}},
#   '2021-07-07': {'PFE': {'Neutral': 0,
# ...

# %%
url_2 = "https://stocknewsapi.com/api/v1/stat?&tickers=PFE&date=04012019-07152021&page=2&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"

# %%
response = requests.get(url_2)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data

pfe2 = data

# %%
url_3 = "https://stocknewsapi.com/api/v1/stat?&tickers=PFE&date=04012019-07152021&page=3&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"

# %%
response = requests.get(url_3)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
pfe3 = data

# %%
url_4 = "https://stocknewsapi.com/api/v1/stat?&tickers=PFE&date=04012019-07152021&page=4&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"

# %%
response = requests.get(url_4)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
pfe4 = data

# %%
url_5 = "https://stocknewsapi.com/api/v1/stat?&tickers=PFE&date=04012019-07152021&page=5&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_6 = "https://stocknewsapi.com/api/v1/stat?&tickers=PFE&date=04012019-07152021&page=6&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"

url_7 = "https://stocknewsapi.com/api/v1/stat?&tickers=PFE&date=04012019-07152021&page=7&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_8 = "https://stocknewsapi.com/api/v1/stat?&tickers=PFE&date=04012019-07152021&page=8&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_9 = "https://stocknewsapi.com/api/v1/stat?&tickers=PFE&date=04012019-07152021&page=9&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_10 = "https://stocknewsapi.com/api/v1/stat?&tickers=PFE&date=04012019-07152021&page=10&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_11 = "https://stocknewsapi.com/api/v1/stat?&tickers=PFE&date=04012019-07152021&page=11&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_12 = "https://stocknewsapi.com/api/v1/stat?&tickers=PFE&date=04012019-07152021&page=12&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_13 = "https://stocknewsapi.com/api/v1/stat?&tickers=PFE&date=04012019-07152021&page=13&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"

url_14 = "https://stocknewsapi.com/api/v1/stat?&tickers=PFE&date=04012019-07152021&page=14&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_15 = "https://stocknewsapi.com/api/v1/stat?&tickers=PFE&date=04012019-07152021&page=15&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"

url_16 = "https://stocknewsapi.com/api/v1/stat?&tickers=PFE&date=04012019-07152021&page=16&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_17 = "https://stocknewsapi.com/api/v1/stat?&tickers=PFE&date=04012019-07152021&page=17&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_18 = "https://stocknewsapi.com/api/v1/stat?&tickers=PFE&date=04012019-07152021&page=18&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_19 = "https://stocknewsapi.com/api/v1/stat?&tickers=PFE&date=04012019-07152021&page=19&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"

# %%
response = requests.get(url_5)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
pfe5 = data

# %%
response = requests.get(url_6)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
pfe6 = data

# %%
response = requests.get(url_7)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
pfe7 = data

# %%
response = requests.get(url_8)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
pfe8 = data

# %%
response = requests.get(url_9)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
pfe9 = data

# %%
response = requests.get(url_10)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
pfe10 = data

# %%
response = requests.get(url_11)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
pfe11 = data

# %%
response = requests.get(url_12)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
pfe12 = data

# %%
response = requests.get(url_13)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
pfe13 = data

# %%
response = requests.get(url_14)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
pfe14 = data

# %%
response = requests.get(url_15)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
pfe15 = data

# %%
response = requests.get(url_16)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
pfe16 = data

# %%
response = requests.get(url_17)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
pfe17 = data

# %%
response = requests.get(url_18)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
pfe18 = data

# %%
response = requests.get(url_19)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
pfe19 = data

# %%
pfe1['data'].keys()
datas = pfe1['data'].keys()
pfe_list1 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(pfe1['data'][key]['PFE']['Positive'])
    mini_array.append(pfe1['data'][key]['PFE']['Neutral'])
    mini_array.append(pfe1['data'][key]['PFE']['Negative'])
    mini_array.append(pfe1['data'][key]['PFE']['sentiment_score'])
    pfe_list1.append(mini_array)
pfe_list1
# Out:
# [['2021-07-15', 0, 1, 0, 1],
#  ['2021-07-14', 0, 3, 0, 1],
#  ['2021-07-13', 1, 4, 0, 1.1],
#  ['2021-07-12', 4, 1, 0, 1.4],
#  ['2021-07-11', 1, 3, 0, 1.125],
#  ['2021-07-09', 6, 4, 1, 1.045],
#  ['2021-07-08', 7, 2, 1, 1.1],
#  ['2021-07-07', 0, 0, 1, -1.5],
#  ['2021-07-06', 2, 4, 0, 1.167],
#  ['2021-07-05', 2, 1, 0, 1.333],
#  ['2021-07-04', 1, 0, 0, 1.5],
#  ['2021-07-03', 1, 0, 0, 1.5],
#  ['2021-07-02', 1, 1, 0, 1.25],
#  ['2021-07-01', 1, 0, 0, 1.5],
#  ['2021-06-30', 2, 4, 0, 1.167],
#  ['2021-06-29', 2, 0, 1, 0.5],
#  ['2021-06-28', 3, 0, 2, 0.3],
#  ['2021-06-27', 1, 1, 0, 1.25],
#  ['2021-06-26', 1, 0, 1, 0],
#  ['2021-06-25', 0, 1, 0, 1],
#  ['2021-06-24', 2, 3, 0, 1.2],
#  ['2021-06-23', 2, 2, 3, 0.071],
#  ['2021-06-22', 2, 2, 0, 1.25],
#  ['2021-06-21', 0, 1, 0, 1],
#  ['2021-06-19', 2, 0, 0, 1.5],
#  ['2021-06-18', 0, 2, 0, 1],
#  ['2021-06-17', 2, 0, 1, 0.5],
#  ['2021-06-16', 2, 2, 0, 1.25],
#  ['2021-06-15', 2, 0, 1, 0.5],
#  ['2021-06-14', 0, 1, 1, -0.25],
# ...

# %%
pfe2['data'].keys()
datas = pfe2['data'].keys()
pfe_list2 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(pfe2['data'][key]['PFE']['Positive'])
    mini_array.append(pfe2['data'][key]['PFE']['Neutral'])
    mini_array.append(pfe2['data'][key]['PFE']['Negative'])
    mini_array.append(pfe2['data'][key]['PFE']['sentiment_score'])
    pfe_list2.append(mini_array)
pfe_list2
# Out:
# [['2021-05-23', 1, 1, 0, 1.25],
#  ['2021-05-21', 1, 2, 0, 1.167],
#  ['2021-05-20', 3, 1, 0, 1.375],
#  ['2021-05-19', 1, 0, 0, 1.5],
#  ['2021-05-18', 1, 2, 1, 0.5],
#  ['2021-05-17', 2, 1, 1, 0.625],
#  ['2021-05-16', 1, 0, 0, 1.5],
#  ['2021-05-15', 3, 0, 0, 1.5],
#  ['2021-05-14', 0, 4, 0, 1],
#  ['2021-05-13', 6, 2, 1, 1.056],
#  ['2021-05-12', 10, 1, 1, 1.208],
#  ['2021-05-11', 6, 2, 0, 1.375],
#  ['2021-05-10', 10, 2, 1, 1.192],
#  ['2021-05-09', 2, 1, 0, 1.333],
#  ['2021-05-08', 4, 1, 0, 1.4],
#  ['2021-05-07', 17, 3, 1, 1.286],
#  ['2021-05-06', 2, 4, 6, -0.167],
#  ['2021-05-05', 7, 2, 3, 0.667],
#  ['2021-05-04', 27, 7, 1, 1.314],
#  ['2021-05-03', 5, 3, 0, 1.313],
#  ['2021-05-02', 0, 2, 0, 1],
#  ['2021-05-01', 0, 1, 0, 1],
#  ['2021-04-30', 7, 2, 2, 0.864],
#  ['2021-04-29', 4, 1, 0, 1.4],
#  ['2021-04-28', 5, 2, 0, 1.357],
#  ['2021-04-27', 3, 1, 0, 1.375],
#  ['2021-04-26', 2, 2, 0, 1.25],
#  ['2021-04-25', 1, 0, 0, 1.5],
#  ['2021-04-24', 1, 0, 0, 1.5],
# ...

# %%
pfe3['data'].keys()
datas = pfe3['data'].keys()
pfe_list3 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(pfe3['data'][key]['PFE']['Positive'])
    mini_array.append(pfe3['data'][key]['PFE']['Neutral'])
    mini_array.append(pfe3['data'][key]['PFE']['Negative'])
    mini_array.append(pfe3['data'][key]['PFE']['sentiment_score'])
    pfe_list3.append(mini_array)
pfe_list3
# Out:
# [['2021-03-30', 0, 1, 0, 1],
#  ['2021-03-29', 4, 1, 0, 1.4],
#  ['2021-03-28', 1, 0, 0, 1.5],
#  ['2021-03-27', 0, 0, 1, -1.5],
#  ['2021-03-26', 1, 0, 2, -0.5],
#  ['2021-03-25', 1, 6, 1, 0.75],
#  ['2021-03-24', 2, 2, 2, 0.333],
#  ['2021-03-23', 9, 6, 1, 1.125],
#  ['2021-03-22', 3, 0, 2, 0.3],
#  ['2021-03-21', 0, 1, 0, 1],
#  ['2021-03-20', 1, 0, 0, 1.5],
#  ['2021-03-19', 1, 0, 0, 1.5],
#  ['2021-03-18', 4, 0, 0, 1.5],
#  ['2021-03-17', 2, 3, 2, 0.429],
#  ['2021-03-16', 2, 0, 0, 1.5],
#  ['2021-03-15', 3, 0, 0, 1.5],
#  ['2021-03-13', 0, 2, 0, 1],
#  ['2021-03-12', 1, 1, 0, 1.25],
#  ['2021-03-11', 8, 3, 0, 1.364],
#  ['2021-03-10', 4, 3, 0, 1.286],
#  ['2021-03-09', 11, 1, 0, 1.458],
#  ['2021-03-08', 2, 1, 0, 1.333],
#  ['2021-03-07', 1, 1, 1, 0.333],
#  ['2021-03-06', 0, 3, 0, 1],
#  ['2021-03-05', 1, 5, 0, 1.083],
#  ['2021-03-04', 4, 2, 1, 0.929],
#  ['2021-03-03', 2, 2, 0, 1.25],
#  ['2021-03-02', 3, 4, 1, 0.875],
#  ['2021-03-01', 1, 1, 0, 1.25],
# ...

# %%
pfe4['data'].keys()
datas = pfe4['data'].keys()
pfe_list4 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(pfe4['data'][key]['PFE']['Positive'])
    mini_array.append(pfe4['data'][key]['PFE']['Neutral'])
    mini_array.append(pfe4['data'][key]['PFE']['Negative'])
    mini_array.append(pfe4['data'][key]['PFE']['sentiment_score'])
    pfe_list4.append(mini_array)
pfe_list4
# Out:
# [['2021-02-04', 2, 3, 0, 1.2],
#  ['2021-02-03', 3, 0, 0, 1.5],
#  ['2021-02-02', 13, 11, 6, 0.717],
#  ['2021-02-01', 4, 2, 0, 1.333],
#  ['2021-01-31', 0, 3, 0, 1],
#  ['2021-01-30', 0, 1, 0, 1],
#  ['2021-01-29', 2, 7, 0, 1.111],
#  ['2021-01-28', 2, 3, 0, 1.2],
#  ['2021-01-27', 2, 3, 1, 0.75],
#  ['2021-01-26', 8, 1, 4, 0.538],
#  ['2021-01-25', 4, 3, 0, 1.286],
#  ['2021-01-24', 1, 2, 0, 1.167],
#  ['2021-01-23', 0, 1, 0, 1],
#  ['2021-01-22', 6, 4, 0, 1.3],
#  ['2021-01-21', 4, 0, 1, 0.9],
#  ['2021-01-20', 7, 1, 0, 1.438],
#  ['2021-01-19', 2, 0, 0, 1.5],
#  ['2021-01-18', 2, 1, 0, 1.333],
#  ['2021-01-16', 1, 1, 0, 1.25],
#  ['2021-01-15', 3, 2, 1, 0.833],
#  ['2021-01-14', 2, 1, 0, 1.333],
#  ['2021-01-13', 1, 0, 0, 1.5],
#  ['2021-01-12', 4, 5, 3, 0.542],
#  ['2021-01-11', 7, 1, 0, 1.438],
#  ['2021-01-10', 1, 0, 0, 1.5],
#  ['2021-01-09', 0, 1, 0, 1],
#  ['2021-01-08', 16, 6, 1, 1.239],
#  ['2021-01-07', 2, 3, 0, 1.2],
#  ['2021-01-06', 0, 2, 0, 1],
# ...

# %%
pfe5['data'].keys()
datas = pfe5['data'].keys()
pfe_list5 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(pfe5['data'][key]['PFE']['Positive'])
    mini_array.append(pfe5['data'][key]['PFE']['Neutral'])
    mini_array.append(pfe5['data'][key]['PFE']['Negative'])
    mini_array.append(pfe5['data'][key]['PFE']['sentiment_score'])
    pfe_list5.append(mini_array)
pfe_list5
# Out:
# [['2020-12-14', 17, 6, 0, 1.37],
#  ['2020-12-13', 5, 3, 0, 1.313],
#  ['2020-12-12', 8, 4, 0, 1.333],
#  ['2020-12-11', 35, 10, 0, 1.389],
#  ['2020-12-10', 23, 6, 5, 0.971],
#  ['2020-12-09', 11, 0, 8, 0.237],
#  ['2020-12-08', 23, 12, 1, 1.25],
#  ['2020-12-07', 3, 7, 1, 0.909],
#  ['2020-12-06', 3, 0, 0, 1.5],
#  ['2020-12-05', 2, 0, 0, 1.5],
#  ['2020-12-04', 5, 0, 1, 1],
#  ['2020-12-03', 7, 6, 9, 0.136],
#  ['2020-12-02', 34, 7, 0, 1.415],
#  ['2020-12-01', 13, 2, 0, 1.433],
#  ['2020-11-30', 3, 1, 0, 1.375],
#  ['2020-11-29', 2, 1, 0, 1.333],
#  ['2020-11-28', 0, 2, 0, 1],
#  ['2020-11-27', 2, 0, 0, 1.5],
#  ['2020-11-25', 4, 3, 1, 0.938],
#  ['2020-11-24', 5, 4, 0, 1.278],
#  ['2020-11-23', 4, 2, 0, 1.333],
#  ['2020-11-22', 2, 2, 1, 0.7],
#  ['2020-11-21', 3, 2, 0, 1.3],
#  ['2020-11-20', 27, 5, 1, 1.333],
#  ['2020-11-19', 8, 4, 1, 1.115],
#  ['2020-11-18', 31, 4, 0, 1.443],
#  ['2020-11-17', 13, 2, 3, 0.944],
#  ['2020-11-16', 10, 5, 5, 0.625],
# ...

# %%
pfe6['data'].keys()
datas = pfe6['data'].keys()
pfe_list6 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(pfe6['data'][key]['PFE']['Positive'])
    mini_array.append(pfe6['data'][key]['PFE']['Neutral'])
    mini_array.append(pfe6['data'][key]['PFE']['Negative'])
    mini_array.append(pfe6['data'][key]['PFE']['sentiment_score'])
    pfe_list6.append(mini_array)
pfe_list6
# Out:
# [['2020-10-22', 2, 2, 0, 1.25],
#  ['2020-10-21', 2, 1, 0, 1.333],
#  ['2020-10-20', 1, 3, 1, 0.6],
#  ['2020-10-19', 3, 2, 0, 1.3],
#  ['2020-10-18', 0, 1, 0, 1],
#  ['2020-10-17', 0, 1, 0, 1],
#  ['2020-10-16', 13, 1, 1, 1.267],
#  ['2020-10-15', 1, 1, 0, 1.25],
#  ['2020-10-14', 2, 2, 0, 1.25],
#  ['2020-10-13', 1, 3, 0, 1.125],
#  ['2020-10-12', 2, 1, 1, 0.625],
#  ['2020-10-11', 3, 1, 0, 1.375],
#  ['2020-10-09', 1, 1, 0, 1.25],
#  ['2020-10-08', 0, 1, 0, 1],
#  ['2020-10-07', 6, 3, 0, 1.333],
#  ['2020-10-06', 4, 3, 0, 1.286],
#  ['2020-10-05', 4, 0, 2, 0.5],
#  ['2020-10-04', 1, 2, 0, 1.167],
#  ['2020-10-03', 0, 1, 0, 1],
#  ['2020-10-02', 2, 2, 0, 1.25],
#  ['2020-10-01', 1, 4, 0, 1.1],
#  ['2020-09-30', 5, 2, 1, 1],
#  ['2020-09-29', 2, 1, 0, 1.333],
#  ['2020-09-28', 0, 2, 0, 1],
#  ['2020-09-27', 2, 0, 0, 1.5],
#  ['2020-09-25', 1, 0, 0, 1.5],
#  ['2020-09-24', 1, 1, 0, 1.25],
#  ['2020-09-23', 3, 2, 0, 1.3],
#  ['2020-09-22', 3, 2, 0, 1.3],
# ...

# %%
pfe7['data'].keys()
datas = pfe7['data'].keys()
pfe_list7 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(pfe7['data'][key]['PFE']['Positive'])
    mini_array.append(pfe7['data'][key]['PFE']['Neutral'])
    mini_array.append(pfe7['data'][key]['PFE']['Negative'])
    mini_array.append(pfe7['data'][key]['PFE']['sentiment_score'])
    pfe_list7.append(mini_array)
pfe_list7
# Out:
# [['2020-08-31', 2, 4, 0, 1.167],
#  ['2020-08-30', 1, 2, 0, 1.167],
#  ['2020-08-28', 0, 2, 0, 1],
#  ['2020-08-27', 1, 1, 2, -0.125],
#  ['2020-08-26', 4, 3, 0, 1.286],
#  ['2020-08-25', 0, 3, 1, 0.375],
#  ['2020-08-24', 3, 2, 1, 0.833],
#  ['2020-08-21', 7, 0, 0, 1.5],
#  ['2020-08-20', 4, 2, 0, 1.333],
#  ['2020-08-19', 1, 1, 0, 1.25],
#  ['2020-08-18', 1, 0, 0, 1.5],
#  ['2020-08-16', 2, 0, 0, 1.5],
#  ['2020-08-14', 1, 2, 0, 1.167],
#  ['2020-08-13', 1, 3, 0, 1.125],
#  ['2020-08-12', 0, 0, 1, -1.5],
#  ['2020-08-11', 4, 0, 0, 1.5],
#  ['2020-08-10', 3, 1, 0, 1.375],
#  ['2020-08-07', 6, 1, 0, 1.429],
#  ['2020-08-06', 1, 3, 0, 1.125],
#  ['2020-08-05', 3, 1, 0, 1.375],
#  ['2020-08-04', 1, 1, 0, 1.25],
#  ['2020-08-03', 1, 1, 0, 1.25],
#  ['2020-08-02', 1, 2, 0, 1.167],
#  ['2020-08-01', 2, 0, 0, 1.5],
#  ['2020-07-31', 1, 2, 0, 1.167],
#  ['2020-07-30', 3, 0, 0, 1.5],
#  ['2020-07-29', 1, 3, 0, 1.125],
#  ['2020-07-28', 15, 5, 3, 1],
#  ['2020-07-27', 7, 2, 1, 1.1],
# ...

# %%
pfe8['data'].keys()
datas = pfe8['data'].keys()
pfe_list8 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(pfe8['data'][key]['PFE']['Positive'])
    mini_array.append(pfe8['data'][key]['PFE']['Neutral'])
    mini_array.append(pfe8['data'][key]['PFE']['Negative'])
    mini_array.append(pfe8['data'][key]['PFE']['sentiment_score'])
    pfe_list8.append(mini_array)
pfe_list8
# Out:
# [['2020-07-01', 17, 4, 0, 1.405],
#  ['2020-06-30', 0, 2, 0, 1],
#  ['2020-06-29', 2, 2, 1, 0.7],
#  ['2020-06-28', 0, 1, 0, 1],
#  ['2020-06-27', 0, 1, 0, 1],
#  ['2020-06-26', 1, 1, 0, 1.25],
#  ['2020-06-25', 0, 2, 1, 0.167],
#  ['2020-06-24', 0, 1, 0, 1],
#  ['2020-06-23', 0, 3, 0, 1],
#  ['2020-06-22', 1, 1, 0, 1.25],
#  ['2020-06-20', 0, 2, 0, 1],
#  ['2020-06-18', 1, 2, 0, 1.167],
#  ['2020-06-17', 1, 0, 0, 1.5],
#  ['2020-06-16', 1, 1, 0, 1.25],
#  ['2020-06-15', 0, 1, 0, 1],
#  ['2020-06-11', 0, 1, 0, 1],
#  ['2020-06-10', 0, 0, 1, -1.5],
#  ['2020-06-09', 0, 1, 0, 1],
#  ['2020-06-08', 2, 0, 1, 0.5],
#  ['2020-06-06', 1, 0, 0, 1.5],
#  ['2020-06-05', 0, 2, 0, 1],
#  ['2020-06-04', 0, 3, 0, 1],
#  ['2020-06-03', 1, 2, 1, 0.5],
#  ['2020-06-02', 2, 0, 1, 0.5],
#  ['2020-06-01', 0, 3, 8, -0.818],
#  ['2020-05-31', 0, 0, 1, -1.5],
#  ['2020-05-30', 1, 0, 0, 1.5],
#  ['2020-05-29', 1, 0, 3, -0.75],
#  ['2020-05-28', 0, 2, 1, 0.167],
#  ['2020-05-26', 0, 1, 0, 1],
# ...

# %%
pfe9['data'].keys()
datas = pfe9['data'].keys()
pfe_list9 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(pfe9['data'][key]['PFE']['Positive'])
    mini_array.append(pfe9['data'][key]['PFE']['Neutral'])
    mini_array.append(pfe9['data'][key]['PFE']['Negative'])
    mini_array.append(pfe9['data'][key]['PFE']['sentiment_score'])
    pfe_list9.append(mini_array)
pfe_list9
# Out:
# [['2020-04-30', 1, 0, 0, 1.5],
#  ['2020-04-29', 1, 2, 1, 0.5],
#  ['2020-04-28', 6, 5, 2, 0.846],
#  ['2020-04-27', 2, 2, 1, 0.7],
#  ['2020-04-26', 0, 1, 0, 1],
#  ['2020-04-25', 0, 1, 0, 1],
#  ['2020-04-24', 1, 0, 0, 1.5],
#  ['2020-04-23', 2, 1, 0, 1.333],
#  ['2020-04-22', 2, 1, 0, 1.333],
#  ['2020-04-21', 0, 1, 0, 1],
#  ['2020-04-17', 1, 0, 0, 1.5],
#  ['2020-04-15', 2, 1, 0, 1.333],
#  ['2020-04-14', 1, 1, 0, 1.25],
#  ['2020-04-13', 2, 1, 0, 1.333],
#  ['2020-04-11', 1, 0, 0, 1.5],
#  ['2020-04-10', 1, 1, 0, 1.25],
#  ['2020-04-09', 9, 3, 0, 1.375],
#  ['2020-04-08', 1, 0, 1, 0],
#  ['2020-04-06', 0, 1, 0, 1],
#  ['2020-04-02', 0, 1, 0, 1],
#  ['2020-04-01', 1, 1, 0, 1.25],
#  ['2020-03-31', 1, 1, 0, 1.25],
#  ['2020-03-30', 2, 1, 0, 1.333],
#  ['2020-03-28', 1, 0, 0, 1.5],
#  ['2020-03-27', 1, 1, 0, 1.25],
#  ['2020-03-26', 2, 2, 0, 1.25],
#  ['2020-03-25', 1, 3, 0, 1.125],
#  ['2020-03-24', 0, 1, 0, 1],
#  ['2020-03-23', 0, 1, 0, 1],
#  ['2020-03-22', 1, 0, 0, 1.5],
# ...

# %%
pfe10['data'].keys()
datas = pfe10['data'].keys()
pfe_list10 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(pfe10['data'][key]['PFE']['Positive'])
    mini_array.append(pfe10['data'][key]['PFE']['Neutral'])
    mini_array.append(pfe10['data'][key]['PFE']['Negative'])
    mini_array.append(pfe10['data'][key]['PFE']['sentiment_score'])
    pfe_list10.append(mini_array)
pfe_list10
# Out:
# [['2020-02-18', 1, 0, 0, 1.5],
#  ['2020-02-14', 0, 1, 0, 1],
#  ['2020-02-12', 1, 0, 1, 0],
#  ['2020-02-11', 0, 1, 1, -0.25],
#  ['2020-02-06', 1, 0, 0, 1.5],
#  ['2020-02-05', 1, 1, 0, 1.25],
#  ['2020-02-03', 1, 1, 0, 1.25],
#  ['2020-01-31', 2, 1, 1, 0.625],
#  ['2020-01-29', 0, 1, 0, 1],
#  ['2020-01-28', 1, 5, 12, -0.639],
#  ['2020-01-27', 1, 3, 0, 1.125],
#  ['2020-01-26', 0, 1, 0, 1],
#  ['2020-01-24', 1, 0, 0, 1.5],
#  ['2020-01-23', 1, 2, 0, 1.167],
#  ['2020-01-22', 1, 0, 0, 1.5],
#  ['2020-01-16', 0, 0, 1, -1.5],
#  ['2020-01-15', 1, 1, 0, 1.25],
#  ['2020-01-14', 3, 0, 0, 1.5],
#  ['2020-01-13', 1, 1, 1, 0.333],
#  ['2020-01-10', 0, 2, 0, 1],
#  ['2020-01-09', 0, 1, 0, 1],
#  ['2020-01-08', 0, 1, 1, -0.25],
#  ['2020-01-07', 2, 1, 0, 1.333],
#  ['2020-01-03', 4, 0, 0, 1.5],
#  ['2020-01-02', 1, 2, 0, 1.167],
#  ['2020-01-01', 0, 2, 0, 1],
#  ['2019-12-31', 3, 1, 1, 0.8],
#  ['2019-12-30', 1, 1, 1, 0.333],
#  ['2019-12-28', 0, 1, 0, 1],
#  ['2019-12-27', 0, 1, 0, 1],
# ...

# %%
pfe11['data'].keys()
datas = pfe11['data'].keys()
pfe_list11 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(pfe11['data'][key]['PFE']['Positive'])
    mini_array.append(pfe11['data'][key]['PFE']['Neutral'])
    mini_array.append(pfe11['data'][key]['PFE']['Negative'])
    mini_array.append(pfe11['data'][key]['PFE']['sentiment_score'])
    pfe_list11.append(mini_array)
pfe_list11
# Out:
# [['2019-11-19', 2, 0, 0, 1.5],
#  ['2019-11-15', 2, 0, 0, 1.5],
#  ['2019-11-14', 1, 1, 0, 1.25],
#  ['2019-11-13', 2, 1, 0, 1.333],
#  ['2019-11-11', 0, 0, 1, -1.5],
#  ['2019-11-08', 0, 0, 1, -1.5],
#  ['2019-11-06', 1, 0, 0, 1.5],
#  ['2019-11-04', 2, 0, 0, 1.5],
#  ['2019-10-30', 0, 1, 0, 1],
#  ['2019-10-29', 16, 3, 0, 1.421],
#  ['2019-10-28', 2, 2, 0, 1.25],
#  ['2019-10-27', 0, 2, 0, 1],
#  ['2019-10-23', 0, 1, 0, 1],
#  ['2019-10-21', 1, 1, 0, 1.25],
#  ['2019-10-17', 0, 1, 0, 1],
#  ['2019-10-15', 1, 0, 0, 1.5],
#  ['2019-10-13', 1, 0, 0, 1.5],
#  ['2019-10-11', 1, 0, 0, 1.5],
#  ['2019-10-10', 0, 1, 2, -0.667],
#  ['2019-10-08', 0, 1, 1, -0.25],
#  ['2019-10-07', 0, 2, 1, 0.167],
#  ['2019-10-01', 1, 0, 0, 1.5],
#  ['2019-09-30', 1, 1, 0, 1.25],
#  ['2019-09-29', 0, 1, 0, 1],
#  ['2019-09-27', 1, 1, 0, 1.25],
#  ['2019-09-26', 0, 1, 0, 1],
#  ['2019-09-25', 1, 0, 0, 1.5],
#  ['2019-09-23', 1, 2, 0, 1.167],
#  ['2019-09-16', 1, 2, 0, 1.167],
# ...

# %%
pfe12['data'].keys()
datas = pfe12['data'].keys()
pfe_list12 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(pfe12['data'][key]['PFE']['Positive'])
    mini_array.append(pfe12['data'][key]['PFE']['Neutral'])
    mini_array.append(pfe12['data'][key]['PFE']['Negative'])
    mini_array.append(pfe12['data'][key]['PFE']['sentiment_score'])
    pfe_list12.append(mini_array)
pfe_list12
# Out:
# [['2019-07-29', 9, 22, 3, 0.912],
#  ['2019-07-28', 0, 1, 0, 1],
#  ['2019-07-27', 1, 1, 0, 1.25],
#  ['2019-07-25', 1, 0, 1, 0],
#  ['2019-07-24', 1, 0, 0, 1.5],
#  ['2019-07-23', 0, 0, 1, -1.5],
#  ['2019-07-21', 0, 1, 0, 1],
#  ['2019-07-20', 1, 0, 0, 1.5],
#  ['2019-07-16', 1, 0, 0, 1.5],
#  ['2019-07-12', 1, 0, 1, 0],
#  ['2019-07-11', 2, 1, 1, 0.625],
#  ['2019-07-10', 3, 1, 0, 1.375],
#  ['2019-07-09', 1, 0, 0, 1.5],
#  ['2019-07-08', 1, 1, 1, 0.333],
#  ['2019-07-07', 0, 1, 0, 1],
#  ['2019-07-05', 2, 0, 2, 0],
#  ['2019-07-03', 2, 1, 0, 1.333],
#  ['2019-07-02', 5, 1, 1, 1],
#  ['2019-07-01', 4, 0, 1, 0.9],
#  ['2019-06-30', 1, 0, 0, 1.5],
#  ['2019-06-29', 1, 0, 0, 1.5],
#  ['2019-06-28', 2, 0, 1, 0.5],
#  ['2019-06-27', 5, 0, 0, 1.5],
#  ['2019-06-25', 2, 0, 1, 0.5],
#  ['2019-06-24', 2, 1, 0, 1.333],
#  ['2019-06-23', 1, 0, 0, 1.5],
#  ['2019-06-21', 1, 0, 1, 0],
#  ['2019-06-20', 1, 0, 0, 1.5],
#  ['2019-06-19', 2, 1, 0, 1.333],
#  ['2019-06-18', 2, 0, 0, 1.5],
# ...

# %%
pfe13['data'].keys()
datas = pfe13['data'].keys()
pfe_list13 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(pfe13['data'][key]['PFE']['Positive'])
    mini_array.append(pfe13['data'][key]['PFE']['Neutral'])
    mini_array.append(pfe13['data'][key]['PFE']['Negative'])
    mini_array.append(pfe13['data'][key]['PFE']['sentiment_score'])
    pfe_list13.append(mini_array)
pfe_list13
# Out:
# [['2019-05-14', 0, 1, 0, 1],
#  ['2019-05-12', 0, 1, 0, 1],
#  ['2019-05-10', 1, 0, 0, 1.5],
#  ['2019-05-09', 1, 0, 0, 1.5],
#  ['2019-05-08', 1, 1, 0, 1.25],
#  ['2019-05-07', 1, 2, 0, 1.167],
#  ['2019-05-06', 1, 0, 0, 1.5],
#  ['2019-05-05', 1, 0, 0, 1.5],
#  ['2019-05-03', 0, 1, 0, 1],
#  ['2019-05-02', 1, 0, 0, 1.5],
#  ['2019-05-01', 2, 0, 0, 1.5],
#  ['2019-04-30', 6, 3, 1, 1.05],
#  ['2019-04-28', 0, 1, 0, 1],
#  ['2019-04-26', 0, 0, 1, -1.5],
#  ['2019-04-24', 2, 0, 0, 1.5],
#  ['2019-04-23', 1, 1, 0, 1.25],
#  ['2019-04-22', 1, 0, 1, 0],
#  ['2019-04-19', 1, 0, 0, 1.5],
#  ['2019-04-18', 0, 0, 1, -1.5],
#  ['2019-04-14', 0, 0, 1, -1.5],
#  ['2019-04-11', 1, 0, 0, 1.5],
#  ['2019-04-10', 1, 0, 2, -0.5],
#  ['2019-04-09', 0, 0, 1, -1.5],
#  ['2019-04-05', 1, 0, 0, 1.5],
#  ['2019-04-02', 1, 0, 0, 1.5],
#  ['2019-04-01', 1, 0, 0, 1.5]]

# %%
pfe_list = pfe_list1 + pfe_list2 + pfe_list3 + pfe_list4 + pfe_list5 + pfe_list6 + pfe_list7 + pfe_list8 + pfe_list9 + pfe_list10 + pfe_list11 + pfe_list12 + pfe_list13

# %%
# # my_dict = json.load(json_file)
pfe_df = pd.DataFrame(pfe_list)
pfe_df.shape
# Out:
# (626, 5)

# %%
pfe_df.to_csv('pfe_df.csv')

# %%
pfe_df
# Out:
#               0  1  2  3      4
# 0    2021-07-15  0  1  0  1.000
# 1    2021-07-14  0  3  0  1.000
# 2    2021-07-13  1  4  0  1.100
# 3    2021-07-12  4  1  0  1.400
# 4    2021-07-11  1  3  0  1.125
# ..          ... .. .. ..    ...
# 621  2019-04-10  1  0  2 -0.500
# 622  2019-04-09  0  0  1 -1.500
# 623  2019-04-05  1  0  0  1.500
# 624  2019-04-02  1  0  0  1.500
# 625  2019-04-01  1  0  0  1.500
#
# [626 rows x 5 columns]
