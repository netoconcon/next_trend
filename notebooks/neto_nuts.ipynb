# %%
# import toolkit
# import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from datetime import date
import pandas as pd

# %%
# import sentimental data
amazon_df = pd.read_csv('amazon_df.csv')
gme_df = pd.read_csv('gme_df.csv')
kodak_df = pd.read_csv('kodak_df.csv')
facebook_df = pd.read_csv('fb_df.csv')

# %%
# renaming columns
amazon_df.rename({'0':'Date', '1':'Positive', '2':'Neutral', '3':'Negative', '4':'Sentimental Score'}, axis=1, inplace=True)
gme_df.rename({'0':'Date', '1':'Positive', '2':'Neutral', '3':'Negative', '4':'Sentimental Score'}, axis=1, inplace=True)
kodak_df.rename({'0':'Date', '1':'Positive', '2':'Neutral', '3':'Negative', '4':'Sentimental Score'}, axis=1, inplace=True)
facebook_df.rename({'0':'Date', '1':'Positive', '2':'Neutral', '3':'Negative', '4':'Sentimental Score'}, axis=1, inplace=True)

# dropping columns

amazon_df.drop(columns=['Unnamed: 0'], inplace=True)
gme_df.drop(columns=['Unnamed: 0'], inplace=True)
kodak_df.drop(columns=['Unnamed: 0'], inplace=True)
facebook_df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
# import price data
amazon_price_df = pd.read_csv('price/AMZN.csv')
gme_price_df = pd.read_csv('price/GME.csv')
kodak_price_df = pd.read_csv('price/KODK.csv')
facebook_price_df = pd.read_csv('price/FB.csv')

# %%
# merging DB

amazon_df = pd.merge(amazon_df, amazon_price_df, how="outer", on=["Date", "Date"] )
gme_df = pd.merge(gme_df, gme_price_df, how="outer", on=["Date", "Date"] )
kodak_df = pd.merge(kodak_df, kodak_price_df, how="outer", on=["Date", "Date"] )
facebook_df = pd.merge(facebook_df, facebook_price_df, how="outer", on=["Date", "Date"] )



print(amazon_df.shape)
print(kodak_df.shape)
print(gme_df.shape)
print(facebook_df.shape)
# Out:
# (804, 11)
# (595, 11)
# (668, 11)
# (847, 11)

# %%
def convert_date(string):
    year = int(string.split('-')[0])
    month = int(string.split('-')[1])
    day = int(string.split('-')[2])
    return date(year, month, day)

# %%
amazon_df['Date'] = amazon_df['Date'].apply(lambda i: convert_date(i) )
amazon_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/rl/l0hlsnhd3_zcy_9mm8jb32n00000gn/T/ipykernel_73844/2180694571.py in <module>
# ----> 1 amazon_df['Date'] = amazon_df['Date'].apply(lambda i: convert_date(i) )
#       2 amazon_df
#
# ~/.pyenv/versions/3.8.6/envs/next_trend/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4354         dtype: float64
#    4355         """
# -> 4356         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4357
#    4358     def _reduce(
#
# ~/.pyenv/versions/3.8.6/envs/next_trend/lib/python3.8/site-packages/pandas/core/apply.py in apply(self)
#    1034             return self.apply_str()
#    1035
# -> 1036         return self.apply_standard()
#    1037
#    1038     def agg(self):
#
# ...

# %% [markdown]
# ### AMAZON DATA

# %%
data = amazon_df['Date']
positive = amazon_df['Positive']
neutral = amazon_df['Neutral']
negative = amazon_df['Negative']
price = amazon_df['Close']
volume = amazon_df['Volume']

fig = plt.figure(figsize=(50.0, 50.0))
gs = fig.add_gridspec(3, 3)
ax1 = fig.add_subplot(gs[0, :])
ax2 = fig.add_subplot(gs[1, :])
ax3 = fig.add_subplot(gs[2, :])

ax1.plot(data, price, color='red')
ax2.bar(data, positive, color='green')
ax2.bar(data, neutral, color='yellow')
ax2.bar(data, negative, color='red')
ax3.bar(data, volume)
# Out:
# <BarContainer object of 804 artists>

# %% [markdown]
# ### FACEBOOK DATA

# %%
data = facebook_df['Date']
positive = facebook_df['Positive']
neutral = facebook_df['Neutral']
negative = facebook_df['Negative']
price = facebook_df['Close']
volume = facebook_df['Volume']

fig = plt.figure(figsize=(50.0, 50.0))
gs = fig.add_gridspec(3, 3)
ax1 = fig.add_subplot(gs[0, :])
ax2 = fig.add_subplot(gs[1, :])
ax3 = fig.add_subplot(gs[2, :])

ax1.plot(data, price, color='red')
ax2.bar(data, positive, color='green')
ax2.bar(data, neutral, color='yellow')
ax2.bar(data, negative, color='red')
ax3.bar(data, volume)
# Out:
# <BarContainer object of 847 artists>

# %% [markdown]
# ### KODAK DATA

# %%
data = kodak_df['Date']
positive = kodak_df['Positive']
neutral = kodak_df['Neutral']
negative = kodak_df['Negative']
price = kodak_df['Close']
volume = kodak_df['Volume']

fig = plt.figure(figsize=(50.0, 50.0))
gs = fig.add_gridspec(3, 3)
ax1 = fig.add_subplot(gs[0, :])
ax2 = fig.add_subplot(gs[1, :])
ax3 = fig.add_subplot(gs[2, :])

ax1.plot(data, price, color='red')
ax2.bar(data, positive, color='green')
ax2.bar(data, neutral, color='yellow')
ax2.bar(data, negative, color='red')
ax3.bar(data, volume)
# Out:
# <BarContainer object of 595 artists>

# %% [markdown]
# ### GME DATA

# %%
data = gme_df['Date']
positive = gme_df['Positive']
neutral = gme_df['Neutral']
negative = gme_df['Negative']
price = gme_df['Close']
volume = gme_df['Volume']

fig = plt.figure(figsize=(50.0, 50.0))
gs = fig.add_gridspec(3, 3)
ax1 = fig.add_subplot(gs[0, :])
ax2 = fig.add_subplot(gs[1, :])
ax3 = fig.add_subplot(gs[2, :])

ax1.plot(data, price, color='red')
ax2.bar(data, positive, color='green')
ax2.bar(data, neutral, color='yellow')
ax2.bar(data, negative, color='red')
ax3.bar(data, volume)
# Out:
# <BarContainer object of 668 artists>
