# %%
import matplotlib
# %matplotlib inline
import numpy as np
import pandas as pd
import json

# %%
import requests

# %%
url = "https://stocknewsapi.com/api/v1/stat?&tickers=JNJ&date=04012019-07152021&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"

# %%
url
# Out:
# 'https://stocknewsapi.com/api/v1/stat?&tickers=JNJ&date=04012019-07152021&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit'

# %%
response = requests.get(url)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data

jnj1 = data
jnj1
# Out:
# {'total': {'JNJ': {'Total Positive': 1269,
#    'Total Negative': 464,
#    'Total Neutral': 693,
#    'Sentiment Score': 0.783}},
#  'data': {'2021-07-15': {'JNJ': {'Neutral': 2,
#     'Positive': 0,
#     'Negative': 11,
#     'sentiment_score': -1.115}},
#   '2021-07-14': {'JNJ': {'Neutral': 2,
#     'Positive': 3,
#     'Negative': 0,
#     'sentiment_score': 1.3}},
#   '2021-07-13': {'JNJ': {'Neutral': 2,
#     'Positive': 3,
#     'Negative': 6,
#     'sentiment_score': -0.227}},
#   '2021-07-12': {'JNJ': {'Neutral': 0,
#     'Positive': 2,
#     'Negative': 6,
#     'sentiment_score': -0.75}},
#   '2021-07-09': {'JNJ': {'Neutral': 0,
#     'Positive': 1,
#     'Negative': 0,
#     'sentiment_score': 1.5}},
#   '2021-07-08': {'JNJ': {'Neutral': 0,
#     'Positive': 1,
#     'Negative': 1,
#     'sentiment_score': 0}},
#   '2021-07-07': {'JNJ': {'Neutral': 0,
#     'Positive': 1,
#     'Negative': 0,
#     'sentiment_score': 1.5}},
#   '2021-07-06': {'JNJ': {'Neutral': 1,
# ...

# %%
url_2 = "https://stocknewsapi.com/api/v1/stat?&tickers=JNJ&date=04012019-07152021&page=2&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_3 = "https://stocknewsapi.com/api/v1/stat?&tickers=JNJ&date=04012019-07152021&page=3&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_4 = "https://stocknewsapi.com/api/v1/stat?&tickers=JNJ&date=04012019-07152021&page=4&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_5 = "https://stocknewsapi.com/api/v1/stat?&tickers=JNJ&date=04012019-07152021&page=5&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_6 = "https://stocknewsapi.com/api/v1/stat?&tickers=JNJ&date=04012019-07152021&page=6&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_7 = "https://stocknewsapi.com/api/v1/stat?&tickers=JNJ&date=04012019-07152021&page=7&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_8 = "https://stocknewsapi.com/api/v1/stat?&tickers=JNJ&date=04012019-07152021&page=8&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_9 = "https://stocknewsapi.com/api/v1/stat?&tickers=JNJ&date=04012019-07152021&page=9&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_10 = "https://stocknewsapi.com/api/v1/stat?&tickers=JNJ&date=04012019-07152021&page=10&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_11 = "https://stocknewsapi.com/api/v1/stat?&tickers=JNJ&date=04012019-07152021&page=11&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_12 = "https://stocknewsapi.com/api/v1/stat?&tickers=JNJ&date=04012019-07152021&page=12&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_13 = "https://stocknewsapi.com/api/v1/stat?&tickers=JNJ&date=04012019-07152021&page=13&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"

# %%
response = requests.get(url_2)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
jnj2 = data

# %%
response = requests.get(url_3)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
jnj3 = data

# %%
response = requests.get(url_4)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
jnj4 = data

# %%
response = requests.get(url_5)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
jnj5 = data

# %%
response = requests.get(url_6)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
jnj6 = data

# %%
response = requests.get(url_7)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
jnj7 = data

# %%
response = requests.get(url_8)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
jnj8 = data

# %%
response = requests.get(url_9)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
jnj9 = data

# %%
response = requests.get(url_10)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
jnj10 = data

# %%
response = requests.get(url_11)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
jnj11 = data

# %%
response = requests.get(url_12)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
jnj12 = data

# %%
response = requests.get(url_13)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
jnj13 = data

# %%
jnj1['data'].keys()
datas = jnj1['data'].keys()
jnj_list1 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(jnj1['data'][key]['JNJ']['Positive'])
    mini_array.append(jnj1['data'][key]['JNJ']['Neutral'])
    mini_array.append(jnj1['data'][key]['JNJ']['Negative'])
    mini_array.append(jnj1['data'][key]['JNJ']['sentiment_score'])
    jnj_list1.append(mini_array)
jnj_list1
# Out:
# [['2021-07-15', 0, 2, 11, -1.115],
#  ['2021-07-14', 3, 2, 0, 1.3],
#  ['2021-07-13', 3, 2, 6, -0.227],
#  ['2021-07-12', 2, 0, 6, -0.75],
#  ['2021-07-09', 1, 0, 0, 1.5],
#  ['2021-07-08', 1, 0, 1, 0],
#  ['2021-07-07', 1, 0, 0, 1.5],
#  ['2021-07-06', 3, 1, 0, 1.375],
#  ['2021-07-05', 1, 0, 0, 1.5],
#  ['2021-07-02', 8, 2, 1, 1.136],
#  ['2021-07-01', 2, 2, 0, 1.25],
#  ['2021-06-30', 3, 1, 0, 1.375],
#  ['2021-06-29', 4, 2, 1, 0.929],
#  ['2021-06-28', 1, 1, 1, 0.333],
#  ['2021-06-27', 2, 0, 1, 0.5],
#  ['2021-06-26', 0, 1, 5, -1.083],
#  ['2021-06-25', 2, 0, 0, 1.5],
#  ['2021-06-24', 1, 0, 0, 1.5],
#  ['2021-06-23', 0, 1, 0, 1],
#  ['2021-06-22', 1, 0, 0, 1.5],
#  ['2021-06-21', 1, 0, 0, 1.5],
#  ['2021-06-20', 1, 2, 0, 1.167],
#  ['2021-06-19', 0, 1, 0, 1],
#  ['2021-06-16', 0, 0, 1, -1.5],
#  ['2021-06-15', 0, 1, 0, 1],
#  ['2021-06-14', 2, 0, 1, 0.5],
#  ['2021-06-13', 3, 0, 0, 1.5],
#  ['2021-06-11', 2, 0, 5, -0.643],
#  ['2021-06-10', 1, 0, 0, 1.5],
# ...

# %%
jnj2['data'].keys()
datas = jnj2['data'].keys()
jnj_list2 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(jnj2['data'][key]['JNJ']['Positive'])
    mini_array.append(jnj2['data'][key]['JNJ']['Neutral'])
    mini_array.append(jnj2['data'][key]['JNJ']['Negative'])
    mini_array.append(jnj2['data'][key]['JNJ']['sentiment_score'])
    jnj_list2.append(mini_array)
jnj_list2
# Out:
# [['2021-05-18', 3, 1, 1, 0.8],
#  ['2021-05-17', 2, 2, 0, 1.25],
#  ['2021-05-15', 2, 0, 0, 1.5],
#  ['2021-05-13', 0, 1, 0, 1],
#  ['2021-05-12', 0, 1, 2, -0.667],
#  ['2021-05-11', 1, 3, 0, 1.125],
#  ['2021-05-10', 2, 0, 2, 0],
#  ['2021-05-07', 0, 0, 2, -1.5],
#  ['2021-05-06', 2, 2, 3, 0.071],
#  ['2021-05-05', 2, 0, 2, 0],
#  ['2021-05-04', 3, 1, 0, 1.375],
#  ['2021-05-03', 2, 1, 2, 0.2],
#  ['2021-05-01', 1, 0, 0, 1.5],
#  ['2021-04-29', 1, 1, 0, 1.25],
#  ['2021-04-28', 4, 0, 0, 1.5],
#  ['2021-04-27', 1, 1, 1, 0.333],
#  ['2021-04-26', 3, 3, 2, 0.563],
#  ['2021-04-25', 0, 0, 2, -1.5],
#  ['2021-04-24', 1, 0, 1, 0],
#  ['2021-04-23', 17, 9, 1, 1.222],
#  ['2021-04-22', 1, 1, 1, 0.333],
#  ['2021-04-21', 6, 4, 9, -0.026],
#  ['2021-04-20', 21, 6, 9, 0.667],
#  ['2021-04-19', 4, 5, 3, 0.542],
#  ['2021-04-18', 1, 3, 1, 0.6],
#  ['2021-04-17', 0, 0, 1, -1.5],
#  ['2021-04-16', 2, 2, 5, -0.278],
#  ['2021-04-15', 3, 0, 3, 0],
#  ['2021-04-14', 3, 10, 9, 0.045],
# ...

# %%
jnj3['data'].keys()
datas = jnj3['data'].keys()
jnj_list3 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(jnj3['data'][key]['JNJ']['Positive'])
    mini_array.append(jnj3['data'][key]['JNJ']['Neutral'])
    mini_array.append(jnj3['data'][key]['JNJ']['Negative'])
    mini_array.append(jnj3['data'][key]['JNJ']['sentiment_score'])
    jnj_list3.append(mini_array)
jnj_list3
# Out:
# [['2021-03-21', 1, 1, 0, 1.25],
#  ['2021-03-19', 1, 0, 0, 1.5],
#  ['2021-03-18', 1, 0, 0, 1.5],
#  ['2021-03-17', 2, 1, 0, 1.333],
#  ['2021-03-16', 3, 0, 0, 1.5],
#  ['2021-03-15', 2, 0, 0, 1.5],
#  ['2021-03-13', 1, 1, 0, 1.25],
#  ['2021-03-12', 6, 3, 0, 1.333],
#  ['2021-03-11', 7, 2, 1, 1.1],
#  ['2021-03-10', 11, 4, 1, 1.188],
#  ['2021-03-09', 1, 0, 1, 0],
#  ['2021-03-08', 3, 1, 0, 1.375],
#  ['2021-03-07', 0, 1, 0, 1],
#  ['2021-03-06', 1, 1, 0, 1.25],
#  ['2021-03-05', 5, 2, 0, 1.357],
#  ['2021-03-04', 2, 1, 1, 0.625],
#  ['2021-03-03', 6, 3, 0, 1.333],
#  ['2021-03-02', 19, 5, 0, 1.396],
#  ['2021-03-01', 30, 3, 0, 1.455],
#  ['2021-02-28', 6, 3, 0, 1.333],
#  ['2021-02-27', 9, 1, 0, 1.45],
#  ['2021-02-26', 20, 5, 0, 1.4],
#  ['2021-02-25', 4, 0, 1, 0.9],
#  ['2021-02-24', 17, 4, 0, 1.405],
#  ['2021-02-23', 1, 3, 2, 0.25],
#  ['2021-02-22', 0, 6, 1, 0.643],
#  ['2021-02-21', 1, 0, 0, 1.5],
#  ['2021-02-20', 0, 2, 0, 1],
#  ['2021-02-19', 1, 3, 0, 1.125],
# ...

# %%
jnj4['data'].keys()
datas = jnj4['data'].keys()
jnj_list4 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(jnj4['data'][key]['JNJ']['Positive'])
    mini_array.append(jnj4['data'][key]['JNJ']['Neutral'])
    mini_array.append(jnj4['data'][key]['JNJ']['Negative'])
    mini_array.append(jnj4['data'][key]['JNJ']['sentiment_score'])
    jnj_list4.append(mini_array)
jnj_list4
# Out:
# [['2021-01-26', 21, 5, 0, 1.404],
#  ['2021-01-25', 4, 2, 1, 0.929],
#  ['2021-01-24', 1, 1, 0, 1.25],
#  ['2021-01-23', 1, 0, 0, 1.5],
#  ['2021-01-22', 8, 1, 0, 1.444],
#  ['2021-01-21', 5, 1, 0, 1.417],
#  ['2021-01-20', 2, 1, 0, 1.333],
#  ['2021-01-19', 4, 1, 0, 1.4],
#  ['2021-01-18', 2, 0, 0, 1.5],
#  ['2021-01-17', 1, 0, 0, 1.5],
#  ['2021-01-16', 1, 0, 0, 1.5],
#  ['2021-01-14', 8, 0, 0, 1.5],
#  ['2021-01-13', 4, 0, 3, 0.214],
#  ['2021-01-12', 2, 1, 0, 1.333],
#  ['2021-01-11', 3, 4, 0, 1.214],
#  ['2021-01-06', 1, 0, 0, 1.5],
#  ['2021-01-05', 3, 1, 0, 1.375],
#  ['2021-01-04', 1, 0, 0, 1.5],
#  ['2021-01-03', 0, 1, 0, 1],
#  ['2021-01-02', 3, 0, 0, 1.5],
#  ['2020-12-31', 2, 0, 0, 1.5],
#  ['2020-12-29', 1, 0, 0, 1.5],
#  ['2020-12-28', 1, 0, 0, 1.5],
#  ['2020-12-27', 3, 0, 0, 1.5],
#  ['2020-12-25', 1, 0, 0, 1.5],
#  ['2020-12-23', 1, 1, 1, 0.333],
#  ['2020-12-22', 0, 3, 0, 1],
#  ['2020-12-20', 1, 0, 0, 1.5],
#  ['2020-12-19', 2, 0, 0, 1.5],
# ...

# %%
jnj5['data'].keys()
datas = jnj5['data'].keys()
jnj_list5 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(jnj5['data'][key]['JNJ']['Positive'])
    mini_array.append(jnj5['data'][key]['JNJ']['Neutral'])
    mini_array.append(jnj5['data'][key]['JNJ']['Negative'])
    mini_array.append(jnj5['data'][key]['JNJ']['sentiment_score'])
    jnj_list5.append(mini_array)
jnj_list5
# Out:
# [['2020-11-22', 1, 0, 0, 1.5],
#  ['2020-11-21', 1, 0, 0, 1.5],
#  ['2020-11-20', 3, 2, 3, 0.25],
#  ['2020-11-19', 1, 3, 0, 1.125],
#  ['2020-11-18', 1, 1, 0, 1.25],
#  ['2020-11-17', 4, 1, 0, 1.4],
#  ['2020-11-16', 2, 0, 0, 1.5],
#  ['2020-11-15', 1, 2, 0, 1.167],
#  ['2020-11-14', 2, 2, 0, 1.25],
#  ['2020-11-13', 1, 0, 1, 0],
#  ['2020-11-12', 1, 0, 1, 0],
#  ['2020-11-11', 1, 1, 1, 0.333],
#  ['2020-11-10', 1, 0, 0, 1.5],
#  ['2020-11-09', 1, 1, 0, 1.25],
#  ['2020-11-08', 0, 1, 0, 1],
#  ['2020-11-07', 2, 0, 0, 1.5],
#  ['2020-11-06', 1, 0, 0, 1.5],
#  ['2020-11-05', 1, 0, 0, 1.5],
#  ['2020-11-04', 4, 0, 0, 1.5],
#  ['2020-11-03', 3, 0, 1, 0.75],
#  ['2020-11-02', 5, 1, 1, 1],
#  ['2020-11-01', 2, 1, 0, 1.333],
#  ['2020-10-30', 1, 0, 0, 1.5],
#  ['2020-10-29', 1, 2, 0, 1.167],
#  ['2020-10-28', 1, 2, 0, 1.167],
#  ['2020-10-27', 3, 1, 0, 1.375],
#  ['2020-10-26', 3, 1, 0, 1.375],
#  ['2020-10-25', 2, 1, 0, 1.333],
#  ['2020-10-24', 2, 1, 0, 1.333],
# ...

# %%
jnj6['data'].keys()
datas = jnj6['data'].keys()
jnj_list6 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(jnj6['data'][key]['JNJ']['Positive'])
    mini_array.append(jnj6['data'][key]['JNJ']['Neutral'])
    mini_array.append(jnj6['data'][key]['JNJ']['Negative'])
    mini_array.append(jnj6['data'][key]['JNJ']['sentiment_score'])
    jnj_list6.append(mini_array)
jnj_list6
# Out:
# [['2020-09-30', 2, 0, 0, 1.5],
#  ['2020-09-29', 1, 0, 0, 1.5],
#  ['2020-09-26', 0, 1, 0, 1],
#  ['2020-09-25', 1, 3, 0, 1.125],
#  ['2020-09-24', 1, 4, 0, 1.1],
#  ['2020-09-23', 15, 4, 1, 1.25],
#  ['2020-09-21', 0, 1, 0, 1],
#  ['2020-09-20', 2, 0, 0, 1.5],
#  ['2020-09-18', 3, 0, 0, 1.5],
#  ['2020-09-17', 1, 1, 4, -0.583],
#  ['2020-09-16', 1, 1, 0, 1.25],
#  ['2020-09-15', 2, 0, 0, 1.5],
#  ['2020-09-14', 2, 0, 0, 1.5],
#  ['2020-09-13', 0, 1, 0, 1],
#  ['2020-09-11', 1, 0, 2, -0.5],
#  ['2020-09-10', 3, 0, 0, 1.5],
#  ['2020-09-09', 1, 3, 0, 1.125],
#  ['2020-09-08', 3, 3, 0, 1.25],
#  ['2020-09-07', 0, 1, 0, 1],
#  ['2020-09-06', 2, 0, 0, 1.5],
#  ['2020-09-05', 1, 1, 0, 1.25],
#  ['2020-09-04', 3, 2, 0, 1.3],
#  ['2020-09-03', 3, 3, 0, 1.25],
#  ['2020-09-02', 1, 1, 1, 0.333],
#  ['2020-08-31', 3, 0, 1, 0.75],
#  ['2020-08-30', 1, 2, 0, 1.167],
#  ['2020-08-27', 0, 1, 0, 1],
#  ['2020-08-25', 1, 0, 0, 1.5],
#  ['2020-08-24', 3, 0, 0, 1.5],
#  ['2020-08-22', 1, 1, 0, 1.25],
# ...

# %%
jnj7['data'].keys()
datas = jnj7['data'].keys()
jnj_list7 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(jnj7['data'][key]['JNJ']['Positive'])
    mini_array.append(jnj7['data'][key]['JNJ']['Neutral'])
    mini_array.append(jnj7['data'][key]['JNJ']['Negative'])
    mini_array.append(jnj7['data'][key]['JNJ']['sentiment_score'])
    jnj_list7.append(mini_array)
jnj_list7
# Out:
# [['2020-07-23', 3, 1, 0, 1.375],
#  ['2020-07-22', 0, 2, 0, 1],
#  ['2020-07-21', 0, 2, 0, 1],
#  ['2020-07-20', 2, 1, 0, 1.333],
#  ['2020-07-19', 1, 0, 0, 1.5],
#  ['2020-07-18', 1, 0, 0, 1.5],
#  ['2020-07-17', 4, 2, 0, 1.333],
#  ['2020-07-16', 14, 5, 4, 0.87],
#  ['2020-07-15', 3, 2, 0, 1.3],
#  ['2020-07-14', 3, 3, 0, 1.25],
#  ['2020-07-13', 0, 1, 0, 1],
#  ['2020-07-12', 0, 1, 0, 1],
#  ['2020-07-11', 0, 2, 0, 1],
#  ['2020-07-09', 0, 2, 0, 1],
#  ['2020-07-08', 1, 2, 1, 0.5],
#  ['2020-07-07', 0, 3, 0, 1],
#  ['2020-07-06', 2, 3, 1, 0.75],
#  ['2020-07-04', 1, 0, 0, 1.5],
#  ['2020-07-03', 0, 2, 0, 1],
#  ['2020-07-02', 1, 0, 1, 0],
#  ['2020-07-01', 0, 2, 0, 1],
#  ['2020-06-30', 1, 1, 0, 1.25],
#  ['2020-06-29', 2, 1, 0, 1.333],
#  ['2020-06-28', 0, 1, 0, 1],
#  ['2020-06-27', 1, 0, 0, 1.5],
#  ['2020-06-26', 0, 1, 0, 1],
#  ['2020-06-25', 1, 1, 0, 1.25],
#  ['2020-06-24', 1, 0, 2, -0.5],
#  ['2020-06-23', 0, 0, 3, -1.5],
#  ['2020-06-20', 0, 1, 0, 1],
# ...

# %%
jnj8['data'].keys()
datas = jnj8['data'].keys()
jnj_list8 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(jnj8['data'][key]['JNJ']['Positive'])
    mini_array.append(jnj8['data'][key]['JNJ']['Neutral'])
    mini_array.append(jnj8['data'][key]['JNJ']['Negative'])
    mini_array.append(jnj8['data'][key]['JNJ']['sentiment_score'])
    jnj_list8.append(mini_array)
jnj_list8
# Out:
# [['2020-05-19', 1, 3, 5, -0.333],
#  ['2020-05-18', 0, 1, 0, 1],
#  ['2020-05-16', 0, 1, 0, 1],
#  ['2020-05-15', 1, 1, 1, 0.333],
#  ['2020-05-14', 0, 1, 1, -0.25],
#  ['2020-05-12', 1, 0, 0, 1.5],
#  ['2020-05-11', 2, 0, 0, 1.5],
#  ['2020-05-10', 1, 1, 0, 1.25],
#  ['2020-05-08', 2, 0, 0, 1.5],
#  ['2020-05-07', 1, 0, 0, 1.5],
#  ['2020-05-06', 2, 0, 0, 1.5],
#  ['2020-05-05', 1, 1, 0, 1.25],
#  ['2020-05-04', 1, 0, 0, 1.5],
#  ['2020-05-02', 1, 0, 0, 1.5],
#  ['2020-05-01', 2, 0, 0, 1.5],
#  ['2020-04-30', 3, 0, 0, 1.5],
#  ['2020-04-29', 2, 0, 1, 0.5],
#  ['2020-04-28', 1, 3, 0, 1.125],
#  ['2020-04-27', 1, 0, 2, -0.5],
#  ['2020-04-26', 0, 1, 0, 1],
#  ['2020-04-25', 1, 0, 0, 1.5],
#  ['2020-04-24', 1, 1, 0, 1.25],
#  ['2020-04-23', 1, 2, 0, 1.167],
#  ['2020-04-22', 4, 2, 0, 1.333],
#  ['2020-04-21', 2, 0, 0, 1.5],
#  ['2020-04-20', 2, 0, 0, 1.5],
#  ['2020-04-19', 2, 0, 0, 1.5],
#  ['2020-04-17', 2, 0, 0, 1.5],
#  ['2020-04-16', 5, 0, 0, 1.5],
# ...

# %%
jnj9['data'].keys()
datas = jnj9['data'].keys()
jnj_list9 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(jnj9['data'][key]['JNJ']['Positive'])
    mini_array.append(jnj9['data'][key]['JNJ']['Neutral'])
    mini_array.append(jnj9['data'][key]['JNJ']['Negative'])
    mini_array.append(jnj9['data'][key]['JNJ']['sentiment_score'])
    jnj_list9.append(mini_array)
jnj_list9
# Out:
# [['2020-03-23', 2, 1, 0, 1.333],
#  ['2020-03-21', 1, 0, 0, 1.5],
#  ['2020-03-20', 1, 0, 0, 1.5],
#  ['2020-03-19', 1, 2, 0, 1.167],
#  ['2020-03-18', 3, 2, 0, 1.3],
#  ['2020-03-17', 1, 4, 0, 1.1],
#  ['2020-03-16', 3, 4, 0, 1.214],
#  ['2020-03-15', 1, 0, 0, 1.5],
#  ['2020-03-13', 2, 0, 0, 1.5],
#  ['2020-03-12', 1, 1, 0, 1.25],
#  ['2020-03-11', 1, 0, 0, 1.5],
#  ['2020-03-10', 3, 2, 0, 1.3],
#  ['2020-03-09', 0, 2, 1, 0.167],
#  ['2020-03-07', 1, 0, 0, 1.5],
#  ['2020-03-06', 0, 3, 0, 1],
#  ['2020-03-05', 2, 2, 0, 1.25],
#  ['2020-03-04', 1, 1, 0, 1.25],
#  ['2020-03-03', 0, 2, 1, 0.167],
#  ['2020-03-02', 0, 3, 0, 1],
#  ['2020-02-29', 1, 1, 0, 1.25],
#  ['2020-02-28', 2, 1, 0, 1.333],
#  ['2020-02-26', 2, 0, 0, 1.5],
#  ['2020-02-25', 4, 0, 0, 1.5],
#  ['2020-02-24', 1, 1, 0, 1.25],
#  ['2020-02-21', 0, 0, 1, -1.5],
#  ['2020-02-20', 1, 0, 0, 1.5],
#  ['2020-02-19', 1, 0, 0, 1.5],
#  ['2020-02-18', 1, 0, 0, 1.5],
#  ['2020-02-17', 0, 1, 0, 1],
# ...

# %%
jnj10['data'].keys()
datas = jnj10['data'].keys()
jnj_list10 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(jnj10['data'][key]['JNJ']['Positive'])
    mini_array.append(jnj10['data'][key]['JNJ']['Neutral'])
    mini_array.append(jnj10['data'][key]['JNJ']['Negative'])
    mini_array.append(jnj10['data'][key]['JNJ']['sentiment_score'])
    jnj_list10.append(mini_array)
jnj_list10
# Out:
# [['2020-01-19', 0, 1, 0, 1],
#  ['2020-01-17', 1, 1, 1, 0.333],
#  ['2020-01-16', 3, 0, 0, 1.5],
#  ['2020-01-15', 2, 1, 0, 1.333],
#  ['2020-01-14', 1, 0, 1, 0],
#  ['2020-01-13', 0, 1, 0, 1],
#  ['2020-01-11', 0, 1, 0, 1],
#  ['2020-01-10', 1, 2, 0, 1.167],
#  ['2020-01-08', 1, 2, 0, 1.167],
#  ['2020-01-07', 1, 0, 1, 0],
#  ['2020-01-06', 0, 1, 0, 1],
#  ['2020-01-05', 1, 0, 0, 1.5],
#  ['2020-01-03', 2, 1, 1, 0.625],
#  ['2020-01-02', 1, 0, 0, 1.5],
#  ['2019-12-31', 2, 0, 0, 1.5],
#  ['2019-12-30', 0, 2, 0, 1],
#  ['2019-12-28', 1, 1, 0, 1.25],
#  ['2019-12-27', 3, 0, 0, 1.5],
#  ['2019-12-26', 0, 1, 0, 1],
#  ['2019-12-23', 1, 0, 0, 1.5],
#  ['2019-12-22', 1, 1, 0, 1.25],
#  ['2019-12-20', 3, 0, 0, 1.5],
#  ['2019-12-19', 1, 0, 0, 1.5],
#  ['2019-12-18', 1, 0, 0, 1.5],
#  ['2019-12-17', 2, 1, 0, 1.333],
#  ['2019-12-16', 1, 0, 0, 1.5],
#  ['2019-12-13', 1, 0, 0, 1.5],
#  ['2019-12-11', 1, 0, 0, 1.5],
#  ['2019-12-09', 3, 2, 2, 0.5],
#  ['2019-12-06', 2, 0, 0, 1.5],
# ...

# %%
jnj11['data'].keys()
datas = jnj11['data'].keys()
jnj_list11 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(jnj11['data'][key]['JNJ']['Positive'])
    mini_array.append(jnj11['data'][key]['JNJ']['Neutral'])
    mini_array.append(jnj11['data'][key]['JNJ']['Negative'])
    mini_array.append(jnj11['data'][key]['JNJ']['sentiment_score'])
    jnj_list11.append(mini_array)
jnj_list11
# Out:
# [['2019-10-31', 3, 0, 0, 1.5],
#  ['2019-10-30', 4, 1, 1, 0.917],
#  ['2019-10-29', 5, 1, 0, 1.417],
#  ['2019-10-28', 1, 0, 2, -0.5],
#  ['2019-10-25', 0, 4, 0, 1],
#  ['2019-10-24', 0, 3, 1, 0.375],
#  ['2019-10-23', 2, 3, 1, 0.75],
#  ['2019-10-22', 3, 0, 2, 0.3],
#  ['2019-10-21', 3, 1, 3, 0.143],
#  ['2019-10-18', 3, 3, 7, -0.231],
#  ['2019-10-17', 1, 1, 2, -0.125],
#  ['2019-10-16', 3, 0, 1, 0.75],
#  ['2019-10-15', 20, 5, 0, 1.4],
#  ['2019-10-14', 2, 4, 1, 0.786],
#  ['2019-10-12', 0, 1, 0, 1],
#  ['2019-10-11', 2, 0, 1, 0.5],
#  ['2019-10-10', 1, 1, 1, 0.333],
#  ['2019-10-09', 0, 1, 7, -1.188],
#  ['2019-10-08', 1, 1, 2, -0.125],
#  ['2019-10-07', 0, 1, 0, 1],
#  ['2019-10-05', 2, 1, 0, 1.333],
#  ['2019-10-04', 3, 0, 0, 1.5],
#  ['2019-10-03', 2, 1, 0, 1.333],
#  ['2019-10-02', 3, 1, 0, 1.375],
#  ['2019-10-01', 3, 2, 2, 0.5],
#  ['2019-09-30', 2, 1, 0, 1.333],
#  ['2019-09-27', 1, 0, 0, 1.5],
#  ['2019-09-26', 1, 0, 0, 1.5],
#  ['2019-09-24', 0, 3, 1, 0.375],
# ...

# %%
jnj12['data'].keys()
datas = jnj12['data'].keys()
jnj_list12 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(jnj12['data'][key]['JNJ']['Positive'])
    mini_array.append(jnj12['data'][key]['JNJ']['Neutral'])
    mini_array.append(jnj12['data'][key]['JNJ']['Negative'])
    mini_array.append(jnj12['data'][key]['JNJ']['sentiment_score'])
    jnj_list12.append(mini_array)
jnj_list12
# Out:
# [['2019-08-21', 0, 3, 0, 1],
#  ['2019-08-20', 1, 0, 0, 1.5],
#  ['2019-08-19', 0, 1, 0, 1],
#  ['2019-08-15', 0, 0, 1, -1.5],
#  ['2019-08-14', 2, 0, 0, 1.5],
#  ['2019-08-13', 2, 0, 0, 1.5],
#  ['2019-08-12', 1, 0, 0, 1.5],
#  ['2019-08-06', 1, 0, 0, 1.5],
#  ['2019-08-04', 1, 0, 0, 1.5],
#  ['2019-08-02', 2, 0, 0, 1.5],
#  ['2019-07-29', 2, 1, 1, 0.625],
#  ['2019-07-27', 2, 0, 0, 1.5],
#  ['2019-07-24', 2, 0, 2, 0],
#  ['2019-07-23', 1, 0, 0, 1.5],
#  ['2019-07-22', 2, 1, 3, -0.083],
#  ['2019-07-19', 0, 0, 1, -1.5],
#  ['2019-07-18', 1, 1, 0, 1.25],
#  ['2019-07-17', 0, 1, 0, 1],
#  ['2019-07-16', 17, 6, 3, 1.038],
#  ['2019-07-15', 3, 2, 5, -0.1],
#  ['2019-07-14', 0, 1, 0, 1],
#  ['2019-07-12', 3, 0, 13, -0.938],
#  ['2019-07-11', 0, 1, 0, 1],
#  ['2019-07-10', 2, 0, 0, 1.5],
#  ['2019-07-09', 2, 0, 0, 1.5],
#  ['2019-07-08', 0, 0, 1, -1.5],
#  ['2019-07-07', 0, 1, 0, 1],
#  ['2019-07-05', 1, 1, 1, 0.333],
#  ['2019-07-03', 1, 0, 0, 1.5],
#  ['2019-07-01', 1, 0, 0, 1.5],
# ...

# %%
jnj13['data'].keys()
datas = jnj13['data'].keys()
jnj_list13 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(jnj13['data'][key]['JNJ']['Positive'])
    mini_array.append(jnj13['data'][key]['JNJ']['Neutral'])
    mini_array.append(jnj13['data'][key]['JNJ']['Negative'])
    mini_array.append(jnj13['data'][key]['JNJ']['sentiment_score'])
    jnj_list13.append(mini_array)
jnj_list13
# Out:
# [['2019-05-29', 1, 1, 4, -0.583],
#  ['2019-05-28', 3, 1, 2, 0.417],
#  ['2019-05-27', 1, 0, 0, 1.5],
#  ['2019-05-23', 5, 1, 0, 1.417],
#  ['2019-05-18', 1, 0, 0, 1.5],
#  ['2019-05-17', 1, 1, 1, 0.333],
#  ['2019-05-16', 1, 0, 0, 1.5],
#  ['2019-05-15', 3, 0, 0, 1.5],
#  ['2019-05-14', 0, 1, 0, 1],
#  ['2019-05-08', 0, 1, 0, 1],
#  ['2019-05-07', 1, 0, 1, 0],
#  ['2019-05-05', 0, 1, 0, 1],
#  ['2019-05-02', 1, 0, 0, 1.5],
#  ['2019-04-30', 1, 0, 1, 0],
#  ['2019-04-29', 2, 0, 0, 1.5],
#  ['2019-04-28', 1, 0, 0, 1.5],
#  ['2019-04-26', 1, 0, 0, 1.5],
#  ['2019-04-25', 2, 0, 0, 1.5],
#  ['2019-04-24', 1, 1, 0, 1.25],
#  ['2019-04-22', 1, 0, 0, 1.5],
#  ['2019-04-18', 1, 0, 0, 1.5],
#  ['2019-04-17', 1, 2, 0, 1.167],
#  ['2019-04-16', 13, 1, 1, 1.267],
#  ['2019-04-15', 2, 0, 0, 1.5],
#  ['2019-04-14', 0, 1, 0, 1],
#  ['2019-04-12', 2, 0, 0, 1.5],
#  ['2019-04-11', 1, 0, 0, 1.5],
#  ['2019-04-09', 0, 1, 2, -0.667],
#  ['2019-04-08', 2, 0, 0, 1.5],
#  ['2019-04-07', 0, 1, 0, 1],
# ...

# %%
jnj_list = jnj_list1 + jnj_list2 + jnj_list3 + jnj_list4 + jnj_list5 + jnj_list6 + jnj_list7 + jnj_list8 + jnj_list9 + jnj_list10 + jnj_list11 + jnj_list12 + jnj_list13

# %%
# # my_dict = json.load(json_file)
jnj_df = pd.DataFrame(jnj_list)
jnj_df.shape
# Out:
# (582, 5)

# %%
jnj_df.to_csv('jnj_df.csv')

# %%
jnj_df
# Out:
#               0  1  2  3      4
# 0    2021-05-18  3  1  1  0.800
# 1    2021-05-17  2  2  0  1.250
# 2    2021-05-15  2  0  0  1.500
# 3    2021-05-13  0  1  0  1.000
# 4    2021-05-12  0  1  2 -0.667
# ..          ... .. .. ..    ...
# 577  2019-04-09  0  1  2 -0.667
# 578  2019-04-08  2  0  0  1.500
# 579  2019-04-07  0  1  0  1.000
# 580  2019-04-06  0  1  0  1.000
# 581  2019-04-01  1  0  0  1.500
#
# [582 rows x 5 columns]
