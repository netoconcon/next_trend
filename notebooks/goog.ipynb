# %%
import matplotlib
# %matplotlib inline
import numpy as np
import pandas as pd
import json

# %%
import requests

# %%
url = "https://stocknewsapi.com/api/v1/stat?&tickers=GOOG&date=04012019-07152021&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"

# %%
url
# Out:
# 'https://stocknewsapi.com/api/v1/stat?&tickers=GOOG&date=04012019-07152021&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit'

# %%
response = requests.get(url)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data

goog1 = data
goog1
# Out:
# {'total': {'GOOG': {'Total Positive': 2915,
#    'Total Negative': 2154,
#    'Total Neutral': 2514,
#    'Sentiment Score': 0.482}},
#  'data': {'2021-07-15': {'GOOG': {'Neutral': 2,
#     'Positive': 2,
#     'Negative': 2,
#     'sentiment_score': 0.333}},
#   '2021-07-14': {'GOOG': {'Neutral': 0,
#     'Positive': 2,
#     'Negative': 0,
#     'sentiment_score': 1.5}},
#   '2021-07-13': {'GOOG': {'Neutral': 1,
#     'Positive': 4,
#     'Negative': 18,
#     'sentiment_score': -0.87}},
#   '2021-07-12': {'GOOG': {'Neutral': 0,
#     'Positive': 3,
#     'Negative': 3,
#     'sentiment_score': 0}},
#   '2021-07-10': {'GOOG': {'Neutral': 0,
#     'Positive': 1,
#     'Negative': 1,
#     'sentiment_score': 0}},
#   '2021-07-09': {'GOOG': {'Neutral': 2,
#     'Positive': 3,
#     'Negative': 13,
#     'sentiment_score': -0.722}},
#   '2021-07-08': {'GOOG': {'Neutral': 1,
#     'Positive': 7,
#     'Negative': 11,
#     'sentiment_score': -0.263}},
# ...

# %%
url_2 = "https://stocknewsapi.com/api/v1/stat?&tickers=GOOG&date=04012019-07152021&page=2&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_3 = "https://stocknewsapi.com/api/v1/stat?&tickers=GOOG&date=04012019-07152021&page=3&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_4 = "https://stocknewsapi.com/api/v1/stat?&tickers=GOOG&date=04012019-07152021&page=4&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_5 = "https://stocknewsapi.com/api/v1/stat?&tickers=GOOG&date=04012019-07152021&page=5&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_6 = "https://stocknewsapi.com/api/v1/stat?&tickers=GOOG&date=04012019-07152021&page=6&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_7 = "https://stocknewsapi.com/api/v1/stat?&tickers=GOOG&date=04012019-07152021&page=7&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_8 = "https://stocknewsapi.com/api/v1/stat?&tickers=GOOG&date=04012019-07152021&page=8&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_9 = "https://stocknewsapi.com/api/v1/stat?&tickers=GOOG&date=04012019-07152021&page=9&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_10 = "https://stocknewsapi.com/api/v1/stat?&tickers=GOOG&date=04012019-07152021&page=10&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_11 = "https://stocknewsapi.com/api/v1/stat?&tickers=GOOG&date=04012019-07152021&page=11&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_12 = "https://stocknewsapi.com/api/v1/stat?&tickers=GOOG&date=04012019-07152021&page=12&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_13 = "https://stocknewsapi.com/api/v1/stat?&tickers=GOOG&date=04012019-07152021&page=13&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_14 = "https://stocknewsapi.com/api/v1/stat?&tickers=GOOG&date=04012019-07152021&page=14&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_15 = "https://stocknewsapi.com/api/v1/stat?&tickers=GOOG&date=04012019-07152021&page=15&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_16 = "https://stocknewsapi.com/api/v1/stat?&tickers=GOOG&date=04012019-07152021&page=16&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"

# %%
response = requests.get(url_2)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
goog2 = data

# %%
response = requests.get(url_3)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
goog3 = data

# %%
response = requests.get(url_4)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
goog4 = data

# %%
response = requests.get(url_5)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
goog5 = data

# %%
response = requests.get(url_6)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
goog6 = data

# %%
response = requests.get(url_7)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
goog7 = data

# %%
response = requests.get(url_8)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
goog8 = data

# %%
response = requests.get(url_9)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
goog9 = data

# %%
response = requests.get(url_10)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
goog10 = data

# %%
response = requests.get(url_11)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
goog11 = data

# %%
response = requests.get(url_12)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
goog12 = data

# %%
response = requests.get(url_13)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
goog13 = data

# %%
response = requests.get(url_14)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
goog14 = data

# %%
response = requests.get(url_15)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
goog15 = data

# %%
response = requests.get(url_16)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
goog16 = data

# %%
goog1['data'].keys()
datas = goog1['data'].keys()
goog_list1 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(goog1['data'][key]['GOOG']['Positive'])
    mini_array.append(goog1['data'][key]['GOOG']['Neutral'])
    mini_array.append(goog1['data'][key]['GOOG']['Negative'])
    mini_array.append(goog1['data'][key]['GOOG']['sentiment_score'])
    goog_list1.append(mini_array)
goog_list1
# Out:
# [['2021-07-15', 2, 2, 2, 0.333],
#  ['2021-07-14', 2, 0, 0, 1.5],
#  ['2021-07-13', 4, 1, 18, -0.87],
#  ['2021-07-12', 3, 0, 3, 0],
#  ['2021-07-10', 1, 0, 1, 0],
#  ['2021-07-09', 3, 2, 13, -0.722],
#  ['2021-07-08', 7, 1, 11, -0.263],
#  ['2021-07-07', 1, 0, 14, -1.3],
#  ['2021-07-06', 3, 2, 1, 0.833],
#  ['2021-07-05', 0, 0, 5, -1.5],
#  ['2021-07-04', 0, 1, 0, 1],
#  ['2021-07-03', 1, 0, 0, 1.5],
#  ['2021-07-02', 4, 0, 3, 0.214],
#  ['2021-07-01', 2, 0, 1, 0.5],
#  ['2021-06-30', 0, 6, 3, 0.167],
#  ['2021-06-29', 4, 5, 2, 0.727],
#  ['2021-06-28', 4, 0, 6, -0.3],
#  ['2021-06-27', 1, 0, 0, 1.5],
#  ['2021-06-26', 4, 1, 0, 1.4],
#  ['2021-06-25', 4, 3, 12, -0.474],
#  ['2021-06-24', 2, 5, 4, 0.182],
#  ['2021-06-23', 5, 2, 10, -0.324],
#  ['2021-06-22', 1, 2, 25, -1.214],
#  ['2021-06-21', 6, 2, 2, 0.8],
#  ['2021-06-19', 0, 0, 1, -1.5],
#  ['2021-06-18', 4, 1, 3, 0.313],
#  ['2021-06-17', 6, 6, 3, 0.7],
#  ['2021-06-16', 21, 3, 4, 1.018],
#  ['2021-06-15', 2, 1, 16, -1.053],
# ...

# %%
goog2['data'].keys()
datas = goog2['data'].keys()
goog_list2 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(goog2['data'][key]['GOOG']['Positive'])
    mini_array.append(goog2['data'][key]['GOOG']['Neutral'])
    mini_array.append(goog2['data'][key]['GOOG']['Negative'])
    mini_array.append(goog2['data'][key]['GOOG']['sentiment_score'])
    goog_list2.append(mini_array)
goog_list2
# Out:
# [['2021-05-24', 1, 3, 3, 0],
#  ['2021-05-21', 4, 3, 0, 1.286],
#  ['2021-05-20', 11, 2, 2, 1.033],
#  ['2021-05-19', 4, 5, 0, 1.222],
#  ['2021-05-18', 9, 3, 1, 1.154],
#  ['2021-05-17', 4, 2, 1, 0.929],
#  ['2021-05-16', 1, 0, 0, 1.5],
#  ['2021-05-14', 4, 1, 3, 0.313],
#  ['2021-05-13', 10, 0, 6, 0.375],
#  ['2021-05-12', 5, 4, 0, 1.278],
#  ['2021-05-11', 12, 0, 0, 1.5],
#  ['2021-05-10', 1, 1, 3, -0.4],
#  ['2021-05-09', 1, 1, 0, 1.25],
#  ['2021-05-08', 1, 0, 0, 1.5],
#  ['2021-05-07', 1, 2, 1, 0.5],
#  ['2021-05-06', 4, 2, 2, 0.625],
#  ['2021-05-05', 6, 0, 1, 1.071],
#  ['2021-05-04', 4, 3, 2, 0.667],
#  ['2021-05-03', 4, 3, 0, 1.286],
#  ['2021-05-02', 1, 0, 0, 1.5],
#  ['2021-04-30', 8, 2, 8, 0.111],
#  ['2021-04-29', 5, 3, 1, 1],
#  ['2021-04-28', 15, 9, 2, 1.096],
#  ['2021-04-27', 27, 6, 4, 1.095],
#  ['2021-04-26', 4, 4, 9, -0.206],
#  ['2021-04-25', 1, 1, 0, 1.25],
#  ['2021-04-24', 1, 0, 0, 1.5],
#  ['2021-04-23', 4, 4, 1, 0.944],
#  ['2021-04-22', 2, 2, 3, 0.071],
# ...

# %%
goog3['data'].keys()
datas = goog3['data'].keys()
goog_list3 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(goog3['data'][key]['GOOG']['Positive'])
    mini_array.append(goog3['data'][key]['GOOG']['Neutral'])
    mini_array.append(goog3['data'][key]['GOOG']['Negative'])
    mini_array.append(goog3['data'][key]['GOOG']['sentiment_score'])
    goog_list3.append(mini_array)
goog_list3
# Out:
# [['2021-03-29', 10, 0, 0, 1.5],
#  ['2021-03-28', 0, 1, 0, 1],
#  ['2021-03-26', 2, 0, 1, 0.5],
#  ['2021-03-25', 3, 10, 9, 0.045],
#  ['2021-03-24', 2, 9, 0, 1.091],
#  ['2021-03-23', 2, 2, 0, 1.25],
#  ['2021-03-22', 2, 5, 1, 0.813],
#  ['2021-03-21', 0, 0, 3, -1.5],
#  ['2021-03-20', 0, 2, 0, 1],
#  ['2021-03-19', 4, 2, 1, 0.929],
#  ['2021-03-18', 12, 1, 3, 0.906],
#  ['2021-03-17', 1, 2, 0, 1.167],
#  ['2021-03-16', 3, 9, 2, 0.75],
#  ['2021-03-15', 0, 1, 0, 1],
#  ['2021-03-14', 0, 0, 2, -1.5],
#  ['2021-03-12', 3, 3, 7, -0.231],
#  ['2021-03-11', 0, 1, 1, -0.25],
#  ['2021-03-10', 3, 1, 6, -0.35],
#  ['2021-03-09', 2, 2, 0, 1.25],
#  ['2021-03-08', 4, 0, 1, 0.9],
#  ['2021-03-06', 1, 1, 0, 1.25],
#  ['2021-03-05', 3, 0, 0, 1.5],
#  ['2021-03-04', 0, 6, 3, 0.167],
#  ['2021-03-03', 0, 8, 1, 0.722],
#  ['2021-03-02', 5, 2, 1, 1],
#  ['2021-03-01', 2, 2, 1, 0.7],
#  ['2021-02-27', 0, 1, 0, 1],
#  ['2021-02-26', 1, 0, 0, 1.5],
#  ['2021-02-25', 3, 3, 3, 0.333],
# ...

# %%
goog4['data'].keys()
datas = goog4['data'].keys()
goog_list4 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(goog4['data'][key]['GOOG']['Positive'])
    mini_array.append(goog4['data'][key]['GOOG']['Neutral'])
    mini_array.append(goog4['data'][key]['GOOG']['Negative'])
    mini_array.append(goog4['data'][key]['GOOG']['sentiment_score'])
    goog_list4.append(mini_array)
goog_list4
# Out:
# [['2021-02-01', 13, 12, 11, 0.417],
#  ['2021-01-31', 0, 3, 0, 1],
#  ['2021-01-29', 2, 5, 1, 0.813],
#  ['2021-01-28', 1, 2, 2, 0.1],
#  ['2021-01-27', 4, 3, 3, 0.45],
#  ['2021-01-26', 6, 9, 3, 0.75],
#  ['2021-01-25', 8, 6, 2, 0.938],
#  ['2021-01-24', 0, 2, 1, 0.167],
#  ['2021-01-23', 1, 0, 2, -0.5],
#  ['2021-01-22', 3, 3, 20, -0.865],
#  ['2021-01-21', 5, 5, 12, -0.25],
#  ['2021-01-20', 5, 0, 6, -0.136],
#  ['2021-01-19', 4, 2, 2, 0.625],
#  ['2021-01-18', 0, 2, 1, 0.167],
#  ['2021-01-17', 1, 0, 1, 0],
#  ['2021-01-16', 1, 0, 0, 1.5],
#  ['2021-01-15', 2, 0, 4, -0.5],
#  ['2021-01-14', 6, 1, 3, 0.55],
#  ['2021-01-13', 2, 5, 2, 0.556],
#  ['2021-01-12', 5, 0, 5, 0],
#  ['2021-01-11', 6, 1, 7, -0.036],
#  ['2021-01-10', 0, 0, 1, -1.5],
#  ['2021-01-09', 0, 1, 0, 1],
#  ['2021-01-08', 1, 1, 7, -0.889],
#  ['2021-01-07', 1, 1, 3, -0.4],
#  ['2021-01-06', 2, 3, 8, -0.462],
#  ['2021-01-05', 6, 2, 1, 1.056],
#  ['2021-01-04', 2, 20, 1, 0.935],
#  ['2021-01-03', 1, 0, 0, 1.5],
# ...

# %%
goog5['data'].keys()
datas = goog5['data'].keys()
goog_list5 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(goog5['data'][key]['GOOG']['Positive'])
    mini_array.append(goog5['data'][key]['GOOG']['Neutral'])
    mini_array.append(goog5['data'][key]['GOOG']['Negative'])
    mini_array.append(goog5['data'][key]['GOOG']['sentiment_score'])
    goog_list5.append(mini_array)
goog_list5
# Out:
# [['2020-12-08', 4, 2, 3, 0.389],
#  ['2020-12-07', 3, 3, 6, -0.125],
#  ['2020-12-06', 0, 0, 1, -1.5],
#  ['2020-12-05', 1, 0, 0, 1.5],
#  ['2020-12-04', 2, 0, 2, 0],
#  ['2020-12-03', 0, 1, 4, -1],
#  ['2020-12-02', 2, 1, 7, -0.65],
#  ['2020-12-01', 4, 1, 1, 0.917],
#  ['2020-11-30', 4, 0, 6, -0.3],
#  ['2020-11-29', 2, 0, 0, 1.5],
#  ['2020-11-27', 1, 0, 6, -1.071],
#  ['2020-11-26', 1, 0, 3, -0.75],
#  ['2020-11-25', 3, 2, 4, 0.056],
#  ['2020-11-24', 2, 4, 4, 0.1],
#  ['2020-11-23', 1, 1, 4, -0.583],
#  ['2020-11-21', 1, 0, 0, 1.5],
#  ['2020-11-20', 3, 1, 2, 0.417],
#  ['2020-11-19', 5, 1, 2, 0.688],
#  ['2020-11-18', 11, 5, 3, 0.895],
#  ['2020-11-17', 4, 1, 1, 0.917],
#  ['2020-11-16', 8, 1, 0, 1.444],
#  ['2020-11-15', 0, 1, 2, -0.667],
#  ['2020-11-14', 2, 0, 0, 1.5],
#  ['2020-11-13', 1, 1, 4, -0.583],
#  ['2020-11-12', 4, 3, 9, -0.281],
#  ['2020-11-11', 5, 1, 5, 0.091],
#  ['2020-11-10', 2, 2, 3, 0.071],
#  ['2020-11-09', 2, 1, 3, -0.083],
#  ['2020-11-07', 0, 1, 0, 1],
# ...

# %%
goog6['data'].keys()
datas = goog6['data'].keys()
goog_list6 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(goog6['data'][key]['GOOG']['Positive'])
    mini_array.append(goog6['data'][key]['GOOG']['Neutral'])
    mini_array.append(goog6['data'][key]['GOOG']['Negative'])
    mini_array.append(goog6['data'][key]['GOOG']['sentiment_score'])
    goog_list6.append(mini_array)
goog_list6
# Out:
# [['2020-10-16', 3, 1, 2, 0.417],
#  ['2020-10-15', 1, 4, 5, -0.2],
#  ['2020-10-14', 3, 2, 1, 0.833],
#  ['2020-10-13', 3, 0, 1, 0.75],
#  ['2020-10-12', 5, 2, 7, -0.071],
#  ['2020-10-11', 1, 1, 1, 0.333],
#  ['2020-10-10', 0, 0, 2, -1.5],
#  ['2020-10-09', 1, 6, 4, 0.136],
#  ['2020-10-08', 9, 3, 7, 0.316],
#  ['2020-10-07', 6, 9, 16, -0.194],
#  ['2020-10-06', 8, 9, 21, -0.276],
#  ['2020-10-05', 5, 3, 1, 1],
#  ['2020-10-04', 1, 1, 1, 0.333],
#  ['2020-10-03', 1, 0, 1, 0],
#  ['2020-10-02', 3, 8, 2, 0.731],
#  ['2020-10-01', 4, 17, 2, 0.87],
#  ['2020-09-30', 4, 20, 8, 0.438],
#  ['2020-09-29', 1, 8, 6, 0.033],
#  ['2020-09-28', 3, 6, 1, 0.9],
#  ['2020-09-27', 1, 0, 0, 1.5],
#  ['2020-09-26', 1, 0, 0, 1.5],
#  ['2020-09-25', 0, 9, 4, 0.231],
#  ['2020-09-24', 0, 6, 5, -0.136],
#  ['2020-09-23', 4, 5, 2, 0.727],
#  ['2020-09-22', 6, 2, 2, 0.8],
#  ['2020-09-21', 3, 2, 1, 0.833],
#  ['2020-09-20', 0, 0, 1, -1.5],
#  ['2020-09-18', 1, 2, 2, 0.1],
#  ['2020-09-17', 0, 2, 0, 1],
# ...

# %%
goog7['data'].keys()
datas = goog7['data'].keys()
goog_list7 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(goog7['data'][key]['GOOG']['Positive'])
    mini_array.append(goog7['data'][key]['GOOG']['Neutral'])
    mini_array.append(goog7['data'][key]['GOOG']['Negative'])
    mini_array.append(goog7['data'][key]['GOOG']['sentiment_score'])
    goog_list7.append(mini_array)
goog_list7
# Out:
# [['2020-08-25', 2, 6, 0, 1.125],
#  ['2020-08-24', 4, 2, 3, 0.389],
#  ['2020-08-23', 1, 0, 0, 1.5],
#  ['2020-08-21', 2, 3, 0, 1.2],
#  ['2020-08-20', 3, 3, 4, 0.15],
#  ['2020-08-19', 7, 0, 0, 1.5],
#  ['2020-08-18', 3, 4, 2, 0.611],
#  ['2020-08-17', 2, 4, 10, -0.5],
#  ['2020-08-16', 0, 0, 1, -1.5],
#  ['2020-08-15', 0, 0, 2, -1.5],
#  ['2020-08-14', 2, 5, 5, 0.042],
#  ['2020-08-13', 2, 1, 4, -0.286],
#  ['2020-08-12', 2, 4, 0, 1.167],
#  ['2020-08-11', 5, 5, 1, 1],
#  ['2020-08-10', 1, 4, 4, -0.056],
#  ['2020-08-09', 1, 0, 0, 1.5],
#  ['2020-08-08', 0, 1, 0, 1],
#  ['2020-08-07', 3, 0, 0, 1.5],
#  ['2020-08-06', 4, 3, 1, 0.938],
#  ['2020-08-05', 5, 3, 4, 0.375],
#  ['2020-08-04', 7, 7, 9, 0.174],
#  ['2020-08-03', 17, 4, 1, 1.273],
#  ['2020-08-02', 0, 1, 0, 1],
#  ['2020-07-31', 11, 13, 7, 0.613],
#  ['2020-07-30', 16, 13, 9, 0.618],
#  ['2020-07-29', 5, 17, 15, 0.054],
#  ['2020-07-28', 2, 17, 1, 0.925],
#  ['2020-07-27', 3, 26, 4, 0.742],
# ...

# %%
goog8['data'].keys()
datas = goog8['data'].keys()
goog_list8 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(goog8['data'][key]['GOOG']['Positive'])
    mini_array.append(goog8['data'][key]['GOOG']['Neutral'])
    mini_array.append(goog8['data'][key]['GOOG']['Negative'])
    mini_array.append(goog8['data'][key]['GOOG']['sentiment_score'])
    goog_list8.append(mini_array)
goog_list8
# Out:
# [['2020-06-29', 4, 2, 3, 0.389],
#  ['2020-06-28', 1, 1, 0, 1.25],
#  ['2020-06-27', 1, 0, 0, 1.5],
#  ['2020-06-26', 7, 4, 2, 0.885],
#  ['2020-06-25', 6, 10, 1, 1.029],
#  ['2020-06-24', 8, 7, 1, 1.094],
#  ['2020-06-23', 6, 9, 4, 0.632],
#  ['2020-06-22', 4, 7, 12, -0.217],
#  ['2020-06-20', 1, 1, 0, 1.25],
#  ['2020-06-19', 3, 3, 2, 0.563],
#  ['2020-06-18', 10, 8, 3, 0.881],
#  ['2020-06-17', 5, 16, 2, 0.891],
#  ['2020-06-16', 8, 10, 0, 1.222],
#  ['2020-06-15', 5, 1, 1, 1],
#  ['2020-06-12', 1, 3, 0, 1.125],
#  ['2020-06-11', 0, 4, 4, -0.25],
#  ['2020-06-10', 3, 5, 0, 1.188],
#  ['2020-06-09', 1, 2, 0, 1.167],
#  ['2020-06-08', 2, 0, 0, 1.5],
#  ['2020-06-06', 1, 0, 0, 1.5],
#  ['2020-06-05', 1, 0, 1, 0],
#  ['2020-06-04', 2, 2, 2, 0.333],
#  ['2020-06-03', 6, 5, 4, 0.533],
#  ['2020-06-02', 2, 1, 4, -0.286],
#  ['2020-06-01', 0, 3, 0, 1],
#  ['2020-05-31', 1, 0, 0, 1.5],
#  ['2020-05-30', 0, 1, 0, 1],
#  ['2020-05-29', 1, 6, 0, 1.071],
#  ['2020-05-28', 3, 6, 6, 0.1],
# ...

# %%
goog9['data'].keys()
datas = goog9['data'].keys()
goog_list9 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(goog9['data'][key]['GOOG']['Positive'])
    mini_array.append(goog9['data'][key]['GOOG']['Neutral'])
    mini_array.append(goog9['data'][key]['GOOG']['Negative'])
    mini_array.append(goog9['data'][key]['GOOG']['sentiment_score'])
    goog_list9.append(mini_array)
goog_list9
# Out:
# [['2020-05-01', 6, 5, 2, 0.846],
#  ['2020-04-30', 8, 6, 1, 1.1],
#  ['2020-04-29', 20, 10, 1, 1.242],
#  ['2020-04-28', 23, 15, 6, 0.92],
#  ['2020-04-27', 7, 4, 2, 0.885],
#  ['2020-04-26', 1, 1, 0, 1.25],
#  ['2020-04-25', 3, 0, 0, 1.5],
#  ['2020-04-24', 4, 12, 2, 0.833],
#  ['2020-04-23', 6, 8, 5, 0.5],
#  ['2020-04-22', 5, 4, 0, 1.278],
#  ['2020-04-21', 4, 7, 4, 0.467],
#  ['2020-04-20', 2, 6, 1, 0.833],
#  ['2020-04-19', 3, 3, 0, 1.25],
#  ['2020-04-18', 1, 0, 0, 1.5],
#  ['2020-04-17', 5, 7, 1, 1],
#  ['2020-04-16', 5, 3, 3, 0.545],
#  ['2020-04-15', 6, 10, 0, 1.188],
#  ['2020-04-14', 5, 3, 2, 0.75],
#  ['2020-04-13', 10, 4, 0, 1.357],
#  ['2020-04-12', 0, 1, 0, 1],
#  ['2020-04-11', 2, 0, 0, 1.5],
#  ['2020-04-10', 11, 1, 2, 1.036],
#  ['2020-04-09', 9, 3, 0, 1.375],
#  ['2020-04-08', 10, 4, 0, 1.357],
#  ['2020-04-07', 5, 2, 0, 1.357],
#  ['2020-04-06', 4, 2, 0, 1.333],
#  ['2020-04-05', 1, 0, 0, 1.5],
#  ['2020-04-03', 6, 2, 2, 0.8],
#  ['2020-04-02', 3, 2, 2, 0.5],
# ...

# %%
goog10['data'].keys()
datas = goog10['data'].keys()
goog_list10 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(goog10['data'][key]['GOOG']['Positive'])
    mini_array.append(goog10['data'][key]['GOOG']['Neutral'])
    mini_array.append(goog10['data'][key]['GOOG']['Negative'])
    mini_array.append(goog10['data'][key]['GOOG']['sentiment_score'])
    goog_list10.append(mini_array)
goog_list10
# Out:
# [['2020-03-11', 5, 9, 5, 0.474],
#  ['2020-03-10', 0, 7, 4, 0.091],
#  ['2020-03-09', 5, 3, 2, 0.75],
#  ['2020-03-08', 0, 1, 0, 1],
#  ['2020-03-07', 1, 1, 1, 0.333],
#  ['2020-03-06', 4, 5, 1, 0.95],
#  ['2020-03-05', 5, 4, 1, 1],
#  ['2020-03-04', 4, 12, 1, 0.971],
#  ['2020-03-03', 7, 5, 3, 0.733],
#  ['2020-03-02', 9, 7, 1, 1.118],
#  ['2020-02-28', 1, 1, 2, -0.125],
#  ['2020-02-27', 5, 4, 0, 1.278],
#  ['2020-02-26', 7, 2, 3, 0.667],
#  ['2020-02-25', 1, 1, 2, -0.125],
#  ['2020-02-24', 5, 1, 3, 0.444],
#  ['2020-02-23', 1, 1, 0, 1.25],
#  ['2020-02-21', 2, 4, 5, -0.045],
#  ['2020-02-20', 4, 2, 6, -0.083],
#  ['2020-02-19', 5, 4, 10, -0.184],
#  ['2020-02-18', 2, 5, 1, 0.813],
#  ['2020-02-17', 4, 0, 1, 0.9],
#  ['2020-02-16', 1, 0, 0, 1.5],
#  ['2020-02-15', 1, 1, 0, 1.25],
#  ['2020-02-14', 3, 7, 3, 0.538],
#  ['2020-02-13', 3, 3, 1, 0.857],
#  ['2020-02-12', 7, 4, 3, 0.714],
#  ['2020-02-11', 6, 12, 4, 0.682],
#  ['2020-02-10', 5, 4, 6, 0.167],
# ...

# %%
goog11['data'].keys()
datas = goog11['data'].keys()
goog_list11 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(goog11['data'][key]['GOOG']['Positive'])
    mini_array.append(goog11['data'][key]['GOOG']['Neutral'])
    mini_array.append(goog11['data'][key]['GOOG']['Negative'])
    mini_array.append(goog11['data'][key]['GOOG']['sentiment_score'])
    goog_list11.append(mini_array)
goog_list11
# Out:
# [['2020-01-15', 7, 7, 1, 1.067],
#  ['2020-01-14', 14, 3, 1, 1.25],
#  ['2020-01-13', 7, 2, 2, 0.864],
#  ['2020-01-12', 1, 0, 0, 1.5],
#  ['2020-01-10', 4, 4, 5, 0.192],
#  ['2020-01-09', 8, 2, 1, 1.136],
#  ['2020-01-08', 3, 3, 1, 0.857],
#  ['2020-01-07', 5, 4, 6, 0.167],
#  ['2020-01-06', 8, 4, 0, 1.333],
#  ['2020-01-05', 2, 0, 0, 1.5],
#  ['2020-01-04', 1, 0, 0, 1.5],
#  ['2020-01-03', 2, 8, 3, 0.5],
#  ['2020-01-02', 7, 6, 4, 0.618],
#  ['2020-01-01', 2, 0, 1, 0.5],
#  ['2019-12-31', 3, 2, 1, 0.833],
#  ['2019-12-30', 4, 2, 2, 0.625],
#  ['2019-12-28', 1, 2, 0, 1.167],
#  ['2019-12-27', 4, 2, 1, 0.929],
#  ['2019-12-26', 4, 5, 1, 0.95],
#  ['2019-12-24', 1, 2, 0, 1.167],
#  ['2019-12-23', 5, 1, 0, 1.417],
#  ['2019-12-22', 1, 0, 1, 0],
#  ['2019-12-21', 3, 2, 0, 1.3],
#  ['2019-12-20', 1, 5, 5, -0.091],
#  ['2019-12-19', 5, 0, 1, 1],
#  ['2019-12-18', 7, 3, 5, 0.4],
#  ['2019-12-17', 2, 3, 5, -0.15],
#  ['2019-12-16', 4, 2, 2, 0.625],
#  ['2019-12-14', 0, 1, 0, 1],
# ...

# %%
goog12['data'].keys()
datas = goog12['data'].keys()
goog_list12 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(goog12['data'][key]['GOOG']['Positive'])
    mini_array.append(goog12['data'][key]['GOOG']['Neutral'])
    mini_array.append(goog12['data'][key]['GOOG']['Negative'])
    mini_array.append(goog12['data'][key]['GOOG']['sentiment_score'])
    goog_list12.append(mini_array)
goog_list12
# Out:
# [['2019-11-21', 8, 10, 2, 0.95],
#  ['2019-11-20', 5, 11, 6, 0.432],
#  ['2019-11-19', 6, 2, 6, 0.143],
#  ['2019-11-18', 11, 9, 7, 0.556],
#  ['2019-11-17', 3, 0, 1, 0.75],
#  ['2019-11-16', 0, 1, 0, 1],
#  ['2019-11-15', 3, 4, 12, -0.5],
#  ['2019-11-14', 5, 5, 8, 0.028],
#  ['2019-11-13', 16, 5, 6, 0.741],
#  ['2019-11-12', 2, 3, 9, -0.536],
#  ['2019-11-11', 5, 3, 4, 0.375],
#  ['2019-11-10', 1, 0, 0, 1.5],
#  ['2019-11-09', 0, 2, 1, 0.167],
#  ['2019-11-08', 5, 3, 3, 0.545],
#  ['2019-11-07', 6, 5, 3, 0.679],
#  ['2019-11-06', 5, 1, 8, -0.25],
#  ['2019-11-05', 9, 0, 0, 1.5],
#  ['2019-11-04', 8, 2, 5, 0.433],
#  ['2019-11-03', 0, 2, 1, 0.167],
#  ['2019-11-02', 3, 0, 3, 0],
#  ['2019-11-01', 25, 5, 2, 1.234],
#  ['2019-10-31', 4, 1, 5, -0.05],
#  ['2019-10-30', 3, 3, 1, 0.857],
#  ['2019-10-29', 11, 5, 9, 0.32],
#  ['2019-10-28', 20, 15, 25, 0.125],
#  ['2019-10-27', 1, 0, 1, 0],
#  ['2019-10-26', 2, 0, 1, 0.5],
#  ['2019-10-25', 9, 7, 0, 1.281],
#  ['2019-10-24', 5, 3, 1, 1],
# ...

# %%
goog13['data'].keys()
datas = goog13['data'].keys()
goog_list13 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(goog13['data'][key]['GOOG']['Positive'])
    mini_array.append(goog13['data'][key]['GOOG']['Neutral'])
    mini_array.append(goog13['data'][key]['GOOG']['Negative'])
    mini_array.append(goog13['data'][key]['GOOG']['sentiment_score'])
    goog_list13.append(mini_array)
goog_list13
# Out:
# [['2019-09-29', 1, 1, 2, -0.125],
#  ['2019-09-28', 0, 2, 0, 1],
#  ['2019-09-27', 6, 1, 1, 1.063],
#  ['2019-09-26', 2, 3, 1, 0.75],
#  ['2019-09-25', 1, 5, 0, 1.083],
#  ['2019-09-24', 11, 9, 0, 1.275],
#  ['2019-09-23', 8, 4, 0, 1.333],
#  ['2019-09-22', 1, 0, 0, 1.5],
#  ['2019-09-20', 6, 3, 1, 1.05],
#  ['2019-09-19', 5, 4, 0, 1.278],
#  ['2019-09-18', 1, 0, 0, 1.5],
#  ['2019-09-17', 1, 5, 1, 0.714],
#  ['2019-09-16', 4, 5, 1, 0.95],
#  ['2019-09-13', 1, 1, 7, -0.889],
#  ['2019-09-12', 5, 4, 8, -0.029],
#  ['2019-09-11', 0, 5, 2, 0.286],
#  ['2019-09-10', 1, 9, 2, 0.625],
#  ['2019-09-09', 3, 9, 20, -0.516],
#  ['2019-09-07', 0, 0, 1, -1.5],
#  ['2019-09-06', 3, 8, 8, 0.026],
#  ['2019-09-05', 3, 5, 0, 1.188],
#  ['2019-09-04', 2, 15, 9, 0.173],
#  ['2019-09-03', 2, 6, 4, 0.25],
#  ['2019-09-02', 2, 0, 1, 0.5],
#  ['2019-08-31', 0, 1, 0, 1],
#  ['2019-08-30', 3, 4, 3, 0.4],
#  ['2019-08-29', 4, 5, 1, 0.95],
#  ['2019-08-28', 1, 5, 7, -0.308],
# ...

# %%
goog14['data'].keys()
datas = goog14['data'].keys()
goog_list14 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(goog14['data'][key]['GOOG']['Positive'])
    mini_array.append(goog14['data'][key]['GOOG']['Neutral'])
    mini_array.append(goog14['data'][key]['GOOG']['Negative'])
    mini_array.append(goog14['data'][key]['GOOG']['sentiment_score'])
    goog_list14.append(mini_array)
goog_list14
# Out:
# [['2019-08-03', 0, 1, 0, 1],
#  ['2019-08-02', 0, 8, 2, 0.5],
#  ['2019-08-01', 2, 4, 1, 0.786],
#  ['2019-07-31', 9, 2, 0, 1.409],
#  ['2019-07-30', 6, 2, 1, 1.056],
#  ['2019-07-29', 6, 6, 0, 1.25],
#  ['2019-07-28', 0, 1, 0, 1],
#  ['2019-07-27', 0, 1, 0, 1],
#  ['2019-07-26', 14, 8, 8, 0.567],
#  ['2019-07-25', 23, 8, 9, 0.725],
#  ['2019-07-24', 2, 5, 4, 0.182],
#  ['2019-07-23', 4, 7, 9, -0.025],
#  ['2019-07-22', 5, 7, 0, 1.208],
#  ['2019-07-21', 1, 0, 1, 0],
#  ['2019-07-20', 2, 0, 0, 1.5],
#  ['2019-07-19', 1, 3, 4, -0.188],
#  ['2019-07-18', 2, 4, 2, 0.5],
#  ['2019-07-17', 2, 5, 6, -0.077],
#  ['2019-07-16', 0, 10, 9, -0.184],
#  ['2019-07-15', 2, 6, 7, -0.1],
#  ['2019-07-14', 1, 1, 2, -0.125],
#  ['2019-07-12', 4, 1, 3, 0.313],
#  ['2019-07-11', 5, 5, 6, 0.219],
#  ['2019-07-10', 5, 3, 2, 0.75],
#  ['2019-07-09', 3, 12, 2, 0.794],
#  ['2019-07-08', 6, 3, 1, 1.05],
#  ['2019-07-07', 2, 0, 0, 1.5],
#  ['2019-07-06', 1, 0, 0, 1.5],
#  ['2019-07-05', 4, 3, 3, 0.45],
# ...

# %%
goog15['data'].keys()
datas = goog15['data'].keys()
goog_list15 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(goog15['data'][key]['GOOG']['Positive'])
    mini_array.append(goog15['data'][key]['GOOG']['Neutral'])
    mini_array.append(goog15['data'][key]['GOOG']['Negative'])
    mini_array.append(goog15['data'][key]['GOOG']['sentiment_score'])
    goog_list15.append(mini_array)
goog_list15
# Out:
# [['2019-06-13', 2, 7, 4, 0.308],
#  ['2019-06-12', 6, 12, 7, 0.42],
#  ['2019-06-11', 6, 7, 7, 0.275],
#  ['2019-06-10', 3, 11, 9, 0.087],
#  ['2019-06-09', 0, 2, 1, 0.167],
#  ['2019-06-08', 0, 3, 0, 1],
#  ['2019-06-07', 7, 3, 7, 0.176],
#  ['2019-06-06', 17, 10, 6, 0.803],
#  ['2019-06-05', 7, 9, 10, 0.173],
#  ['2019-06-04', 1, 4, 8, -0.5],
#  ['2019-06-03', 4, 6, 38, -0.938],
#  ['2019-06-02', 3, 2, 9, -0.5],
#  ['2019-06-01', 0, 0, 1, -1.5],
#  ['2019-05-31', 4, 0, 4, 0],
#  ['2019-05-30', 7, 4, 2, 0.885],
#  ['2019-05-29', 8, 2, 1, 1.136],
#  ['2019-05-28', 3, 2, 0, 1.3],
#  ['2019-05-24', 3, 2, 2, 0.5],
#  ['2019-05-23', 2, 2, 0, 1.25],
#  ['2019-05-22', 2, 1, 3, -0.083],
#  ['2019-05-21', 1, 2, 0, 1.167],
#  ['2019-05-20', 3, 10, 7, 0.2],
#  ['2019-05-19', 0, 2, 1, 0.167],
#  ['2019-05-17', 3, 1, 1, 0.8],
#  ['2019-05-16', 2, 0, 0, 1.5],
#  ['2019-05-15', 3, 1, 0, 1.375],
#  ['2019-05-14', 5, 2, 1, 1],
#  ['2019-05-13', 3, 1, 0, 1.375],
#  ['2019-05-12', 1, 0, 0, 1.5],
# ...

# %%
goog16['data'].keys()
datas = goog16['data'].keys()
goog_list16 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(goog16['data'][key]['GOOG']['Positive'])
    mini_array.append(goog16['data'][key]['GOOG']['Neutral'])
    mini_array.append(goog16['data'][key]['GOOG']['Negative'])
    mini_array.append(goog16['data'][key]['GOOG']['sentiment_score'])
    goog_list16.append(mini_array)
goog_list16
# Out:
# [['2019-04-17', 4, 1, 0, 1.4],
#  ['2019-04-16', 3, 0, 1, 0.75],
#  ['2019-04-15', 1, 0, 3, -0.75],
#  ['2019-04-14', 1, 0, 0, 1.5],
#  ['2019-04-13', 1, 0, 0, 1.5],
#  ['2019-04-12', 2, 0, 1, 0.5],
#  ['2019-04-11', 4, 0, 1, 0.9],
#  ['2019-04-10', 1, 3, 2, 0.25],
#  ['2019-04-09', 6, 1, 3, 0.55],
#  ['2019-04-08', 2, 2, 2, 0.333],
#  ['2019-04-07', 3, 1, 0, 1.375],
#  ['2019-04-06', 2, 0, 0, 1.5],
#  ['2019-04-05', 2, 0, 1, 0.5],
#  ['2019-04-04', 3, 1, 2, 0.417],
#  ['2019-04-03', 4, 0, 0, 1.5],
#  ['2019-04-02', 5, 2, 1, 1],
#  ['2019-04-01', 3, 1, 0, 1.375]]

# %%
goog_list = goog_list1 + goog_list2 + goog_list3 + goog_list4 + goog_list5 + goog_list6 + goog_list7 + goog_list8 + goog_list9 + goog_list10 + goog_list11 + goog_list12 + goog_list13 + goog_list14 + goog_list15 + goog_list16

# %%
# # my_dict = json.load(json_file)
goog_df = pd.DataFrame(goog_list)
goog_df.shape
# Out:
# (767, 5)

# %%
goog_df.to_csv('goog_df.csv')

# %%
goog_df
# Out:
#               0  1  2   3      4
# 0    2021-07-15  2  2   2  0.333
# 1    2021-07-14  2  0   0  1.500
# 2    2021-07-13  4  1  18 -0.870
# 3    2021-07-12  3  0   3  0.000
# 4    2021-07-10  1  0   1  0.000
# ..          ... .. ..  ..    ...
# 762  2019-04-05  2  0   1  0.500
# 763  2019-04-04  3  1   2  0.417
# 764  2019-04-03  4  0   0  1.500
# 765  2019-04-02  5  2   1  1.000
# 766  2019-04-01  3  1   0  1.375
#
# [767 rows x 5 columns]
