# %%
import matplotlib
# %matplotlib inline
import numpy as np
import pandas as pd
import json

# %%
import requests

# %%
url = "https://stocknewsapi.com/api/v1/stat?&tickers=KODK&date=04012019-07152021&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb"

# %%
url
# Out:
# 'https://stocknewsapi.com/api/v1/stat?&tickers=KODK&date=04012019-07152021&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb'

# %%
response = requests.get(url)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data

kodak1 = data

# %%
kodak1
# Out:
# {'total': {'KODK': {'Total Positive': 80,
#    'Total Negative': 77,
#    'Total Neutral': 153,
#    'Sentiment Score': 0.508}},
#  'data': {'2021-07-15': {'KODK': {'Neutral': 0,
#     'Positive': 0,
#     'Negative': 1,
#     'sentiment_score': -1.5}},
#   '2021-07-12': {'KODK': {'Neutral': 1,
#     'Positive': 0,
#     'Negative': 0,
#     'sentiment_score': 1}},
#   '2021-06-16': {'KODK': {'Neutral': 1,
#     'Positive': 0,
#     'Negative': 0,
#     'sentiment_score': 1}},
#   '2021-06-08': {'KODK': {'Neutral': 0,
#     'Positive': 1,
#     'Negative': 0,
#     'sentiment_score': 1.5}},
#   '2021-06-03': {'KODK': {'Neutral': 0,
#     'Positive': 0,
#     'Negative': 1,
#     'sentiment_score': -1.5}},
#   '2021-06-02': {'KODK': {'Neutral': 0,
#     'Positive': 1,
#     'Negative': 0,
#     'sentiment_score': 1.5}},
#   '2021-06-01': {'KODK': {'Neutral': 1,
#     'Positive': 0,
#     'Negative': 2,
#     'sentiment_score': -0.667}},
#   '2021-05-18': {'KODK': {'Neutral': 0,
#     'Positive': 0,
#     'Negative': 1,
#     'sentiment_score': -1.5}},
#   '2021-05-17': {'KODK': {'Neutral': 0,
#     'Positive': 0,
#     'Negative': 1,
#     'sentiment_score': -1.5}},
#   '2021-05-12': {'KODK': {'Neutral': 2,
#     'Positive': 0,
#     'Negative': 0,
#     'sentiment_score': 1}},
#   '2021-05-10': {'KODK': {'Neutral': 1,
#     'Positive': 0,
#     'Negative': 0,
#     'sentiment_score': 1}},
#   '2021-04-30': {'KODK': {'Neutral': 1,
#     'Positive': 0,
#     'Negative': 0,
#     'sentiment_score': 1}},
#   '2021-04-19': {'KODK': {'Neutral': 1,
#     'Positive': 0,
#     'Negative': 0,
#     'sentiment_score': 1}},
#   '2021-03-17': {'KODK': {'Neutral': 0,
#     'Positive': 0,
#     'Negative': 1,
#     'sentiment_score': -1.5}},
#   '2021-03-16': {'KODK': {'Neutral': 2,
#     'Positive': 0,
#     'Negative': 0,
#     'sentiment_score': 1}},
#   '2021-03-15': {'KODK': {'Neutral': 1,
#     'Positive': 0,
#     'Negative': 0,
#     'sentiment_score': 1}},
#   '2021-03-09': {'KODK': {'Neutral': 1,
#     'Positive': 1,
#     'Negative': 0,
#     'sentiment_score': 1.25}},
#   '2021-02-04': {'KODK': {'Neutral': 1,
#     'Positive': 0,
#     'Negative': 0,
#     'sentiment_score': 1}},
#   '2021-02-03': {'KODK': {'Neutral': 0,
#     'Positive': 3,
#     'Negative': 0,
#     'sentiment_score': 1.5}},
#   '2021-01-28': {'KODK': {'Neutral': 0,
#     'Positive': 0,
#     'Negative': 1,
#     'sentiment_score': -1.5}},
#   '2021-01-27': {'KODK': {'Neutral': 0,
#     'Positive': 2,
#     'Negative': 0,
#     'sentiment_score': 1.5}},
#   '2021-01-21': {'KODK': {'Neutral': 1,
#     'Positive': 0,
#     'Negative': 0,
#     'sentiment_score': 1}},
#   '2021-01-04': {'KODK': {'Neutral': 0,
#     'Positive': 1,
#     'Negative': 0,
#     'sentiment_score': 1.5}},
#   '2020-12-16': {'KODK': {'Neutral': 1,
#     'Positive': 0,
#     'Negative': 0,
#     'sentiment_score': 1}},
#   '2020-12-15': {'KODK': {'Neutral': 0,
#     'Positive': 1,
#     'Negative': 0,
#     'sentiment_score': 1.5}},
#   '2020-12-07': {'KODK': {'Neutral': 2,
#     'Positive': 13,
#     'Negative': 1,
#     'sentiment_score': 1.25}},
#   '2020-12-06': {'KODK': {'Neutral': 0,
#     'Positive': 1,
#     'Negative': 0,
#     'sentiment_score': 1.5}},
#   '2020-11-21': {'KODK': {'Neutral': 0,
#     'Positive': 1,
#     'Negative': 0,
#     'sentiment_score': 1.5}},
#   '2020-11-20': {'KODK': {'Neutral': 0,
#     'Positive': 0,
#     'Negative': 1,
#     'sentiment_score': -1.5}},
#   '2020-11-13': {'KODK': {'Neutral': 1,
#     'Positive': 0,
#     'Negative': 2,
#     'sentiment_score': -0.667}},
#   '2020-11-11': {'KODK': {'Neutral': 0,
#     'Positive': 0,
#     'Negative': 4,
#     'sentiment_score': -1.5}},
#   '2020-11-10': {'KODK': {'Neutral': 1,
#     'Positive': 0,
#     'Negative': 0,
#     'sentiment_score': 1}},
#   '2020-11-06': {'KODK': {'Neutral': 0,
#     'Positive': 0,
#     'Negative': 1,
#     'sentiment_score': -1.5}},
#   '2020-11-05': {'KODK': {'Neutral': 0,
#     'Positive': 0,
#     'Negative': 1,
#     'sentiment_score': -1.5}},
#   '2020-11-03': {'KODK': {'Neutral': 1,
#     'Positive': 0,
#     'Negative': 1,
#     'sentiment_score': -0.25}},
#   '2020-11-02': {'KODK': {'Neutral': 0,
#     'Positive': 0,
#     'Negative': 1,
#     'sentiment_score': -1.5}},
#   '2020-10-30': {'KODK': {'Neutral': 0,
#     'Positive': 0,
#     'Negative': 1,
#     'sentiment_score': -1.5}},
#   '2020-10-29': {'KODK': {'Neutral': 0,
#     'Positive': 0,
#     'Negative': 1,
#     'sentiment_score': -1.5}},
#   '2020-10-28': {'KODK': {'Neutral': 0,
#     'Positive': 0,
#     'Negative': 1,
#     'sentiment_score': -1.5}},
#   '2020-10-27': {'KODK': {'Neutral': 1,
#     'Positive': 0,
#     'Negative': 0,
#     'sentiment_score': 1}},
#   '2020-10-26': {'KODK': {'Neutral': 1,
#     'Positive': 0,
#     'Negative': 0,
#     'sentiment_score': 1}},
#   '2020-10-25': {'KODK': {'Neutral': 0,
#     'Positive': 0,
#     'Negative': 1,
#     'sentiment_score': -1.5}},
#   '2020-10-23': {'KODK': {'Neutral': 0,
#     'Positive': 0,
#     'Negative': 1,
#     'sentiment_score': -1.5}},
#   '2020-10-22': {'KODK': {'Neutral': 0,
#     'Positive': 0,
#     'Negative': 1,
#     'sentiment_score': -1.5}},
#   '2020-10-21': {'KODK': {'Neutral': 0,
#     'Positive': 0,
#     'Negative': 1,
#     'sentiment_score': -1.5}},
#   '2020-10-19': {'KODK': {'Neutral': 2,
#     'Positive': 0,
#     'Negative': 0,
#     'sentiment_score': 1}},
#   '2020-10-16': {'KODK': {'Neutral': 0,
#     'Positive': 0,
#     'Negative': 1,
#     'sentiment_score': -1.5}},
#   '2020-10-13': {'KODK': {'Neutral': 3,
#     'Positive': 1,
#     'Negative': 0,
#     'sentiment_score': 1.125}},
#   '2020-10-12': {'KODK': {'Neutral': 4,
#     'Positive': 0,
#     'Negative': 0,
#     'sentiment_score': 1}},
#   '2020-10-11': {'KODK': {'Neutral': 2,
#     'Positive': 0,
#     'Negative': 0,
#     'sentiment_score': 1}}},
#  'total_pages': 3}

# %%
url_2 = "https://stocknewsapi.com/api/v1/stat?&tickers=KODK&date=04012019-07152021&page=2&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb"

# %%
response = requests.get(url_2)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data

kodak2 = data

# %%
url_3 = "https://stocknewsapi.com/api/v1/stat?&tickers=KODK&date=04012019-07152021&page=3&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb"

# %%
response = requests.get(url_3)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
kodak3 = data

# %%
# Out:
# {'total': {'KODK': {'Total Positive': 80,
#    'Total Negative': 77,
#    'Total Neutral': 153,
#    'Sentiment Score': 0.508}},
#  'data': [],
#  'total_pages': 3}

# %%
# url_5 = "https://stocknewsapi.com/api/v1/stat?&tickers=AMZN&date=04012019-07152021&page=5&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb"

# response = requests.get(url_5)
# if response.status_code != 200:
#     print("deu ruim")
# data = response.json()
# data

# amazon5 = data

# %%
# url_6 = "https://stocknewsapi.com/api/v1/stat?&tickers=AMZN&date=04012019-07152021&page=6&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb"

# response = requests.get(url_6)
# if response.status_code != 200:
#     print("deu ruim")
# data = response.json()
# data

# amazon6 = data

# %%
# url_7 = "https://stocknewsapi.com/api/v1/stat?&tickers=AMZN&date=04012019-07152021&page=7&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb"

# response = requests.get(url_7)
# if response.status_code != 200:
#     print("deu ruim")
# data = response.json()
# data

# amazon7 = data

# %%
# url_8 = "https://stocknewsapi.com/api/v1/stat?&tickers=AMZN&date=04012019-07152021&page=8&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb"

# response = requests.get(url_8)
# if response.status_code != 200:
#     print("deu ruim")
# data = response.json()
# data

# amazon8 = data

# %%
# url_9 = "https://stocknewsapi.com/api/v1/stat?&tickers=AMZN&date=04012019-07152021&page=9&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb"

# response = requests.get(url_9)
# if response.status_code != 200:
#     print("deu ruim")
# data = response.json()
# data

# amazon9 = data

# %%
# url_10 = "https://stocknewsapi.com/api/v1/stat?&tickers=AMZN&date=04012019-07152021&page=10&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb"

# response = requests.get(url_10)
# if response.status_code != 200:
#     print("deu ruim")
# data = response.json()
# data

# amazon10 = data

# %%
# url_11 = "https://stocknewsapi.com/api/v1/stat?&tickers=AMZN&date=04012019-07152021&page=11&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb"

# response = requests.get(url_11)
# if response.status_code != 200:
#     print("deu ruim")
# data = response.json()
# data

# amazon11 = data

# %%
# url_12 = "https://stocknewsapi.com/api/v1/stat?&tickers=AMZN&date=04012019-07152021&page=12&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb"

# response = requests.get(url_12)
# if response.status_code != 200:
#     print("deu ruim")
# data = response.json()
# data

# amazon12 = data

# %%
# url_13 = "https://stocknewsapi.com/api/v1/stat?&tickers=AMZN&date=04012019-07152021&page=13&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb"

# response = requests.get(url_13)
# if response.status_code != 200:
#     print("deu ruim")
# data = response.json()
# data

# amazon13 = data

# %%
# url_14 = "https://stocknewsapi.com/api/v1/stat?&tickers=AMZN&date=04012019-07152021&page=14&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb"

# response = requests.get(url_14)
# if response.status_code != 200:
#     print("deu ruim")
# data = response.json()
# data

# amazon14 = data

# %%
# url_15 = "https://stocknewsapi.com/api/v1/stat?&tickers=AMZN&date=04012019-07152021&page=15&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb"

# response = requests.get(url_15)
# if response.status_code != 200:
#     print("deu ruim")
# data = response.json()
# data

# amazon15 = data

# %%
# url_16 = "https://stocknewsapi.com/api/v1/stat?&tickers=AMZN&date=04012019-07152021&page=16&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb"

# response = requests.get(url_16)
# if response.status_code != 200:
#     print("deu ruim")
# data = response.json()
# data

# amazon16 = data

# %%
# url_17 = "https://stocknewsapi.com/api/v1/stat?&tickers=AMZN&date=04012019-07152021&page=17&token=vhx1apxem0rfwi6ppuuhjtuslpkd7q3japidzcqb"

# response = requests.get(url_17)
# if response.status_code != 200:
#     print("deu ruim")
# data = response.json()
# data

# amazon17 = data

# %%
# amazon_df = pd.DataFrame

# %%
# amazon_df['data'] = data

# %%
# amazon2['data'].keys()
# datas = amazon2['data'].keys()
# list = []
# for key in datas:
#     mini_array = []
#     mini_array.append(key)
#     mini_array.append(amazon2['data'][key]['AMZN']['Positive'])
#     mini_array.append(amazon2['data'][key]['AMZN']['Neutral'])
#     mini_array.append(amazon2['data'][key]['AMZN']['Negative'])
#     mini_array.append(amazon2['data'][key]['AMZN']['sentiment_score'])
#     list.append(mini_array)
# list

# %%
# amazon4['data'].keys()
# datas = amazon4['data'].keys()
# list2 = []
# for key in datas:
#     mini_array = []
#     mini_array.append(key)
#     mini_array.append(amazon4['data'][key]['AMZN']['Positive'])
#     mini_array.append(amazon4['data'][key]['AMZN']['Neutral'])
#     mini_array.append(amazon4['data'][key]['AMZN']['Negative'])
#     mini_array.append(amazon4['data'][key]['AMZN']['sentiment_score'])
#     list2.append(mini_array)
# list2

# %%
# amazon_first_try['data'].keys()
# datas = amazon_first_try['data'].keys()
# list3 = []
# for key in datas:
#     mini_array = []
#     mini_array.append(key)
#     mini_array.append(amazon_first_try['data'][key]['AMZN']['Positive'])
#     mini_array.append(amazon_first_try['data'][key]['AMZN']['Neutral'])
#     mini_array.append(amazon_first_try['data'][key]['AMZN']['Negative'])
#     mini_array.append(amazon_first_try['data'][key]['AMZN']['sentiment_score'])
#     list3.append(mini_array)
# list3

# %%
kodak1['data'].keys()
datas = kodak1['data'].keys()
kodak_list1 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(kodak1['data'][key]['KODK']['Positive'])
    mini_array.append(kodak1['data'][key]['KODK']['Neutral'])
    mini_array.append(kodak1['data'][key]['KODK']['Negative'])
    mini_array.append(kodak1['data'][key]['KODK']['sentiment_score'])
    kodak_list1.append(mini_array)
kodak_list1
# Out:
# [['2021-07-15', 0, 0, 1, -1.5],
#  ['2021-07-12', 0, 1, 0, 1],
#  ['2021-06-16', 0, 1, 0, 1],
#  ['2021-06-08', 1, 0, 0, 1.5],
#  ['2021-06-03', 0, 0, 1, -1.5],
#  ['2021-06-02', 1, 0, 0, 1.5],
#  ['2021-06-01', 0, 1, 2, -0.667],
#  ['2021-05-18', 0, 0, 1, -1.5],
#  ['2021-05-17', 0, 0, 1, -1.5],
#  ['2021-05-12', 0, 2, 0, 1],
#  ['2021-05-10', 0, 1, 0, 1],
#  ['2021-04-30', 0, 1, 0, 1],
#  ['2021-04-19', 0, 1, 0, 1],
#  ['2021-03-17', 0, 0, 1, -1.5],
#  ['2021-03-16', 0, 2, 0, 1],
#  ['2021-03-15', 0, 1, 0, 1],
#  ['2021-03-09', 1, 1, 0, 1.25],
#  ['2021-02-04', 0, 1, 0, 1],
#  ['2021-02-03', 3, 0, 0, 1.5],
#  ['2021-01-28', 0, 0, 1, -1.5],
#  ['2021-01-27', 2, 0, 0, 1.5],
#  ['2021-01-21', 0, 1, 0, 1],
#  ['2021-01-04', 1, 0, 0, 1.5],
#  ['2020-12-16', 0, 1, 0, 1],
#  ['2020-12-15', 1, 0, 0, 1.5],
#  ['2020-12-07', 13, 2, 1, 1.25],
#  ['2020-12-06', 1, 0, 0, 1.5],
#  ['2020-11-21', 1, 0, 0, 1.5],
#  ['2020-11-20', 0, 0, 1, -1.5],
#  ['2020-11-13', 0, 1, 2, -0.667],
#  ['2020-11-11', 0, 0, 4, -1.5],
#  ['2020-11-10', 0, 1, 0, 1],
#  ['2020-11-06', 0, 0, 1, -1.5],
#  ['2020-11-05', 0, 0, 1, -1.5],
#  ['2020-11-03', 0, 1, 1, -0.25],
#  ['2020-11-02', 0, 0, 1, -1.5],
#  ['2020-10-30', 0, 0, 1, -1.5],
#  ['2020-10-29', 0, 0, 1, -1.5],
#  ['2020-10-28', 0, 0, 1, -1.5],
#  ['2020-10-27', 0, 1, 0, 1],
#  ['2020-10-26', 0, 1, 0, 1],
#  ['2020-10-25', 0, 0, 1, -1.5],
#  ['2020-10-23', 0, 0, 1, -1.5],
#  ['2020-10-22', 0, 0, 1, -1.5],
#  ['2020-10-21', 0, 0, 1, -1.5],
#  ['2020-10-19', 0, 2, 0, 1],
#  ['2020-10-16', 0, 0, 1, -1.5],
#  ['2020-10-13', 1, 3, 0, 1.125],
#  ['2020-10-12', 0, 4, 0, 1],
#  ['2020-10-11', 0, 2, 0, 1]]

# %%
kodak2['data'].keys()
datas = kodak2['data'].keys()
kodak_list2 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(kodak2['data'][key]['KODK']['Positive'])
    mini_array.append(kodak2['data'][key]['KODK']['Neutral'])
    mini_array.append(kodak2['data'][key]['KODK']['Negative'])
    mini_array.append(kodak2['data'][key]['KODK']['sentiment_score'])
    kodak_list2.append(mini_array)
kodak_list2
# Out:
# [['2020-10-10', 0, 2, 0, 1],
#  ['2020-10-09', 0, 3, 0, 1],
#  ['2020-10-08', 0, 3, 1, 0.375],
#  ['2020-10-07', 0, 2, 0, 1],
#  ['2020-10-06', 0, 1, 0, 1],
#  ['2020-10-05', 1, 1, 0, 1.25],
#  ['2020-10-04', 0, 2, 0, 1],
#  ['2020-10-01', 0, 2, 0, 1],
#  ['2020-09-30', 0, 1, 0, 1],
#  ['2020-09-29', 0, 1, 0, 1],
#  ['2020-09-28', 0, 1, 1, -0.25],
#  ['2020-09-26', 0, 1, 1, -0.25],
#  ['2020-09-25', 0, 0, 1, -1.5],
#  ['2020-09-24', 0, 2, 0, 1],
#  ['2020-09-23', 0, 2, 1, 0.167],
#  ['2020-09-22', 0, 2, 1, 0.167],
#  ['2020-09-20', 0, 1, 0, 1],
#  ['2020-09-19', 0, 0, 1, -1.5],
#  ['2020-09-18', 1, 1, 0, 1.25],
#  ['2020-09-17', 1, 0, 1, 0],
#  ['2020-09-16', 9, 1, 0, 1.45],
#  ['2020-09-15', 0, 2, 0, 1],
#  ['2020-09-14', 0, 2, 0, 1],
#  ['2020-09-11', 2, 0, 0, 1.5],
#  ['2020-09-09', 0, 2, 0, 1],
#  ['2020-09-08', 0, 1, 0, 1],
#  ['2020-09-07', 0, 1, 1, -0.25],
#  ['2020-09-04', 0, 1, 0, 1],
#  ['2020-09-03', 0, 1, 0, 1],
#  ['2020-09-02', 0, 1, 0, 1],
#  ['2020-09-01', 8, 0, 0, 1.5],
#  ['2020-08-31', 1, 1, 0, 1.25],
#  ['2020-08-28', 0, 2, 0, 1],
#  ['2020-08-27', 0, 1, 0, 1],
#  ['2020-08-26', 0, 1, 0, 1],
#  ['2020-08-25', 0, 1, 0, 1],
#  ['2020-08-24', 0, 2, 0, 1],
#  ['2020-08-23', 0, 1, 0, 1],
#  ['2020-08-22', 0, 3, 0, 1],
#  ['2020-08-21', 0, 4, 0, 1],
#  ['2020-08-20', 0, 2, 0, 1],
#  ['2020-08-19', 0, 1, 0, 1],
#  ['2020-08-18', 0, 5, 0, 1],
#  ['2020-08-17', 0, 3, 2, 0],
#  ['2020-08-16', 0, 2, 0, 1],
#  ['2020-08-14', 0, 6, 0, 1],
#  ['2020-08-12', 0, 1, 0, 1],
#  ['2020-08-11', 1, 4, 1, 0.667],
#  ['2020-08-10', 0, 8, 10, -0.389],
#  ['2020-08-09', 0, 0, 1, -1.5]]

# %%
kodak3['data'].keys()
datas = kodak3['data'].keys()
kodak_list3 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(kodak3['data'][key]['KODK']['Positive'])
    mini_array.append(kodak3['data'][key]['KODK']['Neutral'])
    mini_array.append(kodak3['data'][key]['KODK']['Negative'])
    mini_array.append(kodak3['data'][key]['KODK']['sentiment_score'])
    kodak_list3.append(mini_array)
kodak_list3
# Out:
# [['2020-08-08', 0, 0, 3, -1.5],
#  ['2020-08-07', 0, 2, 0, 1],
#  ['2020-08-06', 1, 0, 0, 1.5],
#  ['2020-08-05', 2, 5, 5, 0.042],
#  ['2020-08-04', 1, 8, 8, -0.147],
#  ['2020-08-03', 1, 0, 4, -0.9],
#  ['2020-08-02', 1, 0, 0, 1.5],
#  ['2020-08-01', 0, 1, 0, 1],
#  ['2020-07-31', 0, 3, 1, 0.375],
#  ['2020-07-30', 1, 2, 1, 0.5],
#  ['2020-07-29', 12, 3, 1, 1.219],
#  ['2020-07-28', 9, 0, 1, 1.2],
#  ['2020-05-12', 0, 1, 0, 1],
#  ['2020-03-17', 0, 2, 0, 1],
#  ['2020-02-14', 1, 0, 0, 1.5],
#  ['2019-11-08', 0, 1, 0, 1],
#  ['2019-08-09', 0, 1, 0, 1],
#  ['2019-07-25', 0, 0, 1, -1.5],
#  ['2019-06-11', 0, 1, 0, 1],
#  ['2019-05-31', 0, 0, 1, -1.5],
#  ['2019-05-09', 1, 1, 0, 1.25],
#  ['2019-04-01', 0, 1, 0, 1]]

# %%
kodak_list = kodak_list1 + kodak_list2 + kodak_list3

# %%
# # my_dict = json.load(json_file)
kodak_df = pd.DataFrame(kodak_list)
kodak_df.shape
# Out:
# (122, 5)

# %%
kodak_df.to_csv('kodak_df.csv')

# %%
kodak_df
# Out:
#               0  1  2  3     4
# 0    2021-07-15  0  0  1 -1.50
# 1    2021-07-12  0  1  0  1.00
# 2    2021-06-16  0  1  0  1.00
# 3    2021-06-08  1  0  0  1.50
# 4    2021-06-03  0  0  1 -1.50
# ..          ... .. .. ..   ...
# 117  2019-07-25  0  0  1 -1.50
# 118  2019-06-11  0  1  0  1.00
# 119  2019-05-31  0  0  1 -1.50
# 120  2019-05-09  1  1  0  1.25
# 121  2019-04-01  0  1  0  1.00
#
# [122 rows x 5 columns]
