# %%
import matplotlib
# %matplotlib inline
import numpy as np
import pandas as pd
import json

# %%
import requests

# %%
url = "https://stocknewsapi.com/api/v1/stat?&tickers=BABA&date=04012019-07152021&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"

# %%
url
# Out:
# 'https://stocknewsapi.com/api/v1/stat?&tickers=BABA&date=04012019-07152021&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit'

# %%
response = requests.get(url)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data

baba1 = data
baba1
# Out:
# {'total': {'BABA': {'Total Positive': 1423,
#    'Total Negative': 495,
#    'Total Neutral': 654,
#    'Sentiment Score': 0.795}},
#  'data': {'2021-07-15': {'BABA': {'Neutral': 1,
#     'Positive': 1,
#     'Negative': 3,
#     'sentiment_score': -0.4}},
#   '2021-07-14': {'BABA': {'Neutral': 1,
#     'Positive': 6,
#     'Negative': 1,
#     'sentiment_score': 1.063}},
#   '2021-07-13': {'BABA': {'Neutral': 3,
#     'Positive': 3,
#     'Negative': 2,
#     'sentiment_score': 0.563}},
#   '2021-07-12': {'BABA': {'Neutral': 1,
#     'Positive': 4,
#     'Negative': 2,
#     'sentiment_score': 0.571}},
#   '2021-07-11': {'BABA': {'Neutral': 2,
#     'Positive': 0,
#     'Negative': 0,
#     'sentiment_score': 1}},
#   '2021-07-10': {'BABA': {'Neutral': 0,
#     'Positive': 1,
#     'Negative': 0,
#     'sentiment_score': 1.5}},
#   '2021-07-09': {'BABA': {'Neutral': 1,
#     'Positive': 1,
#     'Negative': 2,
#     'sentiment_score': -0.125}},
# ...

# %%
url_2 = "https://stocknewsapi.com/api/v1/stat?&tickers=BABA&date=04012019-07152021&page=2&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_3 = "https://stocknewsapi.com/api/v1/stat?&tickers=BABA&date=04012019-07152021&page=3&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_4 = "https://stocknewsapi.com/api/v1/stat?&tickers=BABA&date=04012019-07152021&page=4&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_5 = "https://stocknewsapi.com/api/v1/stat?&tickers=BABA&date=04012019-07152021&page=5&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_6 = "https://stocknewsapi.com/api/v1/stat?&tickers=BABA&date=04012019-07152021&page=6&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_7 = "https://stocknewsapi.com/api/v1/stat?&tickers=BABA&date=04012019-07152021&page=7&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_8 = "https://stocknewsapi.com/api/v1/stat?&tickers=BABA&date=04012019-07152021&page=8&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_9 = "https://stocknewsapi.com/api/v1/stat?&tickers=BABA&date=04012019-07152021&page=9&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_10 = "https://stocknewsapi.com/api/v1/stat?&tickers=BABA&date=04012019-07152021&page=10&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_11 = "https://stocknewsapi.com/api/v1/stat?&tickers=BABA&date=04012019-07152021&page=11&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_12 = "https://stocknewsapi.com/api/v1/stat?&tickers=BABA&date=04012019-07152021&page=12&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"
url_13 = "https://stocknewsapi.com/api/v1/stat?&tickers=BABA&date=04012019-07152021&page=13&token=djenvnaczug9w9yyl3nulhj2jr1tlyt9eyhiemit"

# %%
response = requests.get(url_2)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
baba2 = data

# %%
response = requests.get(url_3)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
baba3 = data

# %%
response = requests.get(url_4)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
baba4 = data

# %%
response = requests.get(url_5)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
baba5 = data

# %%
response = requests.get(url_6)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
baba6 = data

# %%
response = requests.get(url_7)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
baba7 = data

# %%
response = requests.get(url_8)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
baba8 = data

# %%
response = requests.get(url_9)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
baba9 = data

# %%
response = requests.get(url_10)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
baba10 = data

# %%
response = requests.get(url_11)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
baba11 = data

# %%
response = requests.get(url_12)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
baba12 = data

# %%
response = requests.get(url_13)
if response.status_code != 200:
    print("deu ruim")
data = response.json()
data
baba13 = data

# %%
baba1['data'].keys()
datas = baba1['data'].keys()
baba_list1 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(baba1['data'][key]['BABA']['Positive'])
    mini_array.append(baba1['data'][key]['BABA']['Neutral'])
    mini_array.append(baba1['data'][key]['BABA']['Negative'])
    mini_array.append(baba1['data'][key]['BABA']['sentiment_score'])
    baba_list1.append(mini_array)
baba_list1
# Out:
# [['2021-07-15', 1, 1, 3, -0.4],
#  ['2021-07-14', 6, 1, 1, 1.063],
#  ['2021-07-13', 3, 3, 2, 0.563],
#  ['2021-07-12', 4, 1, 2, 0.571],
#  ['2021-07-11', 0, 2, 0, 1],
#  ['2021-07-10', 1, 0, 0, 1.5],
#  ['2021-07-09', 1, 1, 2, -0.125],
#  ['2021-07-08', 2, 1, 8, -0.727],
#  ['2021-07-07', 3, 1, 4, -0.063],
#  ['2021-07-06', 0, 2, 5, -0.786],
#  ['2021-07-05', 0, 1, 0, 1],
#  ['2021-07-04', 1, 0, 0, 1.5],
#  ['2021-07-02', 0, 0, 2, -1.5],
#  ['2021-07-01', 1, 1, 1, 0.333],
#  ['2021-06-30', 1, 0, 0, 1.5],
#  ['2021-06-29', 2, 2, 0, 1.25],
#  ['2021-06-28', 3, 1, 0, 1.375],
#  ['2021-06-27', 2, 0, 0, 1.5],
#  ['2021-06-25', 2, 0, 0, 1.5],
#  ['2021-06-24', 0, 1, 0, 1],
#  ['2021-06-23', 2, 1, 0, 1.333],
#  ['2021-06-21', 5, 2, 0, 1.357],
#  ['2021-06-17', 0, 1, 0, 1],
#  ['2021-06-16', 1, 1, 1, 0.333],
#  ['2021-06-15', 4, 2, 2, 0.625],
#  ['2021-06-14', 2, 1, 0, 1.333],
#  ['2021-06-13', 0, 1, 0, 1],
#  ['2021-06-11', 0, 1, 0, 1],
#  ['2021-06-10', 4, 1, 0, 1.4],
# ...

# %%
baba2['data'].keys()
datas = baba2['data'].keys()
baba_list2 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(baba2['data'][key]['BABA']['Positive'])
    mini_array.append(baba2['data'][key]['BABA']['Neutral'])
    mini_array.append(baba2['data'][key]['BABA']['Negative'])
    mini_array.append(baba2['data'][key]['BABA']['sentiment_score'])
    baba_list2.append(mini_array)
baba_list2
# Out:
# [['2021-05-14', 5, 2, 3, 0.5],
#  ['2021-05-13', 3, 6, 14, -0.457],
#  ['2021-05-12', 1, 2, 1, 0.5],
#  ['2021-05-11', 2, 1, 0, 1.333],
#  ['2021-05-10', 4, 2, 1, 0.929],
#  ['2021-05-09', 1, 1, 0, 1.25],
#  ['2021-05-08', 0, 1, 0, 1],
#  ['2021-05-07', 1, 1, 0, 1.25],
#  ['2021-05-06', 0, 1, 0, 1],
#  ['2021-05-05', 0, 1, 1, -0.25],
#  ['2021-05-04', 1, 0, 0, 1.5],
#  ['2021-05-03', 4, 0, 4, 0],
#  ['2021-05-02', 0, 1, 0, 1],
#  ['2021-04-30', 0, 5, 1, 0.583],
#  ['2021-04-29', 1, 0, 0, 1.5],
#  ['2021-04-28', 2, 1, 0, 1.333],
#  ['2021-04-27', 1, 2, 1, 0.5],
#  ['2021-04-26', 1, 3, 0, 1.125],
#  ['2021-04-25', 0, 1, 1, -0.25],
#  ['2021-04-23', 2, 0, 0, 1.5],
#  ['2021-04-22', 3, 1, 0, 1.375],
#  ['2021-04-21', 2, 0, 1, 0.5],
#  ['2021-04-20', 1, 1, 0, 1.25],
#  ['2021-04-19', 2, 2, 1, 0.7],
#  ['2021-04-18', 0, 2, 0, 1],
#  ['2021-04-17', 0, 0, 1, -1.5],
#  ['2021-04-16', 1, 2, 1, 0.5],
#  ['2021-04-15', 2, 3, 0, 1.2],
#  ['2021-04-14', 2, 0, 2, 0],
# ...

# %%
baba3['data'].keys()
datas = baba3['data'].keys()
baba_list3 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(baba3['data'][key]['BABA']['Positive'])
    mini_array.append(baba3['data'][key]['BABA']['Neutral'])
    mini_array.append(baba3['data'][key]['BABA']['Negative'])
    mini_array.append(baba3['data'][key]['BABA']['sentiment_score'])
    baba_list3.append(mini_array)
baba_list3
# Out:
# [['2021-03-21', 1, 1, 0, 1.25],
#  ['2021-03-19', 1, 0, 1, 0],
#  ['2021-03-18', 1, 0, 1, 0],
#  ['2021-03-17', 1, 1, 2, -0.125],
#  ['2021-03-16', 0, 1, 5, -1.083],
#  ['2021-03-15', 2, 1, 6, -0.556],
#  ['2021-03-13', 0, 1, 0, 1],
#  ['2021-03-12', 2, 2, 1, 0.7],
#  ['2021-03-11', 2, 0, 4, -0.5],
#  ['2021-03-10', 2, 1, 0, 1.333],
#  ['2021-03-09', 5, 0, 0, 1.5],
#  ['2021-03-05', 0, 1, 0, 1],
#  ['2021-03-02', 1, 2, 0, 1.167],
#  ['2021-03-01', 0, 1, 0, 1],
#  ['2021-02-28', 0, 0, 1, -1.5],
#  ['2021-02-27', 0, 2, 0, 1],
#  ['2021-02-26', 4, 1, 0, 1.4],
#  ['2021-02-25', 1, 1, 0, 1.25],
#  ['2021-02-23', 3, 2, 0, 1.3],
#  ['2021-02-20', 0, 1, 0, 1],
#  ['2021-02-19', 2, 1, 0, 1.333],
#  ['2021-02-18', 2, 0, 0, 1.5],
#  ['2021-02-12', 0, 0, 1, -1.5],
#  ['2021-02-11', 2, 0, 0, 1.5],
#  ['2021-02-09', 1, 0, 0, 1.5],
#  ['2021-02-08', 1, 0, 1, 0],
#  ['2021-02-07', 2, 1, 0, 1.333],
#  ['2021-02-06', 0, 1, 0, 1],
#  ['2021-02-05', 1, 1, 0, 1.25],
#  ['2021-02-04', 0, 2, 0, 1],
# ...

# %%
baba4['data'].keys()
datas = baba4['data'].keys()
baba_list4 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(baba4['data'][key]['BABA']['Positive'])
    mini_array.append(baba4['data'][key]['BABA']['Neutral'])
    mini_array.append(baba4['data'][key]['BABA']['Negative'])
    mini_array.append(baba4['data'][key]['BABA']['sentiment_score'])
    baba_list4.append(mini_array)
baba_list4
# Out:
# [['2021-01-09', 0, 0, 1, -1.5],
#  ['2021-01-08', 2, 3, 4, 0],
#  ['2021-01-07', 1, 1, 4, -0.583],
#  ['2021-01-06', 3, 2, 13, -0.722],
#  ['2021-01-05', 7, 5, 17, -0.345],
#  ['2021-01-04', 3, 2, 8, -0.423],
#  ['2021-01-03', 0, 1, 0, 1],
#  ['2021-01-01', 1, 0, 0, 1.5],
#  ['2020-12-31', 4, 3, 0, 1.286],
#  ['2020-12-30', 4, 2, 3, 0.389],
#  ['2020-12-29', 6, 1, 3, 0.55],
#  ['2020-12-28', 2, 1, 10, -0.846],
#  ['2020-12-27', 0, 3, 4, -0.429],
#  ['2020-12-26', 2, 0, 1, 0.5],
#  ['2020-12-25', 2, 1, 0, 1.333],
#  ['2020-12-24', 0, 8, 28, -0.944],
#  ['2020-12-23', 1, 0, 9, -1.2],
#  ['2020-12-22', 2, 3, 1, 0.75],
#  ['2020-12-21', 1, 0, 1, 0],
#  ['2020-12-19', 0, 1, 1, -0.25],
#  ['2020-12-18', 3, 2, 0, 1.3],
#  ['2020-12-17', 3, 3, 0, 1.25],
#  ['2020-12-16', 1, 1, 1, 0.333],
#  ['2020-12-14', 2, 0, 8, -0.9],
#  ['2020-12-12', 0, 1, 0, 1],
#  ['2020-12-11', 1, 0, 0, 1.5],
#  ['2020-12-09', 3, 0, 1, 0.75],
#  ['2020-12-08', 1, 1, 0, 1.25],
#  ['2020-12-07', 1, 1, 0, 1.25],
# ...

# %%
baba5['data'].keys()
datas = baba5['data'].keys()
baba_list5 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(baba5['data'][key]['BABA']['Positive'])
    mini_array.append(baba5['data'][key]['BABA']['Neutral'])
    mini_array.append(baba5['data'][key]['BABA']['Negative'])
    mini_array.append(baba5['data'][key]['BABA']['sentiment_score'])
    baba_list5.append(mini_array)
baba_list5
# Out:
# [['2020-11-11', 21, 1, 14, 0.319],
#  ['2020-11-10', 7, 4, 3, 0.714],
#  ['2020-11-09', 2, 2, 2, 0.333],
#  ['2020-11-07', 0, 0, 1, -1.5],
#  ['2020-11-06', 5, 3, 1, 1],
#  ['2020-11-05', 4, 4, 10, -0.278],
#  ['2020-11-04', 5, 4, 3, 0.583],
#  ['2020-11-03', 2, 9, 26, -0.73],
#  ['2020-11-02', 10, 1, 1, 1.208],
#  ['2020-10-31', 2, 0, 0, 1.5],
#  ['2020-10-30', 6, 1, 0, 1.429],
#  ['2020-10-29', 2, 0, 0, 1.5],
#  ['2020-10-28', 1, 2, 0, 1.167],
#  ['2020-10-27', 3, 0, 0, 1.5],
#  ['2020-10-26', 6, 2, 0, 1.375],
#  ['2020-10-24', 0, 2, 0, 1],
#  ['2020-10-23', 4, 0, 0, 1.5],
#  ['2020-10-22', 0, 4, 0, 1],
#  ['2020-10-20', 3, 1, 0, 1.375],
#  ['2020-10-19', 7, 0, 0, 1.5],
#  ['2020-10-18', 5, 1, 0, 1.417],
#  ['2020-10-16', 2, 0, 0, 1.5],
#  ['2020-10-15', 0, 0, 2, -1.5],
#  ['2020-10-14', 2, 0, 1, 0.5],
#  ['2020-10-13', 1, 0, 0, 1.5],
#  ['2020-10-12', 3, 1, 1, 0.8],
#  ['2020-10-11', 1, 0, 0, 1.5],
#  ['2020-10-09', 0, 0, 1, -1.5],
#  ['2020-10-08', 1, 0, 0, 1.5],
# ...

# %%
baba6['data'].keys()
datas = baba6['data'].keys()
baba_list6 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(baba6['data'][key]['BABA']['Positive'])
    mini_array.append(baba6['data'][key]['BABA']['Neutral'])
    mini_array.append(baba6['data'][key]['BABA']['Negative'])
    mini_array.append(baba6['data'][key]['BABA']['sentiment_score'])
    baba_list6.append(mini_array)
baba_list6
# Out:
# [['2020-09-09', 1, 0, 0, 1.5],
#  ['2020-09-08', 4, 0, 0, 1.5],
#  ['2020-09-07', 1, 0, 0, 1.5],
#  ['2020-09-06', 1, 0, 0, 1.5],
#  ['2020-09-04', 3, 0, 0, 1.5],
#  ['2020-09-03', 1, 1, 0, 1.25],
#  ['2020-09-02', 2, 0, 2, 0],
#  ['2020-08-31', 2, 0, 0, 1.5],
#  ['2020-08-28', 2, 0, 0, 1.5],
#  ['2020-08-27', 1, 2, 1, 0.5],
#  ['2020-08-26', 3, 3, 1, 0.857],
#  ['2020-08-25', 8, 2, 0, 1.4],
#  ['2020-08-24', 4, 1, 0, 1.4],
#  ['2020-08-22', 1, 0, 0, 1.5],
#  ['2020-08-21', 10, 2, 0, 1.417],
#  ['2020-08-20', 7, 3, 4, 0.536],
#  ['2020-08-19', 3, 2, 0, 1.3],
#  ['2020-08-18', 2, 0, 0, 1.5],
#  ['2020-08-17', 2, 1, 0, 1.333],
#  ['2020-08-16', 0, 1, 0, 1],
#  ['2020-08-15', 1, 0, 1, 0],
#  ['2020-08-14', 2, 1, 0, 1.333],
#  ['2020-08-13', 2, 1, 1, 0.625],
#  ['2020-08-12', 2, 2, 0, 1.25],
#  ['2020-08-11', 1, 0, 0, 1.5],
#  ['2020-08-10', 0, 2, 1, 0.167],
#  ['2020-08-09', 1, 0, 0, 1.5],
#  ['2020-08-07', 3, 2, 3, 0.25],
#  ['2020-08-06', 1, 0, 0, 1.5],
# ...

# %%
baba7['data'].keys()
datas = baba7['data'].keys()
baba_list7 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(baba7['data'][key]['BABA']['Positive'])
    mini_array.append(baba7['data'][key]['BABA']['Neutral'])
    mini_array.append(baba7['data'][key]['BABA']['Negative'])
    mini_array.append(baba7['data'][key]['BABA']['sentiment_score'])
    baba_list7.append(mini_array)
baba_list7
# Out:
# [['2020-07-06', 3, 0, 0, 1.5],
#  ['2020-07-03', 1, 0, 1, 0],
#  ['2020-07-02', 2, 1, 0, 1.333],
#  ['2020-07-01', 4, 1, 0, 1.4],
#  ['2020-06-30', 3, 0, 0, 1.5],
#  ['2020-06-29', 3, 0, 0, 1.5],
#  ['2020-06-27', 1, 0, 0, 1.5],
#  ['2020-06-26', 2, 1, 0, 1.333],
#  ['2020-06-25', 3, 0, 5, -0.375],
#  ['2020-06-24', 2, 2, 0, 1.25],
#  ['2020-06-23', 1, 1, 0, 1.25],
#  ['2020-06-22', 1, 0, 0, 1.5],
#  ['2020-06-19', 7, 0, 0, 1.5],
#  ['2020-06-17', 2, 0, 0, 1.5],
#  ['2020-06-15', 5, 0, 0, 1.5],
#  ['2020-06-14', 1, 0, 0, 1.5],
#  ['2020-06-12', 3, 0, 0, 1.5],
#  ['2020-06-10', 3, 0, 0, 1.5],
#  ['2020-06-09', 7, 2, 0, 1.389],
#  ['2020-06-08', 3, 0, 0, 1.5],
#  ['2020-06-06', 0, 1, 0, 1],
#  ['2020-06-05', 1, 0, 0, 1.5],
#  ['2020-06-04', 2, 1, 1, 0.625],
#  ['2020-06-03', 4, 0, 0, 1.5],
#  ['2020-06-02', 6, 0, 0, 1.5],
#  ['2020-06-01', 1, 0, 0, 1.5],
#  ['2020-05-29', 3, 0, 0, 1.5],
#  ['2020-05-28', 4, 1, 1, 0.917],
#  ['2020-05-27', 0, 1, 3, -0.875],
# ...

# %%
baba8['data'].keys()
datas = baba8['data'].keys()
baba_list8 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(baba8['data'][key]['BABA']['Positive'])
    mini_array.append(baba8['data'][key]['BABA']['Neutral'])
    mini_array.append(baba8['data'][key]['BABA']['Negative'])
    mini_array.append(baba8['data'][key]['BABA']['sentiment_score'])
    baba_list8.append(mini_array)
baba_list8
# Out:
# [['2020-04-24', 0, 1, 0, 1],
#  ['2020-04-22', 1, 0, 0, 1.5],
#  ['2020-04-21', 1, 2, 0, 1.167],
#  ['2020-04-20', 4, 4, 0, 1.25],
#  ['2020-04-17', 2, 0, 1, 0.5],
#  ['2020-04-16', 1, 0, 0, 1.5],
#  ['2020-04-15', 1, 1, 0, 1.25],
#  ['2020-04-14', 1, 0, 1, 0],
#  ['2020-04-13', 0, 0, 1, -1.5],
#  ['2020-04-12', 0, 0, 1, -1.5],
#  ['2020-04-09', 5, 1, 0, 1.417],
#  ['2020-04-08', 3, 1, 0, 1.375],
#  ['2020-04-07', 2, 0, 0, 1.5],
#  ['2020-04-06', 2, 0, 0, 1.5],
#  ['2020-04-04', 1, 0, 0, 1.5],
#  ['2020-04-03', 4, 0, 0, 1.5],
#  ['2020-04-02', 2, 1, 0, 1.333],
#  ['2020-04-01', 2, 0, 0, 1.5],
#  ['2020-03-31', 0, 0, 1, -1.5],
#  ['2020-03-30', 0, 2, 0, 1],
#  ['2020-03-28', 1, 0, 0, 1.5],
#  ['2020-03-27', 1, 0, 0, 1.5],
#  ['2020-03-25', 0, 1, 0, 1],
#  ['2020-03-24', 3, 0, 1, 0.75],
#  ['2020-03-23', 4, 1, 2, 0.571],
#  ['2020-03-22', 1, 1, 0, 1.25],
#  ['2020-03-21', 0, 1, 0, 1],
#  ['2020-03-20', 0, 0, 1, -1.5],
#  ['2020-03-19', 1, 1, 0, 1.25],
#  ['2020-03-18', 0, 1, 0, 1],
# ...

# %%
baba9['data'].keys()
datas = baba9['data'].keys()
baba_list9 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(baba9['data'][key]['BABA']['Positive'])
    mini_array.append(baba9['data'][key]['BABA']['Neutral'])
    mini_array.append(baba9['data'][key]['BABA']['Negative'])
    mini_array.append(baba9['data'][key]['BABA']['sentiment_score'])
    baba_list9.append(mini_array)
baba_list9
# Out:
# [['2020-02-21', 2, 1, 0, 1.333],
#  ['2020-02-20', 2, 0, 0, 1.5],
#  ['2020-02-19', 1, 1, 0, 1.25],
#  ['2020-02-18', 3, 1, 1, 0.8],
#  ['2020-02-17', 2, 0, 0, 1.5],
#  ['2020-02-15', 3, 0, 0, 1.5],
#  ['2020-02-14', 3, 0, 0, 1.5],
#  ['2020-02-13', 7, 1, 6, 0.179],
#  ['2020-02-12', 6, 1, 1, 1.063],
#  ['2020-02-11', 1, 2, 0, 1.167],
#  ['2020-02-10', 3, 4, 0, 1.214],
#  ['2020-02-08', 1, 0, 1, 0],
#  ['2020-02-07', 1, 1, 1, 0.333],
#  ['2020-02-06', 1, 0, 0, 1.5],
#  ['2020-02-05', 1, 0, 0, 1.5],
#  ['2020-02-04', 1, 1, 1, 0.333],
#  ['2020-02-03', 2, 4, 0, 1.167],
#  ['2020-02-01', 1, 1, 0, 1.25],
#  ['2020-01-31', 1, 0, 0, 1.5],
#  ['2020-01-30', 2, 1, 1, 0.625],
#  ['2020-01-29', 1, 1, 1, 0.333],
#  ['2020-01-28', 2, 0, 0, 1.5],
#  ['2020-01-27', 1, 0, 4, -0.9],
#  ['2020-01-26', 2, 0, 0, 1.5],
#  ['2020-01-24', 2, 0, 1, 0.5],
#  ['2020-01-23', 2, 0, 1, 0.5],
#  ['2020-01-21', 2, 0, 0, 1.5],
#  ['2020-01-19', 0, 1, 0, 1],
#  ['2020-01-18', 1, 0, 0, 1.5],
# ...

# %%
baba10['data'].keys()
datas = baba10['data'].keys()
baba_list10 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(baba10['data'][key]['BABA']['Positive'])
    mini_array.append(baba10['data'][key]['BABA']['Neutral'])
    mini_array.append(baba10['data'][key]['BABA']['Negative'])
    mini_array.append(baba10['data'][key]['BABA']['sentiment_score'])
    baba_list10.append(mini_array)
baba_list10
# Out:
# [['2019-12-19', 1, 1, 0, 1.25],
#  ['2019-12-18', 1, 1, 0, 1.25],
#  ['2019-12-17', 0, 0, 1, -1.5],
#  ['2019-12-13', 2, 1, 0, 1.333],
#  ['2019-12-12', 2, 1, 0, 1.333],
#  ['2019-12-11', 2, 5, 0, 1.143],
#  ['2019-12-10', 3, 0, 0, 1.5],
#  ['2019-12-06', 2, 1, 1, 0.625],
#  ['2019-12-05', 3, 2, 0, 1.3],
#  ['2019-12-04', 1, 2, 0, 1.167],
#  ['2019-12-03', 4, 0, 0, 1.5],
#  ['2019-12-02', 3, 0, 1, 0.75],
#  ['2019-11-30', 1, 0, 0, 1.5],
#  ['2019-11-29', 1, 0, 0, 1.5],
#  ['2019-11-28', 2, 0, 0, 1.5],
#  ['2019-11-27', 3, 0, 0, 1.5],
#  ['2019-11-26', 10, 5, 0, 1.333],
#  ['2019-11-25', 8, 0, 0, 1.5],
#  ['2019-11-22', 3, 1, 0, 1.375],
#  ['2019-11-21', 3, 2, 1, 0.833],
#  ['2019-11-20', 5, 3, 0, 1.313],
#  ['2019-11-19', 5, 3, 0, 1.313],
#  ['2019-11-18', 1, 1, 0, 1.25],
#  ['2019-11-17', 1, 0, 0, 1.5],
#  ['2019-11-16', 2, 0, 0, 1.5],
#  ['2019-11-15', 3, 3, 1, 0.857],
#  ['2019-11-14', 6, 4, 1, 1.045],
#  ['2019-11-13', 10, 6, 1, 1.147],
#  ['2019-11-12', 5, 0, 0, 1.5],
# ...

# %%
baba11['data'].keys()
datas = baba11['data'].keys()
baba_list11 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(baba11['data'][key]['BABA']['Positive'])
    mini_array.append(baba11['data'][key]['BABA']['Neutral'])
    mini_array.append(baba11['data'][key]['BABA']['Negative'])
    mini_array.append(baba11['data'][key]['BABA']['sentiment_score'])
    baba_list11.append(mini_array)
baba_list11
# Out:
# [['2019-10-14', 1, 1, 0, 1.25],
#  ['2019-10-11', 2, 0, 0, 1.5],
#  ['2019-10-10', 2, 1, 1, 0.625],
#  ['2019-10-09', 3, 2, 0, 1.3],
#  ['2019-10-08', 1, 1, 1, 0.333],
#  ['2019-10-07', 1, 0, 0, 1.5],
#  ['2019-10-04', 2, 0, 0, 1.5],
#  ['2019-10-03', 2, 3, 0, 1.2],
#  ['2019-10-02', 1, 0, 0, 1.5],
#  ['2019-10-01', 3, 2, 1, 0.833],
#  ['2019-09-30', 2, 4, 1, 0.786],
#  ['2019-09-27', 1, 5, 2, 0.438],
#  ['2019-09-26', 3, 1, 0, 1.375],
#  ['2019-09-25', 2, 1, 0, 1.333],
#  ['2019-09-24', 2, 3, 1, 0.75],
#  ['2019-09-23', 2, 2, 0, 1.25],
#  ['2019-09-22', 1, 0, 0, 1.5],
#  ['2019-09-20', 1, 1, 0, 1.25],
#  ['2019-09-19', 1, 1, 1, 0.333],
#  ['2019-09-18', 2, 1, 0, 1.333],
#  ['2019-09-17', 2, 0, 0, 1.5],
#  ['2019-09-16', 2, 0, 0, 1.5],
#  ['2019-09-13', 1, 0, 0, 1.5],
#  ['2019-09-12', 4, 0, 0, 1.5],
#  ['2019-09-11', 0, 1, 0, 1],
#  ['2019-09-10', 3, 12, 0, 1.1],
#  ['2019-09-09', 2, 4, 1, 0.786],
#  ['2019-09-06', 1, 1, 0, 1.25],
#  ['2019-09-05', 0, 3, 0, 1],
# ...

# %%
baba12['data'].keys()
datas = baba12['data'].keys()
baba_list12 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(baba12['data'][key]['BABA']['Positive'])
    mini_array.append(baba12['data'][key]['BABA']['Neutral'])
    mini_array.append(baba12['data'][key]['BABA']['Negative'])
    mini_array.append(baba12['data'][key]['BABA']['sentiment_score'])
    baba_list12.append(mini_array)
baba_list12
# Out:
# [['2019-08-05', 2, 1, 1, 0.625],
#  ['2019-08-03', 0, 1, 0, 1],
#  ['2019-08-02', 1, 1, 0, 1.25],
#  ['2019-08-01', 2, 1, 0, 1.333],
#  ['2019-07-31', 1, 1, 0, 1.25],
#  ['2019-07-30', 3, 0, 0, 1.5],
#  ['2019-07-29', 1, 1, 0, 1.25],
#  ['2019-07-26', 2, 0, 0, 1.5],
#  ['2019-07-25', 3, 0, 0, 1.5],
#  ['2019-07-24', 4, 2, 0, 1.333],
#  ['2019-07-23', 8, 0, 0, 1.5],
#  ['2019-07-22', 1, 0, 0, 1.5],
#  ['2019-07-21', 1, 0, 0, 1.5],
#  ['2019-07-19', 2, 0, 0, 1.5],
#  ['2019-07-18', 2, 0, 0, 1.5],
#  ['2019-07-17', 3, 0, 0, 1.5],
#  ['2019-07-16', 5, 0, 0, 1.5],
#  ['2019-07-13', 0, 1, 0, 1],
#  ['2019-07-12', 1, 0, 0, 1.5],
#  ['2019-07-11', 5, 1, 0, 1.417],
#  ['2019-07-09', 3, 2, 1, 0.833],
#  ['2019-07-08', 0, 0, 1, -1.5],
#  ['2019-07-05', 1, 0, 0, 1.5],
#  ['2019-07-03', 2, 2, 0, 1.25],
#  ['2019-07-02', 3, 0, 0, 1.5],
#  ['2019-07-01', 5, 0, 0, 1.5],
#  ['2019-06-30', 0, 0, 1, -1.5],
#  ['2019-06-28', 0, 1, 0, 1],
#  ['2019-06-27', 5, 1, 0, 1.417],
# ...

# %%
baba13['data'].keys()
datas = baba13['data'].keys()
baba_list13 = []
for key in datas:
    mini_array = []
    mini_array.append(key)
    mini_array.append(baba13['data'][key]['BABA']['Positive'])
    mini_array.append(baba13['data'][key]['BABA']['Neutral'])
    mini_array.append(baba13['data'][key]['BABA']['Negative'])
    mini_array.append(baba13['data'][key]['BABA']['sentiment_score'])
    baba_list13.append(mini_array)
baba_list13
# Out:
# [['2019-05-31', 1, 1, 2, -0.125],
#  ['2019-05-30', 2, 0, 0, 1.5],
#  ['2019-05-29', 3, 0, 1, 0.75],
#  ['2019-05-28', 6, 2, 1, 1.056],
#  ['2019-05-27', 2, 2, 0, 1.25],
#  ['2019-05-24', 3, 0, 1, 0.75],
#  ['2019-05-23', 1, 1, 1, 0.333],
#  ['2019-05-20', 4, 0, 2, 0.5],
#  ['2019-05-18', 1, 0, 0, 1.5],
#  ['2019-05-17', 1, 0, 0, 1.5],
#  ['2019-05-16', 5, 2, 0, 1.357],
#  ['2019-05-15', 13, 1, 2, 1.094],
#  ['2019-05-14', 1, 1, 1, 0.333],
#  ['2019-05-13', 3, 2, 1, 0.833],
#  ['2019-05-11', 0, 1, 0, 1],
#  ['2019-05-10', 1, 0, 1, 0],
#  ['2019-05-09', 2, 0, 0, 1.5],
#  ['2019-05-08', 3, 0, 0, 1.5],
#  ['2019-05-07', 3, 0, 0, 1.5],
#  ['2019-05-04', 0, 0, 1, -1.5],
#  ['2019-05-03', 1, 0, 0, 1.5],
#  ['2019-05-01', 1, 0, 0, 1.5],
#  ['2019-04-26', 1, 0, 1, 0],
#  ['2019-04-25', 1, 0, 1, 0],
#  ['2019-04-24', 1, 1, 0, 1.25],
#  ['2019-04-23', 0, 1, 0, 1],
#  ['2019-04-22', 0, 1, 0, 1],
#  ['2019-04-18', 1, 0, 0, 1.5],
#  ['2019-04-16', 1, 0, 0, 1.5],
#  ['2019-04-15', 0, 3, 0, 1],
# ...

# %%
baba_list = baba_list1 + baba_list2 + baba_list3 + baba_list4 + baba_list5 + baba_list6 + baba_list7 + baba_list8 + baba_list9 + baba_list10 + baba_list11 + baba_list12 + baba_list13

# %%
# # my_dict = json.load(json_file)
baba_df = pd.DataFrame(baba_list)
baba_df.shape
# Out:
# (636, 5)

# %%
baba_df.to_csv('baba_df.csv')

# %%
baba_df
# Out:
#               0  1  2  3      4
# 0    2021-07-15  1  1  3 -0.400
# 1    2021-07-14  6  1  1  1.063
# 2    2021-07-13  3  3  2  0.563
# 3    2021-07-12  4  1  2  0.571
# 4    2021-07-11  0  2  0  1.000
# ..          ... .. .. ..    ...
# 631  2019-04-08  0  1  0  1.000
# 632  2019-04-05  1  0  1  0.000
# 633  2019-04-03  2  0  0  1.500
# 634  2019-04-02  1  0  0  1.500
# 635  2019-04-01  3  0  0  1.500
#
# [636 rows x 5 columns]
